# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# import plotly.express as px

# %%
land_data = pd.read_csv('Resources/LAND_COVER_14032023014858227.csv')

# %%
land_data.head()
# Out:
#    COU    Country  SMALL_SUBNATIONAL_REGION Small subnational region  \
# 0  AUS  Australia                       NaN           Not applicable
# 1  AUS  Australia                       NaN           Not applicable
# 2  AUS  Australia                       NaN           Not applicable
# 3  AUS  Australia                       NaN           Not applicable
# 4  AUS  Australia                       NaN           Not applicable
#
#   LARGE_SUBNATIONAL_REGION           Large subnational region           MEAS  \
# 0           GAUL1_467_2015  Administrative unit not available  THOUSAND_SQKM
# 1           GAUL1_467_2015  Administrative unit not available  THOUSAND_SQKM
# 2           GAUL1_467_2015  Administrative unit not available  THOUSAND_SQKM
# 3           GAUL1_467_2015  Administrative unit not available  THOUSAND_SQKM
# 4           GAUL1_467_2015  Administrative unit not available  THOUSAND_SQKM
#
#                      Measure VARIABLE Land cover class  ...  Year  Unit Code  \
# 0  Square kilometers (000's)    CROPL         Cropland  ...  1992        KM2
# 1  Square kilometers (000's)    CROPL         Cropland  ...  2004        KM2
# 2  Square kilometers (000's)    CROPL         Cropland  ...  2015        KM2
# 3  Square kilometers (000's)    CROPL         Cropland  ...  2018        KM2
# 4  Square kilometers (000's)    CROPL         Cropland  ...  2019        KM2
#
#                 Unit PowerCode Code  PowerCode Reference Period Code  \
# 0  Square kilometres              3  Thousands                   NaN
# 1  Square kilometres              3  Thousands                   NaN
# 2  Square kilometres              3  Thousands                   NaN
# 3  Square kilometres              3  Thousands                   NaN
# 4  Square kilometres              3  Thousands                   NaN
#
#    Reference Period  Value  Flag Codes  Flags
# 0               NaN    0.0         NaN    NaN
# 1               NaN    0.0         NaN    NaN
# 2               NaN    0.0         NaN    NaN
# 3               NaN    0.0         NaN    NaN
# 4               NaN    0.0         NaN    NaN
#
# [5 rows x 21 columns]

# %%
land_data.columns
# Out:
# Index(['COU', 'Country', 'SMALL_SUBNATIONAL_REGION',
#        'Small subnational region', 'LARGE_SUBNATIONAL_REGION',
#        'Large subnational region', 'MEAS', 'Measure', 'VARIABLE',
#        'Land cover class', 'YEA', 'Year', 'Unit Code', 'Unit',
#        'PowerCode Code', 'PowerCode', 'Reference Period Code',
#        'Reference Period', 'Value', 'Flag Codes', 'Flags'],
#       dtype='object')

# %%
# Filtering to USA
usa_data = land_data.loc[land_data['COU'] == 'USA'] 
usa_data
# Out:
#         COU        Country  SMALL_SUBNATIONAL_REGION Small subnational region  \
# 220473  USA  United States                       NaN           Not applicable
# 220474  USA  United States                       NaN           Not applicable
# 220475  USA  United States                       NaN           Not applicable
# 220476  USA  United States                       NaN           Not applicable
# 220477  USA  United States                       NaN           Not applicable
# ...     ...            ...                       ...                      ...
# 246208  USA  United States                       NaN           Not applicable
# 246209  USA  United States                       NaN           Not applicable
# 246210  USA  United States                       NaN           Not applicable
# 246211  USA  United States                       NaN           Not applicable
# 246212  USA  United States                       NaN           Not applicable
#
#        LARGE_SUBNATIONAL_REGION Large subnational region           MEAS  \
# 220473           OECD_US01_2021                  Alabama  THOUSAND_SQKM
# 220474           OECD_US01_2021                  Alabama  THOUSAND_SQKM
# 220475           OECD_US01_2021                  Alabama  THOUSAND_SQKM
# 220476           OECD_US01_2021                  Alabama  THOUSAND_SQKM
# 220477           OECD_US01_2021                  Alabama  THOUSAND_SQKM
# ...                         ...                      ...            ...
# 246208           OECD_US51_2021                 Virginia           PCNT
# 246209           OECD_US51_2021                 Virginia           PCNT
# 246210           OECD_US51_2021                 Virginia           PCNT
# 246211           OECD_US51_2021                 Virginia           PCNT
# 246212           OECD_US51_2021                 Virginia           PCNT
#
#                               Measure VARIABLE Land cover class  ...  Year  \
# 220473      Square kilometers (000's)   FOREST       Tree cover  ...  1992
# 220474      Square kilometers (000's)   FOREST       Tree cover  ...  2004
# 220475      Square kilometers (000's)   FOREST       Tree cover  ...  2015
# 220476      Square kilometers (000's)   FOREST       Tree cover  ...  2018
# 220477      Square kilometers (000's)   FOREST       Tree cover  ...  2019
# ...                               ...      ...              ...  ...   ...
# 246208  Percent of total country area    WATER     Inland water  ...  1992
# 246209  Percent of total country area    WATER     Inland water  ...  2004
# 246210  Percent of total country area    WATER     Inland water  ...  2015
# 246211  Percent of total country area    WATER     Inland water  ...  2018
# 246212  Percent of total country area    WATER     Inland water  ...  2019
#
#         Unit Code               Unit PowerCode Code  PowerCode  \
# 220473        KM2  Square kilometres              3  Thousands
# 220474        KM2  Square kilometres              3  Thousands
# 220475        KM2  Square kilometres              3  Thousands
# 220476        KM2  Square kilometres              3  Thousands
# 220477        KM2  Square kilometres              3  Thousands
# ...           ...                ...            ...        ...
# 246208         PC         Percentage              0      Units
# 246209         PC         Percentage              0      Units
# 246210         PC         Percentage              0      Units
# 246211         PC         Percentage              0      Units
# 246212         PC         Percentage              0      Units
#
#        Reference Period Code  Reference Period      Value  Flag Codes  Flags
# 220473                   NaN               NaN  91.541198         NaN    NaN
# 220474                   NaN               NaN  91.354866         NaN    NaN
# 220475                   NaN               NaN  91.018603         NaN    NaN
# 220476                   NaN               NaN  89.994977         NaN    NaN
# 220477                   NaN               NaN  87.106024         NaN    NaN
# ...                      ...               ...        ...         ...    ...
# 246208                   NaN               NaN   2.588716         NaN    NaN
# 246209                   NaN               NaN   2.629073         NaN    NaN
# 246210                   NaN               NaN   2.644922         NaN    NaN
# 246211                   NaN               NaN   2.645142         NaN    NaN
# 246212                   NaN               NaN   2.645142         NaN    NaN
#
# [4590 rows x 21 columns]

# %%
# Filtering to most recent year
usa_2019_data = usa_data.loc[usa_data['Year'] == 2019] 
usa_2019_data
# Out:
#         COU        Country  SMALL_SUBNATIONAL_REGION Small subnational region  \
# 220477  USA  United States                       NaN           Not applicable
# 220482  USA  United States                       NaN           Not applicable
# 220487  USA  United States                       NaN           Not applicable
# 220492  USA  United States                       NaN           Not applicable
# 220497  USA  United States                       NaN           Not applicable
# ...     ...            ...                       ...                      ...
# 246192  USA  United States                       NaN           Not applicable
# 246197  USA  United States                       NaN           Not applicable
# 246202  USA  United States                       NaN           Not applicable
# 246207  USA  United States                       NaN           Not applicable
# 246212  USA  United States                       NaN           Not applicable
#
#        LARGE_SUBNATIONAL_REGION Large subnational region           MEAS  \
# 220477           OECD_US01_2021                  Alabama  THOUSAND_SQKM
# 220482           OECD_US01_2021                  Alabama  THOUSAND_SQKM
# 220487           OECD_US01_2021                  Alabama  THOUSAND_SQKM
# 220492           OECD_US01_2021                  Alabama  THOUSAND_SQKM
# 220497           OECD_US01_2021                  Alabama  THOUSAND_SQKM
# ...                         ...                      ...            ...
# 246192           OECD_US51_2021                 Virginia           PCNT
# 246197           OECD_US51_2021                 Virginia           PCNT
# 246202           OECD_US51_2021                 Virginia           PCNT
# 246207           OECD_US51_2021                 Virginia           PCNT
# 246212           OECD_US51_2021                 Virginia           PCNT
#
#                               Measure           VARIABLE     Land cover class  \
# 220477      Square kilometers (000's)             FOREST           Tree cover
# 220482      Square kilometers (000's)               GRSL            Grassland
# 220487      Square kilometers (000's)               WETL              Wetland
# 220492      Square kilometers (000's)             SHRUBL            Shrubland
# 220497      Square kilometers (000's)  SPARSE_VEGETATION    Sparse vegetation
# ...                               ...                ...                  ...
# 246192  Percent of total country area  SPARSE_VEGETATION    Sparse vegetation
# 246197  Percent of total country area              CROPL             Cropland
# 246202  Percent of total country area              URBAN  Artificial surfaces
# 246207  Percent of total country area               BARE            Bare area
# 246212  Percent of total country area              WATER         Inland water
#
#         ...  Year  Unit Code               Unit PowerCode Code  PowerCode  \
# 220477  ...  2019        KM2  Square kilometres              3  Thousands
# 220482  ...  2019        KM2  Square kilometres              3  Thousands
# 220487  ...  2019        KM2  Square kilometres              3  Thousands
# 220492  ...  2019        KM2  Square kilometres              3  Thousands
# 220497  ...  2019        KM2  Square kilometres              3  Thousands
# ...     ...   ...        ...                ...            ...        ...
# 246192  ...  2019         PC         Percentage              0      Units
# 246197  ...  2019         PC         Percentage              0      Units
# 246202  ...  2019         PC         Percentage              0      Units
# 246207  ...  2019         PC         Percentage              0      Units
# 246212  ...  2019         PC         Percentage              0      Units
#
#        Reference Period Code  Reference Period      Value  Flag Codes  Flags
# 220477                   NaN               NaN  87.106024         NaN    NaN
# 220482                   NaN               NaN  26.726430         NaN    NaN
# 220487                   NaN               NaN   0.237648         NaN    NaN
# 220492                   NaN               NaN   1.641589         NaN    NaN
# 220497                   NaN               NaN   0.046680         NaN    NaN
# ...                      ...               ...        ...         ...    ...
# 246192                   NaN               NaN   0.025975         NaN    NaN
# 246197                   NaN               NaN  10.927344         NaN    NaN
# 246202                   NaN               NaN   2.967337         NaN    NaN
# 246207                   NaN               NaN   0.195108         NaN    NaN
# 246212                   NaN               NaN   2.645142         NaN    NaN
#
# [918 rows x 21 columns]

# %%
#creating new DF with needed rows
usa_2019_data =usa_data[[
       'COU','Small subnational region','Large subnational region', 'Measure', 'VARIABLE',
       'Land cover class', 'Year', 'Unit Code', 'PowerCode', 'Value']]

usa_2019_data
# Out:
#         COU Small subnational region Large subnational region  \
# 220473  USA           Not applicable                  Alabama
# 220474  USA           Not applicable                  Alabama
# 220475  USA           Not applicable                  Alabama
# 220476  USA           Not applicable                  Alabama
# 220477  USA           Not applicable                  Alabama
# ...     ...                      ...                      ...
# 246208  USA           Not applicable                 Virginia
# 246209  USA           Not applicable                 Virginia
# 246210  USA           Not applicable                 Virginia
# 246211  USA           Not applicable                 Virginia
# 246212  USA           Not applicable                 Virginia
#
#                               Measure VARIABLE Land cover class  Year  \
# 220473      Square kilometers (000's)   FOREST       Tree cover  1992
# 220474      Square kilometers (000's)   FOREST       Tree cover  2004
# 220475      Square kilometers (000's)   FOREST       Tree cover  2015
# 220476      Square kilometers (000's)   FOREST       Tree cover  2018
# 220477      Square kilometers (000's)   FOREST       Tree cover  2019
# ...                               ...      ...              ...   ...
# 246208  Percent of total country area    WATER     Inland water  1992
# 246209  Percent of total country area    WATER     Inland water  2004
# 246210  Percent of total country area    WATER     Inland water  2015
# 246211  Percent of total country area    WATER     Inland water  2018
# 246212  Percent of total country area    WATER     Inland water  2019
#
#        Unit Code  PowerCode      Value
# 220473       KM2  Thousands  91.541198
# 220474       KM2  Thousands  91.354866
# 220475       KM2  Thousands  91.018603
# 220476       KM2  Thousands  89.994977
# 220477       KM2  Thousands  87.106024
# ...          ...        ...        ...
# 246208        PC      Units   2.588716
# 246209        PC      Units   2.629073
# 246210        PC      Units   2.644922
# 246211        PC      Units   2.645142
# 246212        PC      Units   2.645142
#
# [4590 rows x 10 columns]

# %%
# Checking missing values. 
usa_2019_data.isnull().sum()
# Out:
# COU                         0
# Small subnational region    0
# Large subnational region    0
# Measure                     0
# VARIABLE                    0
# Land cover class            0
# Year                        0
# Unit Code                   0
# PowerCode                   0
# Value                       0
# dtype: int64

# %%
# checking number of unique values per column
usa_2019_data.nunique()
# Out:
# COU                            1
# Small subnational region       1
# Large subnational region      51
# Measure                        2
# VARIABLE                       9
# Land cover class               9
# Year                           5
# Unit Code                      2
# PowerCode                      2
# Value                       4304
# dtype: int64
