# %% [markdown]
# This notebook covers the creation of CSVs that will be used to populate the meteorite database.
# The following tables will be created in the database:
#
# |table name|columns|data types|csv data file|
# |------|------|------|------|
# |meteorite_main|id|integer|meteorite_main.csv|
# ||name |VARCHAR(50)||
# ||recclass |VARCHAR(50)||
# ||mass_grams |float||
# ||fall |VARCHAR(10)||
# ||year |integer||
# ||reclat |float||
# ||reclong |float||
# ||geolocation |varchar(50)||
# ||geometry |varchar(50)||
# ||elevation |float||
# ||country |varchar(50)||
# ||state_abbrev |varchar(10)||
# |state|state_abbrev |varchar(10)|state.csv|
# ||state |VARCHAR(50)||
# ||FIPS|integer||
# ||area_sqkm |integer||
# ||country |varchar(50)||
# |landcover|id |Serial|landcover.csv|
# ||state_abbrev varchar(10)||
# ||variable varchar(50)||
# ||value float||
# |meteorite_type|recclass |VARCHAR(50)|meteorite_type.csv|
# ||meteorite_class_subclass |VARCHAR(50)||
# ||meteorite_class |VARCHAR(50)||
# ||meteorite_type |VARCHAR(50)||

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
import geopy
from geopy.geocoders import Nominatim
from pathlib import Path
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.datasets import make_classification
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# %% [markdown]
# * Pull in clean datasets for meteorites, land cover, meteorite types, state FIPS and area
# * create tables that mimic db tables
# * save as csv

# %% [markdown]
# ## meteorite_type table
#
# db table:
#
# CREATE TABLE meteorite_type (
# 	recclass VARCHAR(50),
#   	meteorite_class_subclass VARCHAR(50),
# 	meteorite_class VARCHAR(50),
#   	meteorite_type VARCHAR(50),
#   	PRIMARY KEY (recclass)
# );

# %%
# pull in meteorite_types csv sourced from (ADD WEBSITES HERE)
meteorite_type = pd.read_csv('Resources/Raw_Data/meteorite_types.csv')
print(meteorite_type.dtypes)
meteorite_type.head()
# Out:
# recclass                    object
# meteorite_class_subclass    object
# meteorite_class             object
# meteorite_type              object
# dtype: object
#           recclass meteorite_class_subclass meteorite_class meteorite_type
# 0               H5    Chrondrite - ordinary      Chrondrite     Chrondrite
# 1               L6    Chrondrite - ordinary      Chrondrite     Chrondrite
# 2               L5    Chrondrite - ordinary      Chrondrite     Chrondrite
# 3  Iron, ungrouped             Iron - other            Iron           Iron
# 4        Iron, IVA          Iron - magmatic            Iron           Iron

# %% [markdown]
# * meteorite_type table schema and csv are compatible
# * Use meteorite_types.csv to populate meteorite_type db table.

# %%
# # write meteorite_type to csv- csv already created, commented out so it doesn't get overwritten. Uncomment if needed.
# meteorite_type.to_csv('Resources/DB_CSV/meteorite_types.csv', index = False)

# %%
# # check meteorite_type.csv- csv already created, commented out so it doesn't get overwritten. Uncomment if needed.
# meteorite_type_check = pd.read_csv('Resources/DB_CSV/meteorite_types.csv')
# print(len(meteorite_type_check))
# print(meteorite_type_check.dtypes)
# meteorite_type_check.head()

# %% [markdown]
# ## state table
#
# db table:
#
# CREATE TABLE state (
# 	state_abbrev varchar(10),
# 	state VARCHAR(50),
#   	area_sqkm integer,
# 	FIPS integer,
# 	country varchar(50),
#   	PRIMARY KEY (state_abbrev)
# );

# %%
# pull in state FIPS csv sourced from (ADD WEBSITES HERE)
state_fips = pd.read_csv('Resources/Raw_Data/state_fips.csv')
print(len(state_fips))
print(state_fips.dtypes)
state_fips.head()
# Out:
# 53
# state           object
# state_abbrev    object
# FIPS             int64
# dtype: object
#         state state_abbrev  FIPS
# 0     Alabama           AL     1
# 1      Alaska           AK     2
# 2     Arizona           AZ     4
# 3    Arkansas           AR     5
# 4  California           CA     6

# %%
# pull in state sqkm csv sourced from (ADD WEBSITES HERE)
state_sqkm = pd.read_csv('Resources/Raw_Data/state_sqkm.csv')
print(len(state_sqkm))
print(state_sqkm.dtypes)
state_sqkm.head()
# Out:
# 57
# state        object
# area_sqkm     int64
# dtype: object
#         state  area_sqkm
# 0     Alabama     135767
# 1      Alaska    1723337
# 2     Arizona     295234
# 3    Arkansas     137732
# 4  California     423967

# %%
# merge state_fips and state_sqkm to create state df
state2 = pd.merge(state_fips,state_sqkm)
state = state2[['state_abbrev','state','FIPS','area_sqkm']]
state['country'] = 'United States'
print(len(state))
print(state.dtypes)
state.head()
# Out:
# 52
# state_abbrev    object
# state           object
# FIPS             int64
# area_sqkm        int64
# country         object
# dtype: object
# c:\Users\chris\anaconda3\envs\PythonDataOne\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
#   state_abbrev       state  FIPS  area_sqkm        country
# 0           AL     Alabama     1     135767  United States
# 1           AK      Alaska     2    1723337  United States
# 2           AZ     Arizona     4     295234  United States
# 3           AR    Arkansas     5     137732  United States
# 4           CA  California     6     423967  United States

# %%
# # write state to csv- csv already created, commented out so it doesn't get overwritten. Uncomment if needed.
# state.to_csv('Resources/DB_CSV/state.csv', index = False)

# %%
# # check state.csv- csv already created, commented out so it doesn't get overwritten. Uncomment if needed.
# state_check = pd.read_csv('Resources/DB_CSV/state.csv')
# print(len(state_check))
# print(state_check.dtypes)
# state_check.head()

# %% [markdown]
# * State table schema and csv are compatible
# * Use state.csv to populate state db table.

# %% [markdown]
# ## state_FIPS_char table  - contains FIPS column as character
#
# db table:
#
# CREATE TABLE state (
# 	state_abbrev varchar(10),
# 	state VARCHAR(50),
#   	area_sqkm integer,
#     FIPS varchar(10),
# 	country varchar(50),
#   	PRIMARY KEY (state_abbrev)
# );

# %%
# pull in state_fips_char FIPS csv sourced from (ADD WEBSITES HERE)
state_fips_char = pd.read_csv('Resources/Raw_Data/state_fips_char.csv')
print(len(state_fips_char))
print(state_fips_char.dtypes)
state_fips_char.head()
# Out:
# 53
# state           object
# state_abbrev    object
# FIPS             int64
# FIPS_char        int64
# dtype: object
#         state state_abbrev  FIPS  FIPS_char
# 0     Alabama           AL     1          1
# 1      Alaska           AK     2          2
# 2     Arizona           AZ     4          4
# 3    Arkansas           AR     5          5
# 4  California           CA     6          6

# %%
# pull in state sqkm csv sourced from (ADD WEBSITES HERE)
state_sqkm = pd.read_csv('Resources/Raw_Data/state_sqkm.csv')
print(len(state_sqkm))
print(state_sqkm.dtypes)
state_sqkm.head()
# Out:
# 57
# state        object
# area_sqkm     int64
# dtype: object
#         state  area_sqkm
# 0     Alabama     135767
# 1      Alaska    1723337
# 2     Arizona     295234
# 3    Arkansas     137732
# 4  California     423967

# %%
# merge state_fips_char and state_sqkm to create state df
state_fips_char_2 = pd.merge(state_fips_char,state_sqkm)
state_fips_char_3 = state_fips_char_2[['state_abbrev','state','FIPS','area_sqkm']]
state_fips_char_3['country'] = 'United States'
state_fips_char_3['FIPS']= state_fips_char_3['FIPS'].astype(str)
state_fips_char_3.replace({'1':'01','2':'02','4':'04','5':'05','6':'06','8':'08','9':'09'}, inplace = True)
print(len(state_fips_char_3))
print(state_fips_char_3.dtypes)
state_fips_char_3.head(10)
# Out:
# 52
# state_abbrev    object
# state           object
# FIPS            object
# area_sqkm        int64
# country         object
# dtype: object
#   state_abbrev                 state FIPS  area_sqkm        country
# 0           AL               Alabama   01     135767  United States
# 1           AK                Alaska   02    1723337  United States
# 2           AZ               Arizona   04     295234  United States
# 3           AR              Arkansas   05     137732  United States
# 4           CA            California   06     423967  United States
# 5           CO              Colorado   08     269601  United States
# 6           CT           Connecticut   09      14357  United States
# 7           DE              Delaware   10       6446  United States
# 8           DC  District of Columbia   11        177  United States
# 9           FL               Florida   12     170312  United States

# %%
# write state_fips_char_3 to csv- csv already created, commented out so it doesn't get overwritten. Uncomment if needed.
state_fips_char_3.to_csv('Resources/DB_CSV/state_FIPS_char.csv', index = False)

# %%
# check state_fips_char_check.csv- csv already created, commented out so it doesn't get overwritten. Uncomment if needed.
state_fips_char_check = pd.read_csv('Resources/DB_CSV/state_FIPS_char.csv')
print(len(state_fips_char_check))
print(state_fips_char_check.dtypes)
state_fips_char_check.head()
# Out:
# 52
# state_abbrev    object
# state           object
# FIPS             int64
# area_sqkm        int64
# country         object
# dtype: object
#   state_abbrev       state  FIPS  area_sqkm        country
# 0           AL     Alabama     1     135767  United States
# 1           AK      Alaska     2    1723337  United States
# 2           AZ     Arizona     4     295234  United States
# 3           AR    Arkansas     5     137732  United States
# 4           CA  California     6     423967  United States

# %% [markdown]
# State_fips_char
# * state_fips_char table schema and csv are compatible
# * csv file contains FIPS with leading zeroes

# %% [markdown]
# ## landcover table
#
# db table:
#
# CREATE TABLE landcover (
# 	id Serial,
# 	state_abbrev varchar(10),
#   	variable varchar(50),
#   	value float,
#   	PRIMARY KEY (id)
# );

# %%
# pull in landcover info here - Greg sourced from (website here)
landcover2 = pd.read_csv('Resources/Raw_Data/LAND_COVER_14032023014858227.csv')
landcover2.head()
# Out:
#    COU    Country  SMALL_SUBNATIONAL_REGION Small subnational region  \
# 0  AUS  Australia                       NaN           Not applicable
# 1  AUS  Australia                       NaN           Not applicable
# 2  AUS  Australia                       NaN           Not applicable
# 3  AUS  Australia                       NaN           Not applicable
# 4  AUS  Australia                       NaN           Not applicable
#
#   LARGE_SUBNATIONAL_REGION           Large subnational region           MEAS  \
# 0           GAUL1_467_2015  Administrative unit not available  THOUSAND_SQKM
# 1           GAUL1_467_2015  Administrative unit not available  THOUSAND_SQKM
# 2           GAUL1_467_2015  Administrative unit not available  THOUSAND_SQKM
# 3           GAUL1_467_2015  Administrative unit not available  THOUSAND_SQKM
# 4           GAUL1_467_2015  Administrative unit not available  THOUSAND_SQKM
#
#                      Measure VARIABLE Land cover class  ...  Year  Unit Code  \
# 0  Square kilometers (000's)    CROPL         Cropland  ...  1992        KM2
# 1  Square kilometers (000's)    CROPL         Cropland  ...  2004        KM2
# 2  Square kilometers (000's)    CROPL         Cropland  ...  2015        KM2
# 3  Square kilometers (000's)    CROPL         Cropland  ...  2018        KM2
# 4  Square kilometers (000's)    CROPL         Cropland  ...  2019        KM2
#
#                 Unit PowerCode Code  PowerCode Reference Period Code  \
# 0  Square kilometres              3  Thousands                   NaN
# 1  Square kilometres              3  Thousands                   NaN
# 2  Square kilometres              3  Thousands                   NaN
# 3  Square kilometres              3  Thousands                   NaN
# 4  Square kilometres              3  Thousands                   NaN
#
#    Reference Period  Value  Flag Codes  Flags
# 0               NaN    0.0         NaN    NaN
# 1               NaN    0.0         NaN    NaN
# 2               NaN    0.0         NaN    NaN
# 3               NaN    0.0         NaN    NaN
# 4               NaN    0.0         NaN    NaN
#
# [5 rows x 21 columns]

# %%
# Filtering to USA, year 2019 - Greg, rename and replace - Chris
landcover_US_2019 = landcover2.loc[(landcover2['COU'] == 'USA') & (landcover2['Year'] == 2019)].copy()
landcover_US_2019.rename({'Large subnational region':'state'},axis=1, inplace = True)
landcover_US_2019.rename({'VARIABLE':'variable'},axis=1, inplace = True)
landcover_US_2019.rename({'Value':'value'},axis=1, inplace = True)
landcover_US_2019.replace({'District Of Columbia':'District of Columbia'}, inplace = True)
print(len(landcover_US_2019))
print(type(landcover_US_2019))
landcover_US_2019.head(2)
# Out:
# 918
# <class 'pandas.core.frame.DataFrame'>
#         COU        Country  SMALL_SUBNATIONAL_REGION Small subnational region  \
# 220477  USA  United States                       NaN           Not applicable
# 220482  USA  United States                       NaN           Not applicable
#
#        LARGE_SUBNATIONAL_REGION    state           MEAS  \
# 220477           OECD_US01_2021  Alabama  THOUSAND_SQKM
# 220482           OECD_US01_2021  Alabama  THOUSAND_SQKM
#
#                           Measure variable Land cover class  ...  Year  \
# 220477  Square kilometers (000's)   FOREST       Tree cover  ...  2019
# 220482  Square kilometers (000's)     GRSL        Grassland  ...  2019
#
#         Unit Code               Unit PowerCode Code  PowerCode  \
# 220477        KM2  Square kilometres              3  Thousands
# 220482        KM2  Square kilometres              3  Thousands
#
#        Reference Period Code  Reference Period      value  Flag Codes  Flags
# 220477                   NaN               NaN  87.106024         NaN    NaN
# 220482                   NaN               NaN  26.726430         NaN    NaN
#
# [2 rows x 21 columns]

# %%
# bring in state abbreviation by joining to state_fips
landcover_US_2019_2 = pd.merge(landcover_US_2019,state_fips)
print(len(landcover_US_2019_2))
print(type(landcover_US_2019_2))
landcover_US_2019_2.head(2)
# Out:
# 918
# <class 'pandas.core.frame.DataFrame'>
#    COU        Country  SMALL_SUBNATIONAL_REGION Small subnational region  \
# 0  USA  United States                       NaN           Not applicable
# 1  USA  United States                       NaN           Not applicable
#
#   LARGE_SUBNATIONAL_REGION    state           MEAS                    Measure  \
# 0           OECD_US01_2021  Alabama  THOUSAND_SQKM  Square kilometers (000's)
# 1           OECD_US01_2021  Alabama  THOUSAND_SQKM  Square kilometers (000's)
#
#   variable Land cover class  ...               Unit  PowerCode Code  \
# 0   FOREST       Tree cover  ...  Square kilometres               3
# 1     GRSL        Grassland  ...  Square kilometres               3
#
#    PowerCode Reference Period Code  Reference Period      value  Flag Codes  \
# 0  Thousands                   NaN               NaN  87.106024         NaN
# 1  Thousands                   NaN               NaN  26.726430         NaN
#
#    Flags  state_abbrev  FIPS
# 0    NaN            AL     1
# 1    NaN            AL     1
#
# [2 rows x 23 columns]

# %%
# for Chris evaluation - reduce land cover fips area dataset to measurements by percent (rather than by square kilometers)
landcover_US_2019_3 = landcover_US_2019_2.loc[landcover_US_2019_2['MEAS'] == 'PCNT'] 
print(len(landcover_US_2019_3))
landcover_US_2019_3.head(2)
# Out:
# 459
#     COU        Country  SMALL_SUBNATIONAL_REGION Small subnational region  \
# 9   USA  United States                       NaN           Not applicable
# 10  USA  United States                       NaN           Not applicable
#
#    LARGE_SUBNATIONAL_REGION    state  MEAS                        Measure  \
# 9            OECD_US01_2021  Alabama  PCNT  Percent of total country area
# 10           OECD_US01_2021  Alabama  PCNT  Percent of total country area
#
#    variable Land cover class  ...        Unit  PowerCode Code PowerCode  \
# 9    FOREST       Tree cover  ...  Percentage               0     Units
# 10     GRSL        Grassland  ...  Percentage               0     Units
#
#    Reference Period Code  Reference Period      value  Flag Codes  Flags  \
# 9                    NaN               NaN  64.872148         NaN    NaN
# 10                   NaN               NaN  19.904490         NaN    NaN
#
#     state_abbrev  FIPS
# 9             AL     1
# 10            AL     1
#
# [2 rows x 23 columns]

# %%
#  create landcover table
landcover = landcover_US_2019_3[['state_abbrev','variable','value']]
print(len(landcover))
print(type(landcover))
landcover.head(2)
# Out:
# 459
# <class 'pandas.core.frame.DataFrame'>
#    state_abbrev variable      value
# 9            AL   FOREST  64.872148
# 10           AL     GRSL  19.904490

# %%
# write landcover to csv  - csv already created, commented out so it doesn't get overwritten. Uncomment if needed.
landcover.to_csv('Resources/DB_CSV/landcover.csv', index = False)

# %%
# check landcover.csv - csv already created, commented out so it doesn't get overwritten. Uncomment if needed.
landcover_check = pd.read_csv('Resources/DB_CSV/landcover.csv')
print(len(landcover_check))
print(landcover_check.dtypes)
landcover_check
# Out:
# 459
# state_abbrev     object
# variable         object
# value           float64
# dtype: object
#     state_abbrev           variable      value
# 0             AL             FOREST  64.872148
# 1             AL               GRSL  19.904490
# 2             AL               WETL   0.176988
# 3             AL             SHRUBL   1.222573
# 4             AL  SPARSE_VEGETATION   0.034765
# ..           ...                ...        ...
# 454           VA  SPARSE_VEGETATION   0.025975
# 455           VA              CROPL  10.927344
# 456           VA              URBAN   2.967337
# 457           VA               BARE   0.195108
# 458           VA              WATER   2.645142
#
# [459 rows x 3 columns]

# %% [markdown]
# * Landcover table schema and csv are compatible
# * Use landcover.csv to populate landcover db table

# %% [markdown]
# ## meteorite_main table
#
# db table:
#
# CREATE TABLE meteorite_main (
#   	id integer,
#   	name VARCHAR(50),
#  	recclass VARCHAR(50),
#   	mass_grams float,
# 	fall VARCHAR(10),
#   	year DATE,
# 	reclat float,
# 	reclong float,
# 	geolocation varchar(50),
# 	geometry varchar(50),
# 	elevation float,
# 	country varchar(50),
# 	state_abbrev varchar(10),
#   	PRIMARY KEY (id)
# );

# %%
# pull in meteorite found fell info here - Madina sourced from (website here) and cleaned to create Meteorite_Landings_clean.csv
meteorite10 = pd.read_csv('Resources/Raw_Data/Meteorite_Landings_clean.csv')
print(len(meteorite10))
print(meteorite10.dtypes)
meteorite10.head()
# Out:
# 38114
# Unnamed: 0       int64
# name            object
# id               int64
# nametype        object
# recclass        object
# mass (g)       float64
# fall            object
# year             int64
# reclat         float64
# reclong        float64
# GeoLocation     object
# geometry        object
# dtype: object
#    Unnamed: 0      name   id nametype     recclass  mass (g)  fall  year  \
# 0           0    Aachen    1    Valid           L5      21.0  Fell  1880
# 1           1    Aarhus    2    Valid           H6     720.0  Fell  1951
# 2           2      Abee    6    Valid          EH4  107000.0  Fell  1952
# 3           3  Acapulco   10    Valid  Acapulcoite    1914.0  Fell  1976
# 4           4   Achiras  370    Valid           L6     780.0  Fell  1902
#
#      reclat    reclong           GeoLocation                   geometry
# 0  50.77500    6.08333     (50.775, 6.08333)     POINT (6.08333 50.775)
# 1  56.18333   10.23333  (56.18333, 10.23333)  POINT (10.23333 56.18333)
# 2  54.21667 -113.00000    (54.21667, -113.0)      POINT (-113 54.21667)
# 3  16.88333  -99.90000     (16.88333, -99.9)     POINT (-99.9 16.88333)
# 4 -33.16667  -64.95000   (-33.16667, -64.95)   POINT (-64.95 -33.16667)

# %%
# add columns to meteorite10 df, drop unnamed col, rename cols
meteorite10['state_abbrev'] = 'None_Found'
meteorite10['state'] = 'None_Found'
meteorite10['county'] = 'None_Found'
meteorite10['country'] = 'None_Found'
meteorite10['elevation'] = 0.0
meteorite10.drop(['Unnamed: 0'], axis = 1, inplace = True)
meteorite10.rename({'mass (g)':'mass_grams',"GeoLocation":'geolocation'}, axis = 1, inplace = True)
meteorite10.head(2)
# Out:
#      name  id nametype recclass  mass_grams  fall  year    reclat   reclong  \
# 0  Aachen   1    Valid       L5        21.0  Fell  1880  50.77500   6.08333
# 1  Aarhus   2    Valid       H6       720.0  Fell  1951  56.18333  10.23333
#
#             geolocation                   geometry state_abbrev       state  \
# 0     (50.775, 6.08333)     POINT (6.08333 50.775)   None_Found  None_Found
# 1  (56.18333, 10.23333)  POINT (10.23333 56.18333)   None_Found  None_Found
#
#        county     country  elevation
# 0  None_Found  None_Found        0.0
# 1  None_Found  None_Found        0.0

# %%
# reduce table size to approximate us lat/long
meteorite9 = meteorite10.loc[(meteorite10['reclat']>18)&(meteorite10['reclat']<72)&(meteorite10['reclong']>-170)&(meteorite10['reclong']<-67)].copy()
print(len(meteorite9))
print(meteorite9.dtypes)
meteorite9.head(2)
# Out:
# 1799
# name             object
# id                int64
# nametype         object
# recclass         object
# mass_grams      float64
# fall             object
# year              int64
# reclat          float64
# reclong         float64
# geolocation      object
# geometry         object
# state_abbrev     object
# state            object
# county           object
# country          object
# elevation       float64
# dtype: object
#        name    id nametype recclass  mass_grams  fall  year    reclat  \
# 2      Abee     6    Valid      EH4    107000.0  Fell  1952  54.21667
# 27  Allegan  2276    Valid       H5     32000.0  Fell  1899  42.53333
#
#       reclong            geolocation                    geometry state_abbrev  \
# 2  -113.00000     (54.21667, -113.0)       POINT (-113 54.21667)   None_Found
# 27  -85.88333  (42.53333, -85.88333)  POINT (-85.88333 42.53333)   None_Found
#
#          state      county     country  elevation
# 2   None_Found  None_Found  None_Found        0.0
# 27  None_Found  None_Found  None_Found        0.0

# %%
# check lat longs on map - includes alaska, hawaii but also has canada and central american locations
# Create a scatter map using the 'reclat' and 'reclong' columns of the dataframe as latitude and longitude, respectively
fig = px.scatter_mapbox(meteorite9, lat="reclat", lon="reclong")

# customize the layout of the Map
fig.update_layout(
    mapbox_style="open-street-map",
    mapbox=dict(center=dict(lat=0, lon=0), zoom=0),
    margin=dict(l=0, r=0, t=0, b=0),
    width=600, height=600
)

# Display the map
fig.show()

# %%
# get state/county info
# https://geopy.readthedocs.io/en/stable/
# https://www.geeksforgeeks.org/get-the-city-state-and-country-names-from-latitude-and-longitude-using-python/

#  initialize Nominatim API
geolocator = Nominatim(user_agent="geoapiExercises")

for index, row in meteorite9.iterrows():
    # get latitude, longitude from the DataFrame

    rowlat = str(row['reclat'])
    rowlon = str(row['reclong'])
    rowloc = geolocator.reverse(rowlat+","+rowlon)
    rowaddress = rowloc.raw['address']
    rowstate = rowaddress.get('state','')
    rowcounty = rowaddress.get('county','')
    rowcountry = rowaddress.get('country','')

    
    try:
        meteorite9.loc[index, "county"] = rowcounty
        meteorite9.loc[index, "state"] = rowstate
        meteorite9.loc[index, "country"] = rowcountry
    except (KeyError, IndexError):
        # If no county is found, set the county as no county found".
        meteorite9.loc[index, "county"] = "None_Found"
        meteorite9.loc[index, "state"] = "None_Found"
        meteorite9.loc[index, "country"] = "None_Found"

# %%
# write landcover to csv  - interim csvs available for troubleshooting, uncomment if needed.
meteorite9.to_csv('Resources/Raw_Data/meteorite9_interim.csv', index = False)

# %% [markdown]
# ##### Max retries exceeded - revert to reading info from previously created csv "meteorite9_interim.csv"

# %%
meteorite9 = pd.read_csv('Resources/Raw_Data/meteorite9_interim.csv')

# %%
print(len(meteorite9))
print(meteorite9.dtypes)
meteorite9.head(2)
# Out:
# 1799
# name             object
# id                int64
# nametype         object
# recclass         object
# mass_grams      float64
# fall             object
# year              int64
# reclat          float64
# reclong         float64
# geolocation      object
# geometry         object
# state_abbrev     object
# state            object
# county           object
# country          object
# elevation       float64
# dtype: object
#       name    id nametype recclass  mass_grams  fall  year    reclat  \
# 0     Abee     6    Valid      EH4    107000.0  Fell  1952  54.21667
# 1  Allegan  2276    Valid       H5     32000.0  Fell  1899  42.53333
#
#      reclong            geolocation                    geometry state_abbrev  \
# 0 -113.00000     (54.21667, -113.0)       POINT (-113 54.21667)   None_Found
# 1  -85.88333  (42.53333, -85.88333)  POINT (-85.88333 42.53333)   None_Found
#
#       state           county        country  elevation
# 0   Alberta  Thorhild County         Canada        0.0
# 1  Michigan   Allegan County  United States        0.0

# %%
# bring in state abbreviation by joining to state_fips
meteorite8 = pd.merge(meteorite9,state_fips, on = 'state')
print(len(meteorite8))
print(type(meteorite8))
meteorite8.head(2)
# Out:
# 1650
# <class 'pandas.core.frame.DataFrame'>
#       name    id nametype recclass  mass_grams  fall  year    reclat  \
# 0  Allegan  2276    Valid       H5     32000.0  Fell  1899  42.53333
# 1  Coleman  5401    Valid       L6       469.0  Fell  1994  43.76111
#
#     reclong            geolocation                    geometry state_abbrev_x  \
# 0 -85.88333  (42.53333, -85.88333)  POINT (-85.88333 42.53333)     None_Found
# 1 -84.50778  (43.76111, -84.50778)  POINT (-84.50778 43.76111)     None_Found
#
#       state          county        country  elevation state_abbrev_y  FIPS
# 0  Michigan  Allegan County  United States        0.0             MI    26
# 1  Michigan  Midland County  United States        0.0             MI    26

# %%
# meteorite8 only contains US values after merging with state_fips
meteorite8['country'].value_counts()
# Out:
# United States    1650
# Name: country, dtype: int64

# %%
# Create a scatter map using the 'reclat' and 'reclong' columns of the dataframe as latitude and longitude, respectively
fig = px.scatter_mapbox(meteorite8, lat="reclat", lon="reclong")

# customize the layout of the Map
fig.update_layout(
    mapbox_style="open-street-map",
    mapbox=dict(center=dict(lat=0, lon=0), zoom=0),
    margin=dict(l=0, r=0, t=0, b=0),
    width=600, height=600
)

# Display the map
fig.show()

# %%
# get list of latitudes
qlats = meteorite8['reclat'].to_list()
print(type(qlats))
qlats
# Out:
# <class 'list'>
# [42.53333,
#  43.76111,
#  44.51667,
#  42.38467,
#  42.96667,
#  46.07944000000001,
#  44.64694,
#  43.86667,
#  41.78333,
#  44.61667,
#  44.38333,
#  44.08333,
#  44.36667,
#  43.827,
#  38.5,
#  36.75,
#  37.26667,
#  39.08333,
#  37.91667,
#  39.8,
#  38.7,
#  38.68333,
#  37.06667,
#  38.3,
#  40.266667,
#  39.59167,
#  39.61667,
#  38.65,
#  36.82444,
#  36.53333,
#  40.2875,
#  36.55,
#  37.73333,
#  37.2375,
#  37.75,
#  37.96667,
#  31.805,
#  33.6,
#  31.83333,
#  30.83333,
#  32.675,
#  29.45,
#  30.75,
#  31.60833,
#  30.125,
#  30.7,
#  31.25,
#  32.16667,
#  33.85,
#  32.59033,
#  35.15,
#  34.2,
#  33.1,
#  33.1,
#  33.7825,
#  32.9,
#  31.66,
#  31.76667,
#  30.78333,
#  30.83333,
#  34.0,
#  33.58333,
#  33.59167,
#  29.87861,
#  29.86306,
#  29.8,
#  31.05,
#  34.35,
#  33.28333,
#  33.275,
#  33.275,
#  33.21667,
#  33.21667,
#  33.135,
#  33.21667,
#  32.246109999999994,
#  32.03333,
#  28.41667,
#  34.96667,
#  31.91667,
#  29.82806,
#  34.2,
#  36.2,
#  35.71667,
#  29.0,
#  34.02806,
#  34.905,
#  34.93611,
#  34.34667,
#  34.34833,
#  32.31667,
#  32.01667,
#  31.991670000000006,
#  32.0,
#  31.75,
#  29.01667,
#  36.04333,
#  30.75,
#  29.1,
#  29.00833,
#  34.86,
#  34.86,
#  29.366670000000006,
#  33.0,
#  33.07139,
#  33.51667,
#  33.51667,
#  33.81667,
#  34.58333,
#  34.48333,
#  33.97917,
#  35.9,
#  35.925,
#  33.81667,
#  32.63333,
#  34.28333,
#  34.28333,
#  31.78333,
#  33.71667,
#  33.9,
#  35.98333,
#  34.47,
#  34.10139,
#  34.0,
#  31.38972,
#  34.26667,
#  34.29833,
#  34.43333,
#  32.5225,
#  33.98333,
#  33.98333,
#  32.8,
#  32.90333,
#  33.50667,
#  33.49556,
#  30.91667,
#  33.1,
#  32.33333,
#  34.54,
#  32.7,
#  32.83333,
#  32.25,
#  33.18139,
#  32.788333,
#  33.11667,
#  33.71667,
#  36.33333,
#  29.5,
#  34.05,
#  34.05,
#  31.59333,
#  35.68,
#  34.59333,
#  34.58333,
#  34.80167,
#  34.37718,
#  33.99833,
#  35.94167,
#  33.21333,
#  33.795,
#  33.75,
#  33.5,
#  34.54,
#  31.91667,
#  31.91667,
#  31.96667,
#  30.625,
#  30.5,
#  34.62333,
#  34.67167,
#  34.67167,
#  34.67167,
#  32.58333,
#  29.4,
#  30.41667,
#  34.35833,
#  34.35833,
#  34.33833,
#  34.38333,
#  29.975,
#  26.27167,
#  35.56667,
#  34.53333,
#  32.88333,
#  34.5,
#  30.6,
#  34.61139,
#  34.655,
#  34.655,
#  30.52213,
#  34.15,
#  34.25972,
#  32.9,
#  32.99167,
#  32.98333,
#  33.28944,
#  33.6,
#  32.83611,
#  31.5,
#  33.75,
#  32.925,
#  32.925,
#  33.18333,
#  35.23333,
#  33.33139,
#  33.33139,
#  31.42611,
#  31.26667,
#  35.66667,
#  31.48333,
#  32.50333,
#  33.71667,
#  35.63333,
#  34.12167,
#  28.95,
#  30.95,
#  30.95,
#  34.5,
#  34.5,
#  34.58333,
#  34.58333,
#  34.58333,
#  34.52667,
#  34.04472,
#  33.721,
#  33.17,
#  33.11667,
#  33.11833,
#  28.866670000000006,
#  27.5,
#  31.71667,
#  32.91217,
#  34.16722,
#  30.73333,
#  34.9,
#  35.33333,
#  32.5,
#  32.0,
#  30.33333,
#  33.73,
#  36.35333,
#  29.68333,
#  33.28333,
#  33.26667,
#  34.11667,
#  34.11667,
#  34.125,
#  34.1875,
#  34.18513,
#  31.66333,
#  33.11667,
#  29.5,
#  32.0,
#  33.53333,
#  31.9,
#  34.42222,
#  35.76667,
#  30.81667,
#  30.05806,
#  30.06667,
#  32.865829999999995,
#  31.41667,
#  29.5,
#  30.13333,
#  32.5,
#  32.93333,
#  32.91722,
#  32.98333,
#  32.68333,
#  32.54333,
#  32.55,
#  32.71667,
#  32.71667,
#  32.70038,
#  32.71667,
#  32.71667,
#  32.71667,
#  34.26889,
#  32.4,
#  33.7,
#  34.53333,
#  33.43333,
#  33.11861,
#  33.58333,
#  32.71667,
#  32.18333,
#  34.26667,
#  34.00111,
#  36.25,
#  34.34444000000001,
#  31.73333,
#  34.21,
#  29.30167,
#  32.98333,
#  34.76667,
#  36.0,
#  32.55,
#  31.866670000000006,
#  34.38333,
#  31.116670000000006,
#  36.4,
#  34.93333,
#  34.98333,
#  33.21667,
#  33.205,
#  30.3,
#  30.55556,
#  34.66667,
#  34.61667,
#  34.53333,
#  34.60667,
#  34.555,
#  34.95,
#  29.2,
#  32.4,
#  34.68333,
#  36.15,
#  32.4,
#  32.90333,
#  34.80167,
#  34.95,
#  33.03333,
#  33.025,
#  33.03333,
#  33.01667,
#  33.678329999999995,
#  33.05,
#  33.075,
#  34.06667,
#  29.96667,
#  28.95,
#  31.65,
#  34.75,
#  34.4,
#  32.53333,
#  34.48333,
#  34.58333,
#  33.18836,
#  32.63333,
#  32.0,
#  33.5,
#  33.96667,
#  34.68333,
#  31.55,
#  32.4,
#  34.2,
#  32.23333,
#  34.0,
#  32.68333,
#  34.31667,
#  36.83333,
#  35.95,
#  35.88333,
#  36.00833,
#  34.33333,
#  35.16667,
#  36.8,
#  35.33333,
#  35.0,
#  35.16667,
#  35.84778,
#  36.43333,
#  35.35,
#  35.405,
#  35.96667,
#  36.81667,
#  36.55,
#  36.58333,
#  36.57,
#  36.56,
#  36.71667,
#  36.28402,
#  35.83333,
#  36.9,
#  36.38333,
#  34.1,
#  36.58333,
#  34.849000000000004,
#  34.6,
#  36.98667,
#  34.86667,
#  34.03333,
#  36.34611,
#  34.25,
#  35.833333,
#  35.5,
#  36.73333,
#  36.5,
#  35.0,
#  36.8,
#  32.21667,
#  36.21667,
#  34.175,
#  36.3,
#  33.63333,
#  35.05,
#  32.9,
#  32.306,
#  32.00584,
#  34.15,
#  36.33333,
#  36.21667,
#  34.23333,
#  34.24667,
#  34.20583,
#  35.26667,
#  33.65167,
#  36.5,
#  36.0,
#  34.3,
#  34.3,
#  31.82967,
#  34.95,
#  36.83333,
#  34.08333,
#  34.09,
#  34.05,
#  34.05,
#  32.22548,
#  33.92667,
#  33.92333,
#  33.5,
#  33.78333,
#  33.91667,
#  33.79,
#  33.84333,
#  36.33333,
#  34.19333,
#  37.0,
#  33.86333,
#  36.3,
#  35.6,
#  34.8,
#  34.8,
#  34.8,
#  35.16667,
#  34.38167,
#  34.26667,
#  34.0,
#  32.73333,
#  32.73333,
#  33.9,
#  33.70833,
#  32.9,
#  34.46667,
#  34.45,
#  33.00383,
#  32.62972,
#  32.03333,
#  32.03333,
#  32.04333,
#  34.00833,
#  34.8125,
#  34.0,
#  34.21667,
#  34.38333,
#  34.39833,
#  36.23,
#  33.63333,
#  34.98333,
#  35.75,
#  34.5,
#  36.29533,
#  34.22833,
#  32.37167,
#  33.63333,
#  35.16667,
#  36.5,
#  33.66667,
#  33.2,
#  32.66667,
#  36.5,
#  36.5,
#  34.06667,
#  34.06667,
#  34.1,
#  34.4,
#  34.76778,
#  34.78333,
#  35.3,
#  34.08333,
#  34.08333,
#  34.08333,
#  34.065,
#  33.78333,
#  33.71667,
#  33.88333,
#  34.08333,
#  34.21667,
#  34.08333,
#  33.08333,
#  33.75,
#  34.1,
#  34.1,
#  34.1,
#  34.1,
#  34.1,
#  34.21667,
#  34.31667,
#  34.11667,
#  34.13333,
#  33.81806,
#  34.21667,
#  34.18333,
#  34.08333,
#  34.08333,
#  34.15,
#  33.8,
#  34.08333,
#  34.08333,
#  34.28333,
#  33.78333,
#  34.08333,
#  34.08333,
#  34.08333,
#  34.08333,
#  34.08333,
#  34.08333,
#  34.3,
#  34.08333,
#  34.08333,
#  34.08333,
#  34.08333,
#  34.08333,
#  34.25,
#  34.23333,
#  34.1,
#  34.13333,
#  33.61667,
#  34.08333,
#  34.08333,
#  34.21667,
#  34.1,
#  33.88333,
#  34.3,
#  34.3,
#  34.41667,
#  34.21667,
#  34.08333,
#  34.08333,
#  34.08333,
#  34.08333,
#  34.21667,
#  34.08333,
#  34.08333,
#  33.61667,
#  34.1,
#  34.1,
#  34.1,
#  34.1,
#  34.1,
#  34.1,
#  34.1,
#  34.08333,
#  34.08333,
#  34.18333,
#  34.08333,
#  34.08333,
#  34.08333,
#  34.1,
#  34.05,
#  33.63333,
#  34.08333,
#  33.66667,
#  34.2,
#  34.31667,
#  34.28333,
#  34.06667,
#  33.88333,
#  34.13333,
#  34.28333,
#  34.08333,
#  34.08333,
#  34.08333,
#  34.08333,
#  34.09167,
#  34.09167,
#  33.95833,
#  34.21667,
#  33.6,
#  34.3,
#  34.05,
#  33.995,
#  33.73883,
#  33.72217,
#  34.18833,
#  34.21667,
#  34.21667,
#  34.21667,
#  34.21667,
#  33.736667,
#  35.95,
#  35.95,
#  32.91667,
#  35.25,
#  33.0,
#  34.31833,
#  34.95,
#  36.45,
#  36.45,
#  34.45,
#  34.45,
#  33.23333,
#  34.53333,
#  35.28333,
#  33.38333,
#  36.2,
#  35.84083,
#  34.43333,
#  34.5,
#  35.96667,
#  36.08333,
#  36.5,
#  35.63333,
#  35.55,
#  36.1,
#  35.25,
#  35.41667,
#  35.03333,
#  35.75,
#  35.58333,
#  35.58333,
#  35.71667,
#  35.3,
#  36.5,
#  35.85,
#  35.85,
#  36.1,
#  35.56667,
#  35.31667,
#  35.66667,
#  35.86667,
#  36.38333,
#  35.1,
#  35.96667,
#  35.05,
#  36.41667,
#  35.51667,
#  35.68333,
#  34.5,
#  33.5,
#  34.24216,
#  45.41667,
#  43.2,
#  43.13333,
#  43.5,
#  44.221494,
#  44.47733,
#  43.56333,
#  43.603,
#  45.33333,
#  44.04833,
#  44.35,
#  45.5,
#  45.93333,
#  43.31667,
#  45.425,
#  44.4,
#  38.25,
#  37.62194,
#  36.83333,
#  38.4,
#  38.25,
#  36.6,
#  37.36667,
#  37.25,
#  38.0,
#  38.61667,
#  37.03333,
#  38.2,
#  36.71667,
#  37.01667,
#  38.81667,
#  38.4,
#  37.0,
#  36.95,
#  36.93333,
#  37.75,
#  38.56667,
#  37.95,
#  36.76667,
#  37.13333,
#  36.63333,
#  37.325,
#  40.66813,
#  37.86667,
#  40.90183,
#  35.66117,
#  40.86717,
#  38.66167,
#  40.2495,
#  40.24148,
#  40.26752000000001,
#  40.27537,
#  40.28563,
#  40.28338,
#  40.28247,
#  40.27957,
#  40.2628,
#  40.26667,
#  40.26667,
#  40.26667,
#  40.26667,
#  40.26667,
#  40.26667,
#  40.26667,
#  40.2819,
#  37.21667,
#  37.21667,
#  36.99367,
#  35.65917,
#  40.08173,
#  37.72683,
#  39.66667,
#  40.74018,
#  40.89055,
#  40.89805,
#  40.95805,
#  40.37972,
#  38.39918,
#  40.6265,
#  40.62832,
#  40.63078,
#  40.61667,
#  40.89201,
#  36.55722,
#  37.8594,
#  35.66667,
#  37.2,
#  38.08333,
#  35.63333,
#  35.65933,
#  35.6717,
#  35.68345,
#  35.67297999999999,
#  35.68078,
#  35.67405,
#  35.6701,
#  35.67725,
#  35.67355,
#  35.66594,
#  40.86217,
#  40.95465,
#  40.801,
#  40.792,
#  36.7845,
#  36.25547,
#  36.22907,
#  36.23728,
#  36.23722,
#  36.23743,
#  36.235,
#  35.98728,
#  39.63611,
#  39.67357,
#  39.68449,
#  39.68444,
#  39.6844,
#  39.68436,
#  39.68518,
#  39.68072,
#  39.68035,
#  39.68432,
#  39.68333300000001,
#  39.67917,
#  39.67888,
#  39.68945,
#  39.68908,
#  39.6884,
#  39.6872,
#  39.68938,
#  39.6772,
#  39.68105,
#  39.68973,
#  39.55801,
#  39.35067,
#  39.8,
#  39.75,
#  39.35,
#  38.5,
#  39.68333,
#  38.6,
#  40.0,
#  39.77667,
#  38.7,
#  39.6,
#  39.33333,
#  37.08333,
#  37.26667,
#  37.25,
#  38.53333,
#  37.31667,
#  38.30667,
#  39.91667,
#  37.5825,
#  39.25,
#  38.69667000000001,
#  38.84833,
#  38.23333,
#  37.03333,
#  39.7,
#  37.01667,
#  39.41667,
#  37.26667,
#  37.26667,
#  38.03333,
#  39.2,
#  37.61667,
#  39.65,
#  39.56583,
#  39.5,
#  39.61667,
#  38.85,
#  39.76667,
#  37.01667,
#  38.78333,
#  38.5,
#  38.28,
#  38.5,
#  38.64167,
#  38.26667,
#  39.61667,
#  39.35,
#  37.435,
#  37.46667,
#  38.395,
#  39.93333,
#  37.06667,
#  38.33333,
#  37.96417,
#  37.61667,
#  37.59667,
#  38.11667,
#  39.36667,
#  38.35,
#  37.2,
#  37.83333,
#  38.25,
#  38.76667,
#  37.55,
#  39.71633,
#  38.08333,
#  39.1,
#  39.27556,
#  38.61667,
#  38.07778,
#  38.1995,
#  38.96667,
#  37.66667,
#  39.63333,
#  39.60833,
#  38.38333,
#  38.44,
#  39.93333,
#  39.12417,
#  39.11667,
#  38.36667,
#  39.47444,
#  37.30833,
#  38.525,
#  38.525,
#  38.625,
#  38.5,
#  39.33333,
#  37.45,
#  38.5,
#  38.48333,
#  39.66667,
#  39.81667,
#  39.99167,
#  38.95,
#  39.8,
#  38.53333,
#  38.96667,
#  39.16667,
#  39.11,
#  39.35,
#  37.86667,
#  37.86667,
#  38.18333,
#  39.56667,
#  39.63333,
#  38.61667,
#  39.78333,
#  37.22222,
#  37.11667,
#  37.11667,
#  37.08333,
#  37.08333,
#  39.16667,
#  39.4,
#  39.43,
#  39.84433,
#  37.52392,
#  38.46667,
#  39.36667,
#  39.53333,
#  39.83333,
#  38.77083,
#  38.7,
#  39.83333,
#  39.4,
#  37.5,
#  39.08333,
#  37.6,
#  39.73633,
#  39.33333,
#  39.1,
#  39.81667,
#  37.59183,
#  37.08333,
#  37.53333,
#  37.38333,
#  38.9,
#  39.08333,
#  40.48,
#  41.48472,
#  38.2,
#  42.29111,
#  40.71667,
#  41.11667,
#  42.34667,
#  40.30583,
#  38.47028,
#  39.7825,
#  39.24667,
#  40.35,
#  39.96667,
#  40.15,
#  40.15,
#  37.46667,
#  39.75,
#  38.8,
#  39.76667,
#  39.3,
#  40.51667,
#  40.51667,
#  39.6,
#  39.3,
#  38.0,
#  40.66667,
#  39.86667,
#  39.1,
#  39.66667,
#  39.68333,
#  37.35,
#  38.46483,
#  39.85,
#  38.41667,
#  38.47,
#  37.0,
#  39.83333,
#  38.80778,
#  40.03167,
#  39.23,
#  40.68333,
#  38.81667,
#  38.5,
#  39.7,
#  37.96667,
#  38.76667,
#  38.83333,
#  40.45667,
#  38.06667,
#  40.56667,
#  37.58333,
#  39.13333,
#  39.695,
#  39.975,
#  38.71667,
#  40.46667,
#  38.3925,
#  39.36667,
#  37.68333,
#  37.65,
#  37.16667,
#  37.63333,
#  38.41667,
#  40.62583,
#  37.6,
#  40.96667,
#  40.75833,
#  40.95,
#  40.45,
#  38.51667,
#  38.61667,
#  39.8,
#  40.81667,
#  39.3,
#  39.27667,
#  39.53333,
#  37.38333,
#  37.48333,
#  40.6,
#  40.63783,
#  37.28333,
#  39.22167,
#  39.52167,
#  37.2,
#  38.58139,
#  ...]

# %%
# get a list of longitudes
qlongs = meteorite8['reclong'].to_list()
print(type(qlongs))
qlongs
# Out:
# <class 'list'>
# [-85.88333,
#  -84.50778000000003,
#  -83.95,
#  -83.6115,
#  -85.76666999999998,
#  -88.55972,
#  -85.13667,
#  -85.51666999999998,
#  -84.18333,
#  -70.75,
#  -68.75,
#  -69.48333000000001,
#  -69.2,
#  -70.24717,
#  -94.3,
#  -93.5,
#  -89.58333,
#  -94.4,
#  -92.08333,
#  -91.5,
#  -90.23333,
#  -91.15,
#  -93.55,
#  -94.36667,
#  -94.683333,
#  -94.92194,
#  -94.86667,
#  -94.33333,
#  -93.76111,
#  -91.8,
#  -95.37667,
#  -93.1,
#  -89.85,
#  -92.78694,
#  -90.5,
#  -90.31667,
#  -97.01,
#  -96.46667,
#  -98.83333,
#  -97.76667,
#  -94.51167,
#  -96.0,
#  -95.95,
#  -102.85833,
#  -103.11667,
#  -96.11667,
#  -99.03333,
#  -95.1,
#  -101.8,
#  -101.77217,
#  -102.71667,
#  -101.5,
#  -96.7,
#  -102.95,
#  -102.18111,
#  -102.28333,
#  -96.97167,
#  -99.98333,
#  -103.46667,
#  -97.5,
#  -101.5,
#  -99.8,
#  -103.02667,
#  -96.87222,
#  -96.92667,
#  -98.8,
#  -99.46667,
#  -101.4,
#  -102.96667,
#  -102.96,
#  -102.96,
#  -102.18333,
#  -102.18333,
#  -102.27833,
#  -102.18333,
#  -99.99306,
#  -99.25,
#  -98.25,
#  -101.93333,
#  -98.03333,
#  -96.90861,
#  -100.48333,
#  -102.45,
#  -102.28333,
#  -103.25,
#  -102.68,
#  -100.91333,
#  -100.94167,
#  -101.49,
#  -101.65833,
#  -97.41667,
#  -98.7,
#  -98.65167,
#  -101.5,
#  -97.75,
#  -97.28333,
#  -102.40833,
#  -104.25,
#  -97.6,
#  -97.70556,
#  -102.12,
#  -102.12,
#  -100.96667,
#  -97.0,
#  -102.80028,
#  -95.3,
#  -95.3,
#  -97.0,
#  -102.16667,
#  -102.32833,
#  -101.2,
#  -101.9,
#  -101.895,
#  -100.51667,
#  -96.86667,
#  -101.83333,
#  -101.83333,
#  -106.23333,
#  -100.83333,
#  -101.75,
#  -101.9,
#  -101.75833,
#  -102.65,
#  -101.5,
#  -99.40583,
#  -101.56667,
#  -101.68333,
#  -102.51667,
#  -102.705,
#  -101.28333,
#  -101.33333,
#  -101.11667,
#  -101.16278,
#  -97.65139,
#  -97.58861,
#  -103.06667,
#  -102.26667,
#  -102.745,
#  -102.56833,
#  -101.6,
#  -102.73333,
#  -97.71667,
#  -102.40139,
#  -101.938333,
#  -101.58333,
#  -102.81667,
#  -101.4,
#  -98.0,
#  -101.75,
#  -101.75,
#  -98.25,
#  -101.99333,
#  -101.99333,
#  -102.05,
#  -101.56667,
#  -102.11672,
#  -102.17667,
#  -102.16,
#  -99.73167,
#  -102.24167,
#  -98.83333,
#  -96.6,
#  -102.59433,
#  -106.15,
#  -106.15,
#  -97.86667,
#  -97.53333,
#  -99.83333,
#  -101.91667,
#  -101.815,
#  -101.815,
#  -101.815,
#  -96.41667,
#  -98.5,
#  -99.4,
#  -101.73,
#  -101.73,
#  -101.71667,
#  -101.71667,
#  -97.86667,
#  -97.90167,
#  -100.66667,
#  -101.7,
#  -101.88333,
#  -102.75,
#  -97.9,
#  -100.855,
#  -101.64,
#  -101.64,
#  -99.73698,
#  -101.3,
#  -101.40833,
#  -102.28333,
#  -102.38833,
#  -102.38833,
#  -102.54306,
#  -101.73333,
#  -99.60417,
#  -96.88333,
#  -100.93333,
#  -102.625,
#  -102.625,
#  -96.71667,
#  -100.6,
#  -102.26889,
#  -102.26889,
#  -100.13333,
#  -100.83333,
#  -100.6,
#  -102.88333,
#  -102.74333,
#  -102.76667,
#  -100.13333,
#  -102.695,
#  -97.40278,
#  -98.26667,
#  -98.28333,
#  -102.25,
#  -102.25,
#  -102.08333,
#  -102.08333,
#  -102.05,
#  -102.105,
#  -102.79917,
#  -101.8389,
#  -101.63833,
#  -102.11667,
#  -102.11333,
#  -97.61667,
#  -99.5,
#  -102.4,
#  -101.91867,
#  -102.13361,
#  -101.3,
#  -101.21667,
#  -101.38333,
#  -102.03333,
#  -102.0,
#  -98.95,
#  -102.57667,
#  -100.73167,
#  -98.91667,
#  -102.76667,
#  -102.9,
#  -101.78333,
#  -101.78333,
#  -101.75667,
#  -101.70417,
#  -101.70558,
#  -99.95,
#  -101.38333,
#  -98.05,
#  -95.0,
#  -99.61667,
#  -96.4,
#  -101.4975,
#  -102.95,
#  -97.05,
#  -96.65139,
#  -96.7,
#  -97.32306,
#  -100.35,
#  -98.5,
#  -102.15,
#  -101.0,
#  -102.58333,
#  -102.5,
#  -102.56667,
#  -102.61667,
#  -102.705,
#  -102.39167,
#  -102.65,
#  -102.65,
#  -102.67268,
#  -102.65,
#  -102.65,
#  -102.65,
#  -101.64722,
#  -102.58333,
#  -101.93333,
#  -101.18333,
#  -101.75,
#  -102.74056,
#  -102.16667,
#  -100.91667,
#  -97.8,
#  -101.25,
#  -102.12833,
#  -101.21667,
#  -102.22361,
#  -101.505,
#  -101.39,
#  -103.5,
#  -102.37833,
#  -102.41667,
#  -101.83333,
#  -100.41667,
#  -99.58333,
#  -100.4,
#  -97.3,
#  -103.01667,
#  -102.01667,
#  -101.73333,
#  -102.63167,
#  -102.65833,
#  -97.7,
#  -97.95278,
#  -102.0,
#  -101.95,
#  -101.7,
#  -101.76667,
#  -101.63,
#  -102.1175,
#  -99.76667,
#  -97.08333,
#  -101.38333,
#  -101.05,
#  -101.95,
#  -102.925,
#  -101.68333,
#  -100.25,
#  -102.33333,
#  -102.41667,
#  -102.33333,
#  -102.36667,
#  -102.315,
#  -101.93333,
#  -102.045,
#  -98.91667,
#  -98.11667,
#  -97.40278,
#  -106.18333,
#  -87.0,
#  -87.06667,
#  -87.16667,
#  -87.83333,
#  -87.5,
#  -86.2945,
#  -85.5,
#  -86.0,
#  -85.66667,
#  -87.91667,
#  -85.65,
#  -87.51666999999998,
#  -87.0,
#  -86.48333000000002,
#  -88.2,
#  -87.16667,
#  -85.56667,
#  -96.15,
#  -97.33333,
#  -97.58333,
#  -99.33333,
#  -95.15,
#  -98.3,
#  -97.88333,
#  -100.53333,
#  -99.15,
#  -98.33333,
#  -98.64389,
#  -97.70333,
#  -98.43333,
#  -98.68333,
#  -98.74889,
#  -96.76667,
#  -101.90833,
#  -102.78333,
#  -102.7,
#  -101.19,
#  -97.66667,
#  -102.5,
#  -96.43701,
#  -97.93333,
#  -100.21667,
#  -98.08333,
#  -97.0,
#  -100.2,
#  -99.704,
#  -97.91667,
#  -97.555,
#  -98.95,
#  -95.58333,
#  -97.185,
#  -96.68333,
#  -98.4,
#  -98.7,
#  -102.2,
#  -99.5,
#  -94.75,
#  -108.0,
#  -104.0,
#  -103.4,
#  -103.295,
#  -104.28333,
#  -104.26667,
#  -107.56667,
#  -105.93333,
#  -108.9038,
#  -106.56028,
#  -103.22,
#  -105.05,
#  -103.65,
#  -103.38333,
#  -103.395,
#  -103.22222,
#  -107.96667,
#  -103.70833,
#  -104.2,
#  -104.5,
#  -103.13472,
#  -103.13333,
#  -107.3945,
#  -107.16667,
#  -105.23333,
#  -103.525,
#  -103.61167,
#  -103.63333,
#  -103.55,
#  -107.90458999999998,
#  -103.955,
#  -103.35,
#  -105.5,
#  -103.57667,
#  -103.51833,
#  -103.56333,
#  -103.93667,
#  -104.05,
#  -103.575,
#  -109.05,
#  -103.34667,
#  -104.0,
#  -105.8,
#  -103.31667,
#  -103.31667,
#  -103.31667,
#  -107.88333,
#  -103.39167,
#  -103.38333,
#  -105.5,
#  -103.1,
#  -103.1,
#  -103.55333,
#  -103.76667,
#  -107.73333,
#  -103.92167,
#  -104.13333,
#  -105.85083,
#  -104.35,
#  -103.15,
#  -103.16667,
#  -103.15333,
#  -103.60278,
#  -106.79167,
#  -106.96667,
#  -103.91667,
#  -103.61667,
#  -103.605,
#  -104.11889,
#  -103.33333,
#  -106.05,
#  -103.93333,
#  -107.0,
#  -105.04833,
#  -103.35833,
#  -106.25833,
#  -106.38333,
#  -105.98333,
#  -104.5,
#  -108.1,
#  -105.0,
#  -105.1,
#  -104.5,
#  -104.5,
#  -103.5,
#  -103.5,
#  -103.41667,
#  -106.85,
#  -103.55,
#  -103.66667,
#  -106.63333,
#  -103.5,
#  -103.5,
#  -103.5,
#  -103.40833,
#  -103.56667,
#  -103.65,
#  -103.56667,
#  -103.5,
#  -103.28333,
#  -103.5,
#  -103.5,
#  -103.13333,
#  -103.48333,
#  -103.48333,
#  -103.48333,
#  -103.48333,
#  -103.48333,
#  -103.2,
#  -103.41667,
#  -103.56667,
#  -103.56667,
#  -103.20694,
#  -103.28333,
#  -103.23333,
#  -103.5,
#  -103.5,
#  -104.01667,
#  -103.25,
#  -103.5,
#  -103.5,
#  -103.43333,
#  -103.55,
#  -103.5,
#  -103.5,
#  -103.61667,
#  -103.61667,
#  -103.61667,
#  -103.51667,
#  -103.45,
#  -103.5,
#  -103.5,
#  -103.5,
#  -103.51667,
#  -103.61667,
#  -103.51667,
#  -103.25,
#  -103.48333,
#  -103.36667,
#  -103.45,
#  -103.5,
#  -103.5,
#  -103.35,
#  -103.48333,
#  -103.7,
#  -103.43333,
#  -103.43333,
#  -103.58333,
#  -103.28333,
#  -103.5,
#  -103.5,
#  -103.61667,
#  -103.51667,
#  -103.5,
#  -103.5,
#  -103.5,
#  -103.45,
#  -103.48333,
#  -103.48333,
#  -103.48333,
#  -103.48333,
#  -103.48333,
#  -103.48333,
#  -103.48333,
#  -103.48333,
#  -103.51667,
#  -103.43333,
#  -103.5,
#  -103.5,
#  -103.5,
#  -103.58333,
#  -103.5,
#  -103.16667,
#  -103.56667,
#  -103.41667,
#  -103.23333,
#  -103.38333,
#  -103.28333,
#  -103.51667,
#  -103.56667,
#  -103.53333,
#  -103.51667,
#  -103.5,
#  -103.5,
#  -103.5,
#  -103.5,
#  -103.50167,
#  -103.67667,
#  -103.93833,
#  -103.55,
#  -103.3,
#  -103.45,
#  -103.58333,
#  -103.25,
#  -103.65,
#  -103.67333,
#  -103.94167,
#  -103.93333,
#  -103.13333,
#  -103.18333,
#  -103.18333,
#  -103.623333,
#  -104.2,
#  -104.2,
#  -104.66667,
#  -106.5,
#  -107.5,
#  -103.47167,
#  -107.16667,
#  -104.1,
#  -104.1,
#  -104.01667,
#  -104.01667,
#  -103.44167,
#  -108.35,
#  -108.26667,
#  -105.25,
#  -103.9,
#  -104.58583,
#  -105.78333,
#  -105.83333,
#  -82.48333000000002,
#  -78.06667,
#  -79.25,
#  -78.13333,
#  -77.53333,
#  -81.41667,
#  -80.5,
#  -79.38333,
#  -83.03333,
#  -81.25,
#  -82.53333,
#  -82.35,
#  -81.86667,
#  -81.73333000000002,
#  -79.75,
#  -82.7,
#  -82.7,
#  -80.2,
#  -79.83333,
#  -81.46667,
#  -80.25,
#  -81.91667,
#  -79.86667,
#  -84.03333,
#  -77.96667,
#  -84.23333000000002,
#  -80.0,
#  -79.96667,
#  -82.18333,
#  -88.66667,
#  -89.0,
#  -88.77594,
#  -98.31667,
#  -96.91667,
#  -102.1,
#  -101.25,
#  -98.059192,
#  -103.972,
#  -97.58333,
#  -103.026,
#  -102.08333,
#  -96.59167,
#  -100.38333,
#  -103.5,
#  -102.18333,
#  -100.76667,
#  -101.097,
#  -98.53333,
#  -83.75,
#  -82.23722,
#  -84.35,
#  -84.25,
#  -85.75,
#  -88.1,
#  -85.36667,
#  -85.0,
#  -84.16667,
#  -84.96667,
#  -85.63333,
#  -84.83333,
#  -86.56667,
#  -85.91667,
#  -84.6,
#  -85.36667,
#  -88.25,
#  -84.9,
#  -87.4,
#  -85.5,
#  -85.23333000000002,
#  -85.78333,
#  -86.16667,
#  -88.4,
#  -83.83333,
#  -84.71667,
#  -117.18913,
#  -117.4,
#  -118.54465,
#  -115.33333,
#  -119.18352,
#  -115.51833,
#  -118.93683,
#  -118.94763,
#  -118.94308,
#  -118.9461,
#  -118.94657,
#  -118.94808,
#  -118.94872,
#  -118.94642,
#  -118.95912,
#  -118.93333,
#  -118.93333,
#  -118.93333,
#  -118.93333,
#  -118.93333,
#  -118.93333,
#  -118.93333,
#  -118.94693,
#  -117.08333,
#  -117.08333,
#  -114.99367,
#  -115.37283,
#  -115.93673,
#  -114.7865,
#  -118.96667,
#  -118.17285,
#  -118.36278,
#  -118.35388,
#  -118.35305,
#  -119.08639,
#  -115.9967,
#  -118.41033,
#  -118.4167,
#  -118.40918,
#  -118.38472,
#  -118.55319,
#  -114.42694,
#  -117.02097,
#  -115.36667,
#  -116.7,
#  -115.53333,
#  -115.36667,
#  -115.37167,
#  -115.36722,
#  -115.34703,
#  -115.36717,
#  -115.34062,
#  -115.36807,
#  -115.37248,
#  -115.3566,
#  -115.35067,
#  -115.37081,
#  -118.54167,
#  -118.49693,
#  -114.701,
#  -114.708,
#  -114.94967,
#  -116.18552,
#  -116.17935,
#  -116.1722,
#  -116.17242,
#  -116.17223,
#  -116.18358,
#  -115.85828,
#  -117.65472,
#  -117.60432,
#  -117.62072,
#  -117.62022,
#  -117.62007,
#  -117.62018,
#  -117.62105,
#  -117.62778,
#  -117.62918,
#  -117.62052,
#  -117.616667,
#  -117.62675,
#  -117.62945,
#  -117.62358,
#  -117.62257,
#  -117.62422,
#  -117.62618,
#  -117.62032,
#  -117.62858,
#  -117.61325,
#  -117.61822,
#  -114.42715,
#  -114.40783,
#  -101.2,
#  -97.03333,
#  -100.45,
#  -101.1,
#  -99.86667,
#  -95.21667,
#  -99.25,
#  -100.81333,
#  -96.1,
#  -100.11667,
#  -97.56167,
#  -98.05,
#  -97.76667,
#  -98.13333,
#  -100.21667,
#  -97.25,
#  -99.71,
#  -101.2,
#  -99.16361,
#  -101.33333,
#  -99.70833,
#  -98.72383,
#  -99.53333,
#  -97.625,
#  -98.98333,
#  -95.66667,
#  -101.05,
#  -99.33333,
#  -99.33333,
#  -101.98333,
#  -98.78333,
#  -98.91667,
#  -99.68333,
#  -99.64722,
#  -98.53333,
#  -100.46306,
#  -96.58333,
#  -99.91667,
#  -101.88333,
#  -99.33333,
#  -96.2,
#  -97.365,
#  -100.0,
#  -98.88333,
#  -95.25,
#  -98.7,
#  -101.66667,
#  -98.31833,
#  -101.43333,
#  -98.91583,
#  -99.21667,
#  -98.66167,
#  -101.71167,
#  -97.75583,
#  -99.1,
#  -99.125,
#  -97.43333,
#  -99.85,
#  -101.78333,
#  -101.35,
#  -100.45,
#  -97.66667,
#  -100.73333,
#  -101.68333,
#  -97.8545,
#  -100.25,
#  -94.63333,
#  -96.25944,
#  -101.63333,
#  -96.02639,
#  -99.162,
#  -95.16667,
#  -96.76667,
#  -100.46722,
#  -100.475,
#  -98.01667,
#  -98.06667,
#  -99.6,
#  -98.16778,
#  -98.68333,
#  -97.03333,
#  -96.925,
#  -97.545,
#  -99.81,
#  -95.78056,
#  -96.02278,
#  -101.1,
#  -100.06667,
#  -98.41667,
#  -99.6,
#  -99.91667,
#  -100.0,
#  -100.2,
#  -98.34167,
#  -101.01667,
#  -100.51667,
#  -99.05,
#  -94.66667,
#  -101.28333,
#  -100.36167,
#  -99.91667,
#  -100.66667,
#  -100.66667,
#  -94.71667,
#  -98.68333,
#  -100.5,
#  -99.93333,
#  -100.0,
#  -101.68139,
#  -101.6,
#  -101.6,
#  -101.6,
#  -101.6,
#  -98.43333,
#  -100.4,
#  -99.995,
#  -100.51,
#  -98.62993,
#  -100.93333,
#  -100.63333,
#  -100.56667,
#  -96.06667,
#  -101.79833,
#  -100.35,
#  -99.01667,
#  -100.03333,
#  -100.83333,
#  -95.11667,
#  -101.25,
#  -96.36133,
#  -98.16667,
#  -98.83333,
#  -94.91667,
#  -97.21497,
#  -101.76667,
#  -98.36667,
#  -96.86667,
#  -99.43333,
#  -89.15,
#  -89.00417,
#  -87.67917,
#  -89.68333,
#  -88.62556,
#  -90.41667,
#  -89.80833,
#  -90.1675,
#  -105.02325,
#  -105.24139,
#  -104.93056,
#  -104.58817,
#  -104.9,
#  -103.76667,
#  -103.16667,
#  -103.16667,
#  -105.86667,
#  -105.2,
#  -102.2,
#  -102.13333,
#  -103.25,
#  -103.26667,
#  -103.26667,
#  -105.3,
#  -102.41667,
#  -108.5,
#  -104.31667,
#  -106.88333,
#  -103.25833,
#  -102.83333,
#  -102.845,
#  -108.68333,
#  -105.7015,
#  -102.95,
#  -106.58333,
#  -102.82667,
#  -105.0,
#  -103.21667,
#  -104.56944,
#  -105.05667,
#  -102.99,
#  -102.81667,
#  -104.61667,
#  -105.5,
#  -105.7,
#  -102.33333,
#  -105.51667,
#  -105.8,
#  -102.57834,
#  -102.1,
#  -102.3,
#  -102.76667,
#  -103.48333,
#  -102.295,
#  -102.26667,
#  -103.51667,
#  -103.03333,
#  -104.17667,
#  -103.16667,
#  -105.7,
#  -105.73333,
#  -108.5,
#  -105.83333,
#  -106.21667,
#  -103.84033,
#  -105.83333,
#  -102.4,
#  -102.375,
#  -103.08333,
#  -102.38333,
#  -107.83333,
#  -102.71667,
#  -105.5,
#  -102.25,
#  -102.83333,
#  -102.88667,
#  -103.33333,
#  -102.63333,
#  -102.67667,
#  -103.18333,
#  -103.69717,
#  -102.2,
#  -102.59,
#  -103.16667,
#  -103.58333,
#  -104.07667,
#  ...]

# %%
# get elevation in location dict using lat/long
# Dependencies
import requests

# url = f"https://api.opentopodata.org/v1/etopo1?locations={qlat},{qlong}"

qlatlong = []

for x in range(0,len(qlats)):
    strlalo= f'{qlats[x]},{qlongs[x]}'
    qlatlong.append(strlalo)
    print(strlalo)
    type(strlalo)

print(qlatlong)


responses = []

for qlat in qlatlong:
    print(qlat)
    url = f"https://api.opentopodata.org/v1/etopo1?locations={qlat}"
    location = requests.get(url).json()
    responses.append(location)
    print(location)

print(responses)
# Out:
# 42.53333,-85.88333
# 43.76111,-84.50778000000003
# 44.51667,-83.95
# 42.38467,-83.6115
# 42.96667,-85.76666999999998
# 46.07944000000001,-88.55972
# 44.64694,-85.13667
# 43.86667,-85.51666999999998
# 41.78333,-84.18333
# 44.61667,-70.75
# 44.38333,-68.75
# 44.08333,-69.48333000000001
# 44.36667,-69.2
# 43.827,-70.24717
# 38.5,-94.3
# 36.75,-93.5
# 37.26667,-89.58333
# 39.08333,-94.4
# 37.91667,-92.08333
# 39.8,-91.5
# 38.7,-90.23333
# 38.68333,-91.15
# 37.06667,-93.55
# 38.3,-94.36667
# 40.266667,-94.683333
# 39.59167,-94.92194
# 39.61667,-94.86667
# 38.65,-94.33333
# 36.82444,-93.76111
# 36.53333,-91.8
# 40.2875,-95.37667
# 36.55,-93.1
# 37.73333,-89.85
# 37.2375,-92.78694
# 37.75,-90.5
# 37.96667,-90.31667
# 31.805,-97.01
# 33.6,-96.46667
# 31.83333,-98.83333
# 30.83333,-97.76667
# 32.675,-94.51167
# 29.45,-96.0
# 30.75,-95.95
# 31.60833,-102.85833
# 30.125,-103.11667
# 30.7,-96.11667
# 31.25,-99.03333
# 32.16667,-95.1
# 33.85,-101.8
# 32.59033,-101.77217
# 35.15,-102.71667
# 34.2,-101.5
# 33.1,-96.7
# 33.1,-102.95
# 33.7825,-102.18111
# 32.9,-102.28333
# 31.66,-96.97167
# 31.76667,-99.98333
# 30.78333,-103.46667
# 30.83333,-97.5
# 34.0,-101.5
# 33.58333,-99.8
# 33.59167,-103.02667
# 29.87861,-96.87222
# 29.86306,-96.92667
# 29.8,-98.8
# 31.05,-99.46667
# 34.35,-101.4
# 33.28333,-102.96667
# 33.275,-102.96
# 33.275,-102.96
# 33.21667,-102.18333
# 33.21667,-102.18333
# 33.135,-102.27833
# 33.21667,-102.18333
# 32.246109999999994,-99.99306
# 32.03333,-99.25
# 28.41667,-98.25
# 34.96667,-101.93333
# 31.91667,-98.03333
# 29.82806,-96.90861
# 34.2,-100.48333
# 36.2,-102.45
# 35.71667,-102.28333
# 29.0,-103.25
# 34.02806,-102.68
# 34.905,-100.91333
# 34.93611,-100.94167
# 34.34667,-101.49
# 34.34833,-101.65833
# 32.31667,-97.41667
# 32.01667,-98.7
# 31.991670000000006,-98.65167
# 32.0,-101.5
# 31.75,-97.75
# 29.01667,-97.28333
# 36.04333,-102.40833
# 30.75,-104.25
# 29.1,-97.6
# 29.00833,-97.70556
# 34.86,-102.12
# 34.86,-102.12
# 29.366670000000006,-100.96667
# 33.0,-97.0
# 33.07139,-102.80028
# 33.51667,-95.3
# 33.51667,-95.3
# 33.81667,-97.0
# 34.58333,-102.16667
# 34.48333,-102.32833
# 33.97917,-101.2
# 35.9,-101.9
# 35.925,-101.895
# 33.81667,-100.51667
# 32.63333,-96.86667
# 34.28333,-101.83333
# 34.28333,-101.83333
# 31.78333,-106.23333
# 33.71667,-100.83333
# 33.9,-101.75
# 35.98333,-101.9
# 34.47,-101.75833
# 34.10139,-102.65
# 34.0,-101.5
# 31.38972,-99.40583
# 34.26667,-101.56667
# 34.29833,-101.68333
# 34.43333,-102.51667
# 32.5225,-102.705
# 33.98333,-101.28333
# 33.98333,-101.33333
# 32.8,-101.11667
# 32.90333,-101.16278
# 33.50667,-97.65139
# 33.49556,-97.58861
# 30.91667,-103.06667
# 33.1,-102.26667
# 32.33333,-102.745
# 34.54,-102.56833
# 32.7,-101.6
# 32.83333,-102.73333
# 32.25,-97.71667
# 33.18139,-102.40139
# 32.788333,-101.938333
# 33.11667,-101.58333
# 33.71667,-102.81667
# 36.33333,-101.4
# 29.5,-98.0
# 34.05,-101.75
# 34.05,-101.75
# 31.59333,-98.25
# 35.68,-101.99333
# 34.59333,-101.99333
# 34.58333,-102.05
# 34.80167,-101.56667
# 34.37718,-102.11672
# 33.99833,-102.17667
# 35.94167,-102.16
# 33.21333,-99.73167
# 33.795,-102.24167
# 33.75,-98.83333
# 33.5,-96.6
# 34.54,-102.59433
# 31.91667,-106.15
# 31.91667,-106.15
# 31.96667,-97.86667
# 30.625,-97.53333
# 30.5,-99.83333
# 34.62333,-101.91667
# 34.67167,-101.815
# 34.67167,-101.815
# 34.67167,-101.815
# 32.58333,-96.41667
# 29.4,-98.5
# 30.41667,-99.4
# 34.35833,-101.73
# 34.35833,-101.73
# 34.33833,-101.71667
# 34.38333,-101.71667
# 29.975,-97.86667
# 26.27167,-97.90167
# 35.56667,-100.66667
# 34.53333,-101.7
# 32.88333,-101.88333
# 34.5,-102.75
# 30.6,-97.9
# 34.61139,-100.855
# 34.655,-101.64
# 34.655,-101.64
# 30.52213,-99.73698
# 34.15,-101.3
# 34.25972,-101.40833
# 32.9,-102.28333
# 32.99167,-102.38833
# 32.98333,-102.38833
# 33.28944,-102.54306
# 33.6,-101.73333
# 32.83611,-99.60417
# 31.5,-96.88333
# 33.75,-100.93333
# 32.925,-102.625
# 32.925,-102.625
# 33.18333,-96.71667
# 35.23333,-100.6
# 33.33139,-102.26889
# 33.33139,-102.26889
# 31.42611,-100.13333
# 31.26667,-100.83333
# 35.66667,-100.6
# 31.48333,-102.88333
# 32.50333,-102.74333
# 33.71667,-102.76667
# 35.63333,-100.13333
# 34.12167,-102.695
# 28.95,-97.40278
# 30.95,-98.26667
# 30.95,-98.28333
# 34.5,-102.25
# 34.5,-102.25
# 34.58333,-102.08333
# 34.58333,-102.08333
# 34.58333,-102.05
# 34.52667,-102.105
# 34.04472,-102.79917
# 33.721,-101.8389
# 33.17,-101.63833
# 33.11667,-102.11667
# 33.11833,-102.11333
# 28.866670000000006,-97.61667
# 27.5,-99.5
# 31.71667,-102.4
# 32.91217,-101.91867
# 34.16722,-102.13361
# 30.73333,-101.3
# 34.9,-101.21667
# 35.33333,-101.38333
# 32.5,-102.03333
# 32.0,-102.0
# 30.33333,-98.95
# 33.73,-102.57667
# 36.35333,-100.73167
# 29.68333,-98.91667
# 33.28333,-102.76667
# 33.26667,-102.9
# 34.11667,-101.78333
# 34.11667,-101.78333
# 34.125,-101.75667
# 34.1875,-101.70417
# 34.18513,-101.70558
# 31.66333,-99.95
# 33.11667,-101.38333
# 29.5,-98.05
# 32.0,-95.0
# 33.53333,-99.61667
# 31.9,-96.4
# 34.42222,-101.4975
# 35.76667,-102.95
# 30.81667,-97.05
# 30.05806,-96.65139
# 30.06667,-96.7
# 32.865829999999995,-97.32306
# 31.41667,-100.35
# 29.5,-98.5
# 30.13333,-102.15
# 32.5,-101.0
# 32.93333,-102.58333
# 32.91722,-102.5
# 32.98333,-102.56667
# 32.68333,-102.61667
# 32.54333,-102.705
# 32.55,-102.39167
# 32.71667,-102.65
# 32.71667,-102.65
# 32.70038,-102.67268
# 32.71667,-102.65
# 32.71667,-102.65
# 32.71667,-102.65
# 34.26889,-101.64722
# 32.4,-102.58333
# 33.7,-101.93333
# 34.53333,-101.18333
# 33.43333,-101.75
# 33.11861,-102.74056
# 33.58333,-102.16667
# 32.71667,-100.91667
# 32.18333,-97.8
# 34.26667,-101.25
# 34.00111,-102.12833
# 36.25,-101.21667
# 34.34444000000001,-102.22361
# 31.73333,-101.505
# 34.21,-101.39
# 29.30167,-103.5
# 32.98333,-102.37833
# 34.76667,-102.41667
# 36.0,-101.83333
# 32.55,-100.41667
# 31.866670000000006,-99.58333
# 34.38333,-100.4
# 31.116670000000006,-97.3
# 36.4,-103.01667
# 34.93333,-102.01667
# 34.98333,-101.73333
# 33.21667,-102.63167
# 33.205,-102.65833
# 30.3,-97.7
# 30.55556,-97.95278
# 34.66667,-102.0
# 34.61667,-101.95
# 34.53333,-101.7
# 34.60667,-101.76667
# 34.555,-101.63
# 34.95,-102.1175
# 29.2,-99.76667
# 32.4,-97.08333
# 34.68333,-101.38333
# 36.15,-101.05
# 32.4,-101.95
# 32.90333,-102.925
# 34.80167,-101.68333
# 34.95,-100.25
# 33.03333,-102.33333
# 33.025,-102.41667
# 33.03333,-102.33333
# 33.01667,-102.36667
# 33.678329999999995,-102.315
# 33.05,-101.93333
# 33.075,-102.045
# 34.06667,-98.91667
# 29.96667,-98.11667
# 28.95,-97.40278
# 31.65,-106.18333
# 34.75,-87.0
# 34.4,-87.06667
# 32.53333,-87.16667
# 34.48333,-87.83333
# 34.58333,-87.5
# 33.18836,-86.2945
# 32.63333,-85.5
# 32.0,-86.0
# 33.5,-85.66667
# 33.96667,-87.91667
# 34.68333,-85.65
# 31.55,-87.51666999999998
# 32.4,-87.0
# 34.2,-86.48333000000002
# 32.23333,-88.2
# 34.0,-87.16667
# 32.68333,-85.56667
# 34.31667,-96.15
# 36.83333,-97.33333
# 35.95,-97.58333
# 35.88333,-99.33333
# 36.00833,-95.15
# 34.33333,-98.3
# 35.16667,-97.88333
# 36.8,-100.53333
# 35.33333,-99.15
# 35.0,-98.33333
# 35.16667,-98.64389
# 35.84778,-97.70333
# 36.43333,-98.43333
# 35.35,-98.68333
# 35.405,-98.74889
# 35.96667,-96.76667
# 36.81667,-101.90833
# 36.55,-102.78333
# 36.58333,-102.7
# 36.57,-101.19
# 36.56,-97.66667
# 36.71667,-102.5
# 36.28402,-96.43701
# 35.83333,-97.93333
# 36.9,-100.21667
# 36.38333,-98.08333
# 34.1,-97.0
# 36.58333,-100.2
# 34.849000000000004,-99.704
# 34.6,-97.91667
# 36.98667,-97.555
# 34.86667,-98.95
# 34.03333,-95.58333
# 36.34611,-97.185
# 34.25,-96.68333
# 35.833333,-98.4
# 35.5,-98.7
# 36.73333,-102.2
# 36.5,-99.5
# 35.0,-94.75
# 36.8,-108.0
# 32.21667,-104.0
# 36.21667,-103.4
# 34.175,-103.295
# 36.3,-104.28333
# 33.63333,-104.26667
# 35.05,-107.56667
# 32.9,-105.93333
# 32.306,-108.9038
# 32.00584,-106.56028
# 34.15,-103.22
# 36.33333,-105.05
# 36.21667,-103.65
# 34.23333,-103.38333
# 34.24667,-103.395
# 34.20583,-103.22222
# 35.26667,-107.96667
# 33.65167,-103.70833
# 36.5,-104.2
# 36.0,-104.5
# 34.3,-103.13472
# 34.3,-103.13333
# 31.82967,-107.3945
# 34.95,-107.16667
# 36.83333,-105.23333
# 34.08333,-103.525
# 34.09,-103.61167
# 34.05,-103.63333
# 34.05,-103.55
# 32.22548,-107.90458999999998
# 33.92667,-103.955
# 33.92333,-103.35
# 33.5,-105.5
# 33.78333,-103.57667
# 33.91667,-103.51833
# 33.79,-103.56333
# 33.84333,-103.93667
# 36.33333,-104.05
# 34.19333,-103.575
# 37.0,-109.05
# 33.86333,-103.34667
# 36.3,-104.0
# 35.6,-105.8
# 34.8,-103.31667
# 34.8,-103.31667
# 34.8,-103.31667
# 35.16667,-107.88333
# 34.38167,-103.39167
# 34.26667,-103.38333
# 34.0,-105.5
# 32.73333,-103.1
# 32.73333,-103.1
# 33.9,-103.55333
# 33.70833,-103.76667
# 32.9,-107.73333
# 34.46667,-103.92167
# 34.45,-104.13333
# 33.00383,-105.85083
# 32.62972,-104.35
# 32.03333,-103.15
# 32.03333,-103.16667
# 32.04333,-103.15333
# 34.00833,-103.60278
# 34.8125,-106.79167
# 34.0,-106.96667
# 34.21667,-103.91667
# 34.38333,-103.61667
# 34.39833,-103.605
# 36.23,-104.11889
# 33.63333,-103.33333
# 34.98333,-106.05
# 35.75,-103.93333
# 34.5,-107.0
# 36.29533,-105.04833
# 34.22833,-103.35833
# 32.37167,-106.25833
# 33.63333,-106.38333
# 35.16667,-105.98333
# 36.5,-104.5
# 33.66667,-108.1
# 33.2,-105.0
# 32.66667,-105.1
# 36.5,-104.5
# 36.5,-104.5
# 34.06667,-103.5
# 34.06667,-103.5
# 34.1,-103.41667
# 34.4,-106.85
# 34.76778,-103.55
# 34.78333,-103.66667
# 35.3,-106.63333
# 34.08333,-103.5
# 34.08333,-103.5
# 34.08333,-103.5
# 34.065,-103.40833
# 33.78333,-103.56667
# 33.71667,-103.65
# 33.88333,-103.56667
# 34.08333,-103.5
# 34.21667,-103.28333
# 34.08333,-103.5
# 33.08333,-103.5
# 33.75,-103.13333
# 34.1,-103.48333
# 34.1,-103.48333
# 34.1,-103.48333
# 34.1,-103.48333
# 34.1,-103.48333
# 34.21667,-103.2
# 34.31667,-103.41667
# 34.11667,-103.56667
# 34.13333,-103.56667
# 33.81806,-103.20694
# 34.21667,-103.28333
# 34.18333,-103.23333
# 34.08333,-103.5
# 34.08333,-103.5
# 34.15,-104.01667
# 33.8,-103.25
# 34.08333,-103.5
# 34.08333,-103.5
# 34.28333,-103.43333
# 33.78333,-103.55
# 34.08333,-103.5
# 34.08333,-103.5
# 34.08333,-103.61667
# 34.08333,-103.61667
# 34.08333,-103.61667
# 34.08333,-103.51667
# 34.3,-103.45
# 34.08333,-103.5
# 34.08333,-103.5
# 34.08333,-103.5
# 34.08333,-103.51667
# 34.08333,-103.61667
# 34.25,-103.51667
# 34.23333,-103.25
# 34.1,-103.48333
# 34.13333,-103.36667
# 33.61667,-103.45
# 34.08333,-103.5
# 34.08333,-103.5
# 34.21667,-103.35
# 34.1,-103.48333
# 33.88333,-103.7
# 34.3,-103.43333
# 34.3,-103.43333
# 34.41667,-103.58333
# 34.21667,-103.28333
# 34.08333,-103.5
# 34.08333,-103.5
# 34.08333,-103.61667
# 34.08333,-103.51667
# 34.21667,-103.5
# 34.08333,-103.5
# 34.08333,-103.5
# 33.61667,-103.45
# 34.1,-103.48333
# 34.1,-103.48333
# 34.1,-103.48333
# 34.1,-103.48333
# 34.1,-103.48333
# 34.1,-103.48333
# 34.1,-103.48333
# 34.08333,-103.48333
# 34.08333,-103.51667
# 34.18333,-103.43333
# 34.08333,-103.5
# 34.08333,-103.5
# 34.08333,-103.5
# 34.1,-103.58333
# 34.05,-103.5
# 33.63333,-103.16667
# 34.08333,-103.56667
# 33.66667,-103.41667
# 34.2,-103.23333
# 34.31667,-103.38333
# 34.28333,-103.28333
# 34.06667,-103.51667
# 33.88333,-103.56667
# 34.13333,-103.53333
# 34.28333,-103.51667
# 34.08333,-103.5
# 34.08333,-103.5
# 34.08333,-103.5
# 34.08333,-103.5
# 34.09167,-103.50167
# 34.09167,-103.67667
# 33.95833,-103.93833
# 34.21667,-103.55
# 33.6,-103.3
# 34.3,-103.45
# 34.05,-103.58333
# 33.995,-103.25
# 33.73883,-103.65
# 33.72217,-103.67333
# 34.18833,-103.94167
# 34.21667,-103.93333
# 34.21667,-103.13333
# 34.21667,-103.18333
# 34.21667,-103.18333
# 33.736667,-103.623333
# 35.95,-104.2
# 35.95,-104.2
# 32.91667,-104.66667
# 35.25,-106.5
# 33.0,-107.5
# 34.31833,-103.47167
# 34.95,-107.16667
# 36.45,-104.1
# 36.45,-104.1
# 34.45,-104.01667
# 34.45,-104.01667
# 33.23333,-103.44167
# 34.53333,-108.35
# 35.28333,-108.26667
# 33.38333,-105.25
# 36.2,-103.9
# 35.84083,-104.58583
# 34.43333,-105.78333
# 34.5,-105.83333
# 35.96667,-82.48333000000002
# 36.08333,-78.06667
# 36.5,-79.25
# 35.63333,-78.13333
# 35.55,-77.53333
# 36.1,-81.41667
# 35.25,-80.5
# 35.41667,-79.38333
# 35.03333,-83.03333
# 35.75,-81.25
# 35.58333,-82.53333
# 35.58333,-82.35
# 35.71667,-81.86667
# 35.3,-81.73333000000002
# 36.5,-79.75
# 35.85,-82.7
# 35.85,-82.7
# 36.1,-80.2
# 35.56667,-79.83333
# 35.31667,-81.46667
# 35.66667,-80.25
# 35.86667,-81.91667
# 36.38333,-79.86667
# 35.1,-84.03333
# 35.96667,-77.96667
# 35.05,-84.23333000000002
# 36.41667,-80.0
# 35.51667,-79.96667
# 35.68333,-82.18333
# 34.5,-88.66667
# 33.5,-89.0
# 34.24216,-88.77594
# 45.41667,-98.31667
# 43.2,-96.91667
# 43.13333,-102.1
# 43.5,-101.25
# 44.221494,-98.059192
# 44.47733,-103.972
# 43.56333,-97.58333
# 43.603,-103.026
# 45.33333,-102.08333
# 44.04833,-96.59167
# 44.35,-100.38333
# 45.5,-103.5
# 45.93333,-102.18333
# 43.31667,-100.76667
# 45.425,-101.097
# 44.4,-98.53333
# 38.25,-83.75
# 37.62194,-82.23722
# 36.83333,-84.35
# 38.4,-84.25
# 38.25,-85.75
# 36.6,-88.1
# 37.36667,-85.36667
# 37.25,-85.0
# 38.0,-84.16667
# 38.61667,-84.96667
# 37.03333,-85.63333
# 38.2,-84.83333
# 36.71667,-86.56667
# 37.01667,-85.91667
# 38.81667,-84.6
# 38.4,-85.36667
# 37.0,-88.25
# 36.95,-84.9
# 36.93333,-87.4
# 37.75,-85.5
# 38.56667,-85.23333000000002
# 37.95,-85.78333
# 36.76667,-86.16667
# 37.13333,-88.4
# 36.63333,-83.83333
# 37.325,-84.71667
# 40.66813,-117.18913
# 37.86667,-117.4
# 40.90183,-118.54465
# 35.66117,-115.33333
# 40.86717,-119.18352
# 38.66167,-115.51833
# 40.2495,-118.93683
# 40.24148,-118.94763
# 40.26752000000001,-118.94308
# 40.27537,-118.9461
# 40.28563,-118.94657
# 40.28338,-118.94808
# 40.28247,-118.94872
# 40.27957,-118.94642
# 40.2628,-118.95912
# 40.26667,-118.93333
# 40.26667,-118.93333
# 40.26667,-118.93333
# 40.26667,-118.93333
# 40.26667,-118.93333
# 40.26667,-118.93333
# 40.26667,-118.93333
# 40.2819,-118.94693
# 37.21667,-117.08333
# 37.21667,-117.08333
# 36.99367,-114.99367
# 35.65917,-115.37283
# 40.08173,-115.93673
# 37.72683,-114.7865
# 39.66667,-118.96667
# 40.74018,-118.17285
# 40.89055,-118.36278
# 40.89805,-118.35388
# 40.95805,-118.35305
# 40.37972,-119.08639
# 38.39918,-115.9967
# 40.6265,-118.41033
# 40.62832,-118.4167
# 40.63078,-118.40918
# 40.61667,-118.38472
# 40.89201,-118.55319
# 36.55722,-114.42694
# 37.8594,-117.02097
# 35.66667,-115.36667
# 37.2,-116.7
# 38.08333,-115.53333
# 35.63333,-115.36667
# 35.65933,-115.37167
# 35.6717,-115.36722
# 35.68345,-115.34703
# 35.67297999999999,-115.36717
# 35.68078,-115.34062
# 35.67405,-115.36807
# 35.6701,-115.37248
# 35.67725,-115.3566
# 35.67355,-115.35067
# 35.66594,-115.37081
# 40.86217,-118.54167
# 40.95465,-118.49693
# 40.801,-114.701
# 40.792,-114.708
# 36.7845,-114.94967
# 36.25547,-116.18552
# 36.22907,-116.17935
# 36.23728,-116.1722
# 36.23722,-116.17242
# 36.23743,-116.17223
# 36.235,-116.18358
# 35.98728,-115.85828
# 39.63611,-117.65472
# 39.67357,-117.60432
# 39.68449,-117.62072
# 39.68444,-117.62022
# 39.6844,-117.62007
# 39.68436,-117.62018
# 39.68518,-117.62105
# 39.68072,-117.62778
# 39.68035,-117.62918
# 39.68432,-117.62052
# 39.68333300000001,-117.616667
# 39.67917,-117.62675
# 39.67888,-117.62945
# 39.68945,-117.62358
# 39.68908,-117.62257
# 39.6884,-117.62422
# 39.6872,-117.62618
# 39.68938,-117.62032
# 39.6772,-117.62858
# 39.68105,-117.61325
# 39.68973,-117.61822
# 39.55801,-114.42715
# 39.35067,-114.40783
# 39.8,-101.2
# 39.75,-97.03333
# 39.35,-100.45
# 38.5,-101.1
# 39.68333,-99.86667
# 38.6,-95.21667
# 40.0,-99.25
# 39.77667,-100.81333
# 38.7,-96.1
# 39.6,-100.11667
# 39.33333,-97.56167
# 37.08333,-98.05
# 37.26667,-97.76667
# 37.25,-98.13333
# 38.53333,-100.21667
# 37.31667,-97.25
# 38.30667,-99.71
# 39.91667,-101.2
# 37.5825,-99.16361
# 39.25,-101.33333
# 38.69667000000001,-99.70833
# 38.84833,-98.72383
# 38.23333,-99.53333
# 37.03333,-97.625
# 39.7,-98.98333
# 37.01667,-95.66667
# 39.41667,-101.05
# 37.26667,-99.33333
# 37.26667,-99.33333
# 38.03333,-101.98333
# 39.2,-98.78333
# 37.61667,-98.91667
# 39.65,-99.68333
# 39.56583,-99.64722
# 39.5,-98.53333
# 39.61667,-100.46306
# 38.85,-96.58333
# 39.76667,-99.91667
# 37.01667,-101.88333
# 38.78333,-99.33333
# 38.5,-96.2
# 38.28,-97.365
# 38.5,-100.0
# 38.64167,-98.88333
# 38.26667,-95.25
# 39.61667,-98.7
# 39.35,-101.66667
# 37.435,-98.31833
# 37.46667,-101.43333
# 38.395,-98.91583
# 39.93333,-99.21667
# 37.06667,-98.66167
# 38.33333,-101.71167
# 37.96417,-97.75583
# 37.61667,-99.1
# 37.59667,-99.125
# 38.11667,-97.43333
# 39.36667,-99.85
# 38.35,-101.78333
# 37.2,-101.35
# 37.83333,-100.45
# 38.25,-97.66667
# 38.76667,-100.73333
# 37.55,-101.68333
# 39.71633,-97.8545
# 38.08333,-100.25
# 39.1,-94.63333
# 39.27556,-96.25944
# 38.61667,-101.63333
# 38.07778,-96.02639
# 38.1995,-99.162
# 38.96667,-95.16667
# 37.66667,-96.76667
# 39.63333,-100.46722
# 39.60833,-100.475
# 38.38333,-98.01667
# 38.44,-98.06667
# 39.93333,-99.6
# 39.12417,-98.16778
# 39.11667,-98.68333
# 38.36667,-97.03333
# 39.47444,-96.925
# 37.30833,-97.545
# 38.525,-99.81
# 38.525,-95.78056
# 38.625,-96.02278
# 38.5,-101.1
# 39.33333,-100.06667
# 37.45,-98.41667
# 38.5,-99.6
# 38.48333,-99.91667
# 39.66667,-100.0
# 39.81667,-100.2
# 39.99167,-98.34167
# 38.95,-101.01667
# 39.8,-100.51667
# 38.53333,-99.05
# 38.96667,-94.66667
# 39.16667,-101.28333
# 39.11,-100.36167
# 39.35,-99.91667
# 37.86667,-100.66667
# 37.86667,-100.66667
# 38.18333,-94.71667
# 39.56667,-98.68333
# 39.63333,-100.5
# 38.61667,-99.93333
# 39.78333,-100.0
# 37.22222,-101.68139
# 37.11667,-101.6
# 37.11667,-101.6
# 37.08333,-101.6
# 37.08333,-101.6
# 39.16667,-98.43333
# 39.4,-100.4
# 39.43,-99.995
# 39.84433,-100.51
# 37.52392,-98.62993
# 38.46667,-100.93333
# 39.36667,-100.63333
# 39.53333,-100.56667
# 39.83333,-96.06667
# 38.77083,-101.79833
# 38.7,-100.35
# 39.83333,-99.01667
# 39.4,-100.03333
# 37.5,-100.83333
# 39.08333,-95.11667
# 37.6,-101.25
# 39.73633,-96.36133
# 39.33333,-98.16667
# 39.1,-98.83333
# 39.81667,-94.91667
# 37.59183,-97.21497
# 37.08333,-101.76667
# 37.53333,-98.36667
# 37.38333,-96.86667
# 38.9,-99.43333
# 39.08333,-89.15
# 40.48,-89.00417
# 41.48472,-87.67917
# 38.2,-89.68333
# 42.29111,-88.62556
# 40.71667,-90.41667
# 41.11667,-89.80833
# 42.34667,-90.1675
# 40.30583,-105.02325
# 38.47028,-105.24139
# 39.7825,-104.93056
# 39.24667,-104.58817
# 40.35,-104.9
# 39.96667,-103.76667
# 40.15,-103.16667
# 40.15,-103.16667
# 37.46667,-105.86667
# 39.75,-105.2
# 38.8,-102.2
# 39.76667,-102.13333
# 39.3,-103.25
# 40.51667,-103.26667
# 40.51667,-103.26667
# 39.6,-105.3
# 39.3,-102.41667
# 38.0,-108.5
# 40.66667,-104.31667
# 39.86667,-106.88333
# 39.1,-103.25833
# 39.66667,-102.83333
# 39.68333,-102.845
# 37.35,-108.68333
# 38.46483,-105.7015
# 39.85,-102.95
# 38.41667,-106.58333
# 38.47,-102.82667
# 37.0,-105.0
# 39.83333,-103.21667
# 38.80778,-104.56944
# 40.03167,-105.05667
# 39.23,-102.99
# 40.68333,-102.81667
# 38.81667,-104.61667
# 38.5,-105.5
# 39.7,-105.7
# 37.96667,-102.33333
# 38.76667,-105.51667
# 38.83333,-105.8
# 40.45667,-102.57834
# 38.06667,-102.1
# 40.56667,-102.3
# 37.58333,-102.76667
# 39.13333,-103.48333
# 39.695,-102.295
# 39.975,-102.26667
# 38.71667,-103.51667
# 40.46667,-103.03333
# 38.3925,-104.17667
# 39.36667,-103.16667
# 37.68333,-105.7
# 37.65,-105.73333
# 37.16667,-108.5
# 37.63333,-105.83333
# 38.41667,-106.21667
# 40.62583,-103.84033
# 37.6,-105.83333
# 40.96667,-102.4
# 40.75833,-102.375
# 40.95,-103.08333
# 40.45,-102.38333
# 38.51667,-107.83333
# 38.61667,-102.71667
# 39.8,-105.5
# 40.81667,-102.25
# 39.3,-102.83333
# 39.27667,-102.88667
# 39.53333,-103.33333
# 37.38333,-102.63333
# 37.48333,-102.67667
# 40.6,-103.18333
# 40.63783,-103.69717
# 37.28333,-102.2
# 39.22167,-102.59
# 39.52167,-103.16667
# 37.2,-103.58333
# 38.58139,-104.07667
# 37.63333,-102.41667
# 37.63333,-102.41667
# 39.7,-103.16667
# 40.35,-103.95
# 39.41667,-103.2
# 38.15,-102.66667
# 40.05,-102.2
# 40.33083,-102.19583
# 42.53333,-73.83333
# 41.28333,-73.91667
# 42.86083,-73.95028
# 41.28333,-73.81667
# 42.75,-75.18333
# 43.2,-78.8
# 42.83333,-74.5
# 42.7,-77.88333
# 42.91667,-76.78333
# 43.03333,-78.03333
# 42.88333,-73.6
# 34.16667,-80.28333
# 35.03333,-81.88333
# 34.7,-81.2
# 34.5,-82.03333
# 34.0,-81.25
# 34.3,-81.4
# 40.91667,-78.08333
# 40.5,-80.08333
# 40.93333,-79.73333000000002
# 41.28333,-77.05
# 39.78333,-77.21667
# 40.0,-78.85
# 40.43333,-80.0
# 39.76667,-76.66667
# 35.5,-93.5
# 36.05,-94.16667
# 35.4,-92.05
# 36.21667,-92.26667
# 36.06667,-90.5
# 36.48333,-90.66667
# 36.08333,-92.15
# 35.28333,-93.5
# 34.48333,-94.45
# 33.68333,-93.6
# 35.76667,-91.5
# 35.6,-91.26667
# 35.93333,-91.63333
# 34.65,-91.58333
# 35.0,-94.0
# 36.16667,-87.33333
# 36.4,-86.5
# 35.8,-84.1
# 35.3,-86.63333
# 36.3,-82.88333
# 36.3,-82.88333
# 36.56667,-82.18333
# 36.26667,-85.98333000000002
# 36.08333,-84.2
# 36.16667,-85.51666999999998
# 36.43333,-87.0
# 35.78333,-83.25
# 35.83333,-84.91667
# 35.95,-84.56667
# 35.95,-84.56667
# 36.41667,-85.5
# 36.3,-82.46667
# 36.41667,-85.25
# 36.2,-83.38333
# 35.83333,-86.41667
# 36.4665,-88.60283000000003
# 35.16667,-88.18333
# 35.98333,-85.85
# 36.43333,-83.75
# 32.1025,-81.87278
# 33.01667,-83.96667
# 32.03333,-84.76666999999998
# 31.95,-83.51666999999998
# 34.2,-84.48333000000002
# 34.01667,-85.26666999999998
# 34.88333,-84.78333
# 34.8,-84.98333000000002
# 31.33333,-82.31667
# 34.36667,-85.43333
# 32.133333,-82.983333
# 33.33333,-84.1
# 34.25,-84.5
# 32.83528,-81.87389
# 32.51667,-82.55
# 34.0,-84.8
# 34.5,-84.5
# 33.25,-83.25
# 32.94889000000001,-81.865
# 34.0,-83.16667
# 33.7,-83.7
# 32.4375,-81.91667
# 33.46667,-82.48333000000002
# 32.58333,-82.01666999999998
# 34.75,-84.0
# 44.9,-90.28333
# 43.58333,-89.6
# 42.9075,-90.36556
# 45.34583,-92.05167
# 43.5,-91.16667
# 44.65,-87.46667
# 44.25,-88.25
# 42.73333,-90.35
# 44.91667,-92.43333
# 44.0,-89.25
# 44.07694,-88.56278
# 44.21667,-89.1
# 43.36667,-88.13333
# 42.51333,-88.48944
# 40.25,-74.0
# 40.78167,-96.47167
# 42.71667,-99.38333
# 42.58333,-103.66667
# 42.6,-99.8
# 40.8,-99.2
# 41.41667,-99.1
# 41.81667,-103.36667
# 41.0,-97.53333
# 40.5,-101.08333
# 41.15333,-96.955
# 40.81,-101.80167
# 41.43333,-99.7
# 41.23333,-103.9
# 41.35,-99.11667
# 41.36667,-98.63333
# 40.23333,-100.83333
# 41.23333,-103.48333
# 40.25,-100.23333
# 40.51667,-101.03333
# 40.16667,-97.6
# 40.33333,-99.03333
# 41.18333,-103.0
# 40.23333,-100.41667
# 41.48333,-96.16667
# 40.68333,-99.06667
# 40.66667,-96.75
# 41.43333,-96.96667
# 40.46667,-99.5
# 41.03333,-102.88333
# 40.74972,-97.74972
# 42.45,-103.3
# 40.02,-100.78333
# 42.18333,-103.93333
# 41.16667,-101.66667
# 41.2,-103.68333
# 41.2,-103.68333
# 40.16667,-99.66667
# 41.23333,-103.3
# 40.25,-100.5
# 40.08333,-98.91667
# 40.43333,-98.06667
# 41.05,-102.9
# 40.45,-100.75
# 40.6,-97.86667
# 41.55,-100.96667
# 42.93333,-100.75
# 42.03333,-101.5
# 40.75,-97.5
# 40.86667,-97.6
# 43.41667,-94.83333
# 43.25,-93.66667
# 41.8,-91.86667
# 41.9,-91.6
# 43.32222,-96.28889
# 41.5,-91.47917
# 42.18333,-95.71667
# 47.81667,-96.85
# 45.2,-93.43333
# 44.6,-94.1
# 47.95833,-96.7
# 43.8,-96.16667
# 47.6,-94.76667
# 36.78333,-78.08333
# 38.70066,-77.21163
# 37.46667,-77.5
# 37.83333,-76.7
# 38.16667,-79.08333
# 37.5,-79.75
# 37.23333,-80.73333000000002
# 36.85,-82.45
# 36.55,-79.78333
# 36.93333,-80.5
# 37.21667,-82.0
# 36.9,-76.3
# 38.21667,-79.05
# 41.68333,-112.13333
# 40.56667,-110.48333
# 38.68867,-109.58517
# 38.48417,-113.13639
# 38.18333,-109.88333
# 38.90306,-112.82111
# 39.5,-112.9
# 40.38333,-110.86667
# 39.49133,-112.942
# 37.28333,-113.78333
# 40.25,-110.08333
# 38.17,-110.36667
# 38.98333,-111.85
# 40.91667,-111.66667
# 39.16278,-112.70806
# 38.99861,-113.38167
# 38.94306,-113.37833
# 38.945,-113.38222
# 38.67667,-113.30167
# 41.38333,-86.6
# 38.25,-86.16667
# 40.08528,-86.055
# 41.08333,-86.28333
# 38.91972,-85.94722
# 40.48333,-86.36667
# 41.6,-86.71667
# 40.41667,-86.88333
# 39.8,-84.81667
# 41.33333,-86.31667
# 39.5,-85.5
# 39.61667,-85.45
# 41.65,-86.21667
# 34.9,-110.18333
# 31.96185,-110.434183
# 31.59391,-111.37023
# 35.25,-112.5
# 34.38063,-114.16705
# 34.613316999999995,-113.398967
# 33.71333,-113.275
# 35.8675,-114.19167
# 34.685,-114.323
# 33.96667,-114.06667
# 34.72453,-114.20883
# 34.73245,-114.22257
# 34.71933,-114.20783
# 34.7345,-114.21717
# 34.70108,-114.18845
# 34.70337,-114.19097
# 33.88098,-111.78558
# 35.05,-111.03333
# 32.14833,-111.11167
# 31.7045,-110.77917
# 33.24558,-111.89633
# 34.45,-111.36667
# 35.0,-111.0
# 34.303329999999995,-112.16617
# 34.83333,-112.01667
# 31.91667,-111.5
# 32.319,-111.077
# 33.66348,-114.29207
# 32.295,-109.67
# 34.48333,-113.91667
# 33.68333,-112.26667
# 31.735,-110.75333
# 33.61,-111.72
# 34.71637,-114.22197
# 32.00415,-110.37503
# 33.03333,-112.61667
# 35.875,-114.23333
# 35.89,-114.16667
# 35.87333,-114.2
# 31.76167,-110.75
# 35.06639000000001,-114.0975
# 34.0,-111.0
# 33.75,-112.66667
# 32.35833,-112.40889
# 35.86333,-114.19333
# 35.83833,-114.16617
# 35.8895,-114.192
# 35.92333,-114.10167
# 33.5,-114.0
# 35.16867,-114.455
# 34.38667,-112.02833
# 33.69177,-113.63612
# 33.25,-112.05
# 32.73,-113.71
# 35.33333,-109.5
# 32.5,-111.28
# 34.13228,-112.70225
# 33.67248,-114.2917
# 34.71457,-114.19142
# 34.23333,-111.4
# 32.2,-111.0
# 34.68222,-114.33046000000002
# 34.7049,-114.34572
# 33.68085,-114.1958
# 32.446670000000005,-111.34667
# 35.65306,-114.02437
# 35.64552,-114.03069
# 35.6464,-114.02849
# 35.64645,-114.02853
# 35.62705,-114.04336
# 35.62723,-114.04323
# 35.66185,-114.0271
# 35.66375,-114.02698
# 35.69732,-114.032
# 35.67947,-114.04338
# 35.6448,-114.03452
# 35.62682,-114.04373
# 35.69733,-114.06167
# 35.63333,-114.08333
# 35.64133,-114.09
# 35.647,-114.0955
# 35.65868,-114.02573
# 35.64,-114.03285
# 35.62453,-114.04688
# 32.13333,-111.13333
# 34.756370000000004,-114.23435
# 34.75635,-114.2343
# 34.75873,-114.23342
# 34.75078,-114.22717
# 34.74667,-114.21
# 35.0,-112.0
# 32.16657,-111.11718
# 35.28333,-112.86667
# 32.48333,-111.56667
# 32.15833,-111.11333
# 35.91667,-114.43333
# 35.16993,-114.45585
# 33.91667,-112.55
# 31.85,-110.96667
# 32.25,-110.83333
# 35.8,-113.7
# 34.78698,-114.25052
# 34.25,-112.75
# 35.89,-114.20333
# 35.85667,-114.22333
# 33.96667,-112.73333
# 34.7,-113.6
# 32.56533,-111.7255
# 32.125,-109.83333
# 32.181670000000004,-109.7895
# 32.14202,-109.82423
# 32.0939,-109.88412
# 32.11288,-109.89265
# 32.18843,-109.84563
# 32.07667,-109.8455
# 35.2,-111.4
# 34.8197,-114.2761
# 34.82658,-114.27763
# 34.81923,-114.27735
# 21.3,-157.86667
# 21.3,-157.78333
# 38.41667,-77.16667
# 38.16667,-76.38333
# 39.71667,-77.3
# 39.41667,-79.15
# 40.0,-81.76666999999998
# 39.11667,-83.85
# 39.11667,-84.5
# 39.75,-84.16667
# 39.86667,-83.95
# 39.33333,-84.6
# 40.01667,-82.86667
# 40.66667,-84.35
# 38.66667,-82.78333
# 39.32,-82.37
# 40.76667,-81.95
# 29.94718,-90.10976
# 31.8,-92.75
# 30.51528,-91.01222
# 28.5475,-81.36222
# 26.26667,-81.75
# 28.83333,-81.68333
# 30.31167,-86.16667
# 26.68333,-80.8
# 38.13742,-119.75812
# 33.48472,-117.6625
# 38.80389,-120.90806
# 33.26667,-116.38333
# 38.295,-121.405
# 40.9,-123.1
# 32.91745,-114.767183
# 36.00217,-116.19633
# 33.01222,-114.86667
# 35.25,-118.09067
# 35.05017,-116.76683
# 35.04753,-116.73092
# 35.08808,-116.75398
# 35.0715,-116.77205
# 35.05605,-116.7763
# 35.09373,-116.76343
# 35.07667,-116.74667
# 35.05242,-116.7667
# 35.05878,-116.773
# 35.058170000000004,-116.7743
# 35.03815,-116.7531
# 35.074020000000004,-116.76117
# 35.05073,-116.76698
# 35.04625,-116.73547
# 35.05865,-116.76872
# 35.05847,-116.769
# 35.0501,-116.74443
# 35.03815,-116.7531
# 35.05893,-116.76872
# 35.059470000000005,-116.7685
# 35.06917,-116.7502
# 35.06785,-116.7494
# 35.07028,-116.74847
# 35.0925,-116.76083
# 35.05283,-116.76645
# 35.05283,-116.76538
# 35.06725,-116.74853
# 35.056020000000004,-116.72368
# 35.05607,-116.72365
# 35.07362,-116.76372
# 35.06847,-116.76905
# 35.05865,-116.76872
# 35.06152,-116.76295
# 35.07802,-116.76777
# 35.07,-116.77
# 35.05835,-116.77403
# 35.06888,-116.76197
# 35.05475,-116.75432
# 35.054520000000004,-116.73005
# 35.08838,-116.75283
# 35.05717,-116.7205
# 35.04008,-116.75553
# 35.03842,-116.75818
# 35.08958,-116.75007
# 35.05628,-116.73377
# 35.08758,-116.74603
# 35.059020000000004,-116.76892
# 35.05122,-116.76742
# 35.07118,-116.77162
# 35.0742,-116.7637
# 35.0751,-116.75038
# 35.29575,-117.4668
# 35.2755,-117.47833
# 35.29183,-117.47067
# 35.30233,-117.46017
# 35.31232,-117.45315
# 35.31227,-117.453
# 35.3114,-117.45342
# 35.28333,-117.48333
# 35.31833,-117.46667
# 35.3112,-117.45465
# 35.2758,-117.47877
# 35.31217,-117.453
# 35.31218,-117.45303
# 35.28528,-117.48305
# 35.28638,-117.48305
# 35.30455,-117.45817
# 35.3,-117.4605
# 35.3248,-117.47983
# 35.296,-117.472
# 35.296,-117.472
# 34.08333,-115.78333
# 34.216667,-115.05
# 34.65433,-117.59638
# 34.64667,-117.58108
# 34.63432,-117.56217
# 34.65783,-117.59892
# 34.611670000000004,-115.03333
# 35.37333,-116.90833
# 41.98,-120.54167
# 35.05102,-117.30672
# 35.050670000000004,-117.30095
# 35.0425,-117.30837
# 35.05523,-117.30257
# 35.05063,-117.30188
# 35.04722,-117.30752
# 35.04953,-117.26357
# 35.05193,-117.26138
# 35.04102,-117.27465
# 35.0421,-117.27512
# 35.04015,-117.27283
# 35.04568,-117.26658
# 35.03333,-117.28333
# 32.86667,-115.58333
# 35.33333,-115.31667
# 35.37788,-117.63728
# 34.51667,-117.98333
# 34.5,-116.95
# 34.5,-116.95
# 34.5,-116.95
# 34.5,-116.95
# 34.5,-116.95
# 34.5,-116.95
# 34.5,-116.95
# 34.5,-116.95
# 34.5,-116.95
# 34.5,-116.95
# 34.5,-116.95
# 34.5,-116.95
# 34.5,-116.95
# 34.50133,-116.96467
# 34.5095,-116.95583
# 34.5125,-116.95083
# 34.5,-116.95
# 34.48793,-116.9488
# 34.48868,-116.94985
# 34.4918,-116.943
# 34.493120000000005,-116.94662
# 34.49058,-116.95032
# 34.49095,-116.95038
# 34.49553,-116.9471
# 34.510870000000004,-116.93545
# 34.5001,-116.94217
# 34.48715,-116.95337
# 34.4875,-116.95567
# 34.486999999999995,-116.956
# 34.48708,-116.95797
# 34.4871,-116.9578
# 34.49015,-116.94985
# 34.4868,-116.95837
# 34.48793,-116.95638
# 34.48887,-116.95223
# 34.4921,-116.94308
# 34.48975,-116.94277
# 34.48595,-116.9637
# 34.48457,-116.96255
# 34.48413,-116.96083
# 34.486999999999995,-116.96512
# 34.48742,-116.9735
# 34.48613,-116.9739
# 34.486670000000004,-116.95833
# 34.48472,-116.96107
# 34.48728,-116.95833
# 34.525,-116.95333
# 34.486,-116.97275
# 34.51092,-116.93962
# 34.48972,-116.98128
# 34.48823,-116.97797
# 34.48075,-116.9788
# 34.48148,-116.95325
# 34.4887,-116.9788
# 34.487120000000004,-116.96147
# 34.48657,-116.9592
# 34.48662,-116.9564
# 34.48565,-116.95673
# 34.48703,-116.95595
# 34.48733,-116.96055
# 34.48738,-116.96065
# 34.48598,-116.95593
# 34.48388,-116.9501
# 34.91667,-117.83333
# 34.91667,-117.83333
# 34.44417,-114.8325
# 34.8,-118.5
# 32.83333,-116.06667
# 34.85958,-116.22113
# 34.46667,-115.23333
# 39.68333,-121.63333
# 37.46667,-118.0
# 33.18667,-114.91783
# 34.0,-115.78333
# 34.44567,-117.01083
# 35.4005,-117.66617
# 35.41667,-117.91667
# 35.58333,-117.56667
# 34.82793,-118.1464
# 34.83333,-118.06667
# 34.00056,-115.72972
# 36.0,-119.0
# 34.125,-115.56333
# 34.125,-115.56333
# 38.66667,-120.93333
# 35.51752000000001,-116.17607
# 35.37333,-116.125
# 35.34443,-116.11485
# 41.38333,-123.5
# 36.2058,-116.17042
# 36.20758,-116.16918
# 36.21153,-116.16785
# 36.17557,-116.159
# 36.18472,-116.14342
# 36.21017,-116.16825
# 35.25448,-117.10972
# 35.22358,-117.1136
# 35.24742,-117.0999
# 35.23533,-117.1005
# 35.238,-117.0365
# 35.23883,-117.02667
# 35.23833,-117.03283
# 35.236,-117.044
# 35.23583,-117.044
# 35.23633,-117.04317
# 35.23617,-117.043
# 35.23333,-117.03945
# 35.236,-117.04212
# 35.23667000000001,-117.03945
# 35.23858,-117.02628
# 35.23705,-117.01618
# 35.23625,-117.04638
# 32.87083,-115.7825
# 34.16667,-115.91667
# 34.075,-116.01667
# 35.46667,-115.66667
# 34.25,-119.3
# 35.37358,-115.34388
# 32.95,-114.666667
# 33.98333,-115.68333
# 46.88333,-102.31667
# 48.68333,-97.16667
# 48.78333,-97.35
# 48.66667,-97.11667
# 46.38333,-101.23333
# 48.71667,-97.3
# 46.61667,-98.5
# 46.36667,-101.95
# 48.0,-97.93333
# 47.98333,-103.65
# 44.97917,-122.96944
# 42.03839,-120.58942
# 42.16667,-121.85
# 45.5,-119.5
# 42.53333,-122.875
# 45.36667,-122.58333
# 41.2,-73.13333
# 41.266667,-73.266667
# 41.7,-72.65
# 41.71056,-72.67361
# 42.06667,-104.16667
# 41.5,-104.1
# 41.41667,-104.1
# 44.5,-104.2
# 43.7,-104.7
# 42.91667,-104.41667
# 41.78333,-104.28333
# 44.33823,-107.67405
# 42.76667,-104.35
# 41.18333,-104.06667
# 41.65,-109.025
# 41.23333,-104.98333
# 43.0,-107.16667
# 43.46667,-106.76667
# 45.58333,-122.35
# 46.83333,-117.25
# 46.57056,-117.09861
# 47.25,-122.41667
# 47.767778,-119.876389
# 47.70667,-119.83
# 64.88333,-163.16666999999995
# 59.33333,-136.0
# 55.18333000000001,-162.55
# 65.38333,-146.26667
# 37.83333,-80.31667
# 37.9,-82.38333
# 38.9,-79.18333
# 46.43333,-109.83333
# 46.68333,-112.55
# 45.6,-110.58333
# 46.1,-111.4
# 46.78333,-108.56667
# 46.7,-110.13333
# 45.0,-114.0
# 42.63333,-114.83333
# 42.33333,-113.7
# 43.8,-117.0
# 44.93389000000001,-116.43167
# 43.72444,-116.91167
# 42.31667,-72.63333
# ['42.53333,-85.88333', '43.76111,-84.50778000000003', '44.51667,-83.95', '42.38467,-83.6115', '42.96667,-85.76666999999998', '46.07944000000001,-88.55972', '44.64694,-85.13667', '43.86667,-85.51666999999998', '41.78333,-84.18333', '44.61667,-70.75', '44.38333,-68.75', '44.08333,-69.48333000000001', '44.36667,-69.2', '43.827,-70.24717', '38.5,-94.3', '36.75,-93.5', '37.26667,-89.58333', '39.08333,-94.4', '37.91667,-92.08333', '39.8,-91.5', '38.7,-90.23333', '38.68333,-91.15', '37.06667,-93.55', '38.3,-94.36667', '40.266667,-94.683333', '39.59167,-94.92194', '39.61667,-94.86667', '38.65,-94.33333', '36.82444,-93.76111', '36.53333,-91.8', '40.2875,-95.37667', '36.55,-93.1', '37.73333,-89.85', '37.2375,-92.78694', '37.75,-90.5', '37.96667,-90.31667', '31.805,-97.01', '33.6,-96.46667', '31.83333,-98.83333', '30.83333,-97.76667', '32.675,-94.51167', '29.45,-96.0', '30.75,-95.95', '31.60833,-102.85833', '30.125,-103.11667', '30.7,-96.11667', '31.25,-99.03333', '32.16667,-95.1', '33.85,-101.8', '32.59033,-101.77217', '35.15,-102.71667', '34.2,-101.5', '33.1,-96.7', '33.1,-102.95', '33.7825,-102.18111', '32.9,-102.28333', '31.66,-96.97167', '31.76667,-99.98333', '30.78333,-103.46667', '30.83333,-97.5', '34.0,-101.5', '33.58333,-99.8', '33.59167,-103.02667', '29.87861,-96.87222', '29.86306,-96.92667', '29.8,-98.8', '31.05,-99.46667', '34.35,-101.4', '33.28333,-102.96667', '33.275,-102.96', '33.275,-102.96', '33.21667,-102.18333', '33.21667,-102.18333', '33.135,-102.27833', '33.21667,-102.18333', '32.246109999999994,-99.99306', '32.03333,-99.25', '28.41667,-98.25', '34.96667,-101.93333', '31.91667,-98.03333', '29.82806,-96.90861', '34.2,-100.48333', '36.2,-102.45', '35.71667,-102.28333', '29.0,-103.25', '34.02806,-102.68', '34.905,-100.91333', '34.93611,-100.94167', '34.34667,-101.49', '34.34833,-101.65833', '32.31667,-97.41667', '32.01667,-98.7', '31.991670000000006,-98.65167', '32.0,-101.5', '31.75,-97.75', '29.01667,-97.28333', '36.04333,-102.40833', '30.75,-104.25', '29.1,-97.6', '29.00833,-97.70556', '34.86,-102.12', '34.86,-102.12', '29.366670000000006,-100.96667', '33.0,-97.0', '33.07139,-102.80028', '33.51667,-95.3', '33.51667,-95.3', '33.81667,-97.0', '34.58333,-102.16667', '34.48333,-102.32833', '33.97917,-101.2', '35.9,-101.9', '35.925,-101.895', '33.81667,-100.51667', '32.63333,-96.86667', '34.28333,-101.83333', '34.28333,-101.83333', '31.78333,-106.23333', '33.71667,-100.83333', '33.9,-101.75', '35.98333,-101.9', '34.47,-101.75833', '34.10139,-102.65', '34.0,-101.5', '31.38972,-99.40583', '34.26667,-101.56667', '34.29833,-101.68333', '34.43333,-102.51667', '32.5225,-102.705', '33.98333,-101.28333', '33.98333,-101.33333', '32.8,-101.11667', '32.90333,-101.16278', '33.50667,-97.65139', '33.49556,-97.58861', '30.91667,-103.06667', '33.1,-102.26667', '32.33333,-102.745', '34.54,-102.56833', '32.7,-101.6', '32.83333,-102.73333', '32.25,-97.71667', '33.18139,-102.40139', '32.788333,-101.938333', '33.11667,-101.58333', '33.71667,-102.81667', '36.33333,-101.4', '29.5,-98.0', '34.05,-101.75', '34.05,-101.75', '31.59333,-98.25', '35.68,-101.99333', '34.59333,-101.99333', '34.58333,-102.05', '34.80167,-101.56667', '34.37718,-102.11672', '33.99833,-102.17667', '35.94167,-102.16', '33.21333,-99.73167', '33.795,-102.24167', '33.75,-98.83333', '33.5,-96.6', '34.54,-102.59433', '31.91667,-106.15', '31.91667,-106.15', '31.96667,-97.86667', '30.625,-97.53333', '30.5,-99.83333', '34.62333,-101.91667', '34.67167,-101.815', '34.67167,-101.815', '34.67167,-101.815', '32.58333,-96.41667', '29.4,-98.5', '30.41667,-99.4', '34.35833,-101.73', '34.35833,-101.73', '34.33833,-101.71667', '34.38333,-101.71667', '29.975,-97.86667', '26.27167,-97.90167', '35.56667,-100.66667', '34.53333,-101.7', '32.88333,-101.88333', '34.5,-102.75', '30.6,-97.9', '34.61139,-100.855', '34.655,-101.64', '34.655,-101.64', '30.52213,-99.73698', '34.15,-101.3', '34.25972,-101.40833', '32.9,-102.28333', '32.99167,-102.38833', '32.98333,-102.38833', '33.28944,-102.54306', '33.6, ...
# 42.53333,-85.88333
# {'results': [{'dataset': 'etopo1', 'elevation': 225.0, 'location': {'lat': 42.53333, 'lng': -85.88333}}], 'status': 'OK'}
# 43.76111,-84.50778000000003
# {'results': [{'dataset': 'etopo1', 'elevation': 218.0, 'location': {'lat': 43.76111, 'lng': -84.50778000000003}}], 'status': 'OK'}
# 44.51667,-83.95
# {'results': [{'dataset': 'etopo1', 'elevation': 387.0, 'location': {'lat': 44.51667, 'lng': -83.95}}], 'status': 'OK'}
# 42.38467,-83.6115
# {'results': [{'dataset': 'etopo1', 'elevation': 279.0, 'location': {'lat': 42.38467, 'lng': -83.6115}}], 'status': 'OK'}
# 42.96667,-85.76666999999998
# {'results': [{'dataset': 'etopo1', 'elevation': 225.0, 'location': {'lat': 42.96667, 'lng': -85.76666999999998}}], 'status': 'OK'}
# 46.07944000000001,-88.55972
# {'results': [{'dataset': 'etopo1', 'elevation': 510.0, 'location': {'lat': 46.07944000000001, 'lng': -88.55972}}], 'status': 'OK'}
# 44.64694,-85.13667
# {'results': [{'dataset': 'etopo1', 'elevation': 355.0, 'location': {'lat': 44.64694, 'lng': -85.13667}}], 'status': 'OK'}
# 43.86667,-85.51666999999998
# {'results': [{'dataset': 'etopo1', 'elevation': 329.0, 'location': {'lat': 43.86667, 'lng': -85.51666999999998}}], 'status': 'OK'}
# 41.78333,-84.18333
# {'results': [{'dataset': 'etopo1', 'elevation': 243.0, 'location': {'lat': 41.78333, 'lng': -84.18333}}], 'status': 'OK'}
# 44.61667,-70.75
# {'results': [{'dataset': 'etopo1', 'elevation': 220.0, 'location': {'lat': 44.61667, 'lng': -70.75}}], 'status': 'OK'}
# 44.38333,-68.75
# {'results': [{'dataset': 'etopo1', 'elevation': 25.0, 'location': {'lat': 44.38333, 'lng': -68.75}}], 'status': 'OK'}
# 44.08333,-69.48333000000001
# {'results': [{'dataset': 'etopo1', 'elevation': 44.0, 'location': {'lat': 44.08333, 'lng': -69.48333000000001}}], 'status': 'OK'}
# 44.36667,-69.2
# {'results': [{'dataset': 'etopo1', 'elevation': 76.0, 'location': {'lat': 44.36667, 'lng': -69.2}}], 'status': 'OK'}
# 43.827,-70.24717
# {'results': [{'dataset': 'etopo1', 'elevation': 68.0, 'location': {'lat': 43.827, 'lng': -70.24717}}], 'status': 'OK'}
# 38.5,-94.3
# {'results': [{'dataset': 'etopo1', 'elevation': 264.0, 'location': {'lat': 38.5, 'lng': -94.3}}], 'status': 'OK'}
# 36.75,-93.5
# {'results': [{'dataset': 'etopo1', 'elevation': 294.0, 'location': {'lat': 36.75, 'lng': -93.5}}], 'status': 'OK'}
# 37.26667,-89.58333
# {'results': [{'dataset': 'etopo1', 'elevation': 123.0, 'location': {'lat': 37.26667, 'lng': -89.58333}}], 'status': 'OK'}
# 39.08333,-94.4
# {'results': [{'dataset': 'etopo1', 'elevation': 292.0, 'location': {'lat': 39.08333, 'lng': -94.4}}], 'status': 'OK'}
# 37.91667,-92.08333
# {'results': [{'dataset': 'etopo1', 'elevation': 281.0, 'location': {'lat': 37.91667, 'lng': -92.08333}}], 'status': 'OK'}
# 39.8,-91.5
# {'results': [{'dataset': 'etopo1', 'elevation': 179.0, 'location': {'lat': 39.8, 'lng': -91.5}}], 'status': 'OK'}
# 38.7,-90.23333
# {'results': [{'dataset': 'etopo1', 'elevation': 147.0, 'location': {'lat': 38.7, 'lng': -90.23333}}], 'status': 'OK'}
# 38.68333,-91.15
# {'results': [{'dataset': 'etopo1', 'elevation': 173.0, 'location': {'lat': 38.68333, 'lng': -91.15}}], 'status': 'OK'}
# 37.06667,-93.55
# {'results': [{'dataset': 'etopo1', 'elevation': 416.0, 'location': {'lat': 37.06667, 'lng': -93.55}}], 'status': 'OK'}
# 38.3,-94.36667
# {'results': [{'dataset': 'etopo1', 'elevation': 257.0, 'location': {'lat': 38.3, 'lng': -94.36667}}], 'status': 'OK'}
# 40.266667,-94.683333
# {'results': [{'dataset': 'etopo1', 'elevation': 318.0, 'location': {'lat': 40.266667, 'lng': -94.683333}}], 'status': 'OK'}
# 39.59167,-94.92194
# {'results': [{'dataset': 'etopo1', 'elevation': 339.0, 'location': {'lat': 39.59167, 'lng': -94.92194}}], 'status': 'OK'}
# 39.61667,-94.86667
# {'results': [{'dataset': 'etopo1', 'elevation': 329.0, 'location': {'lat': 39.61667, 'lng': -94.86667}}], 'status': 'OK'}
# 38.65,-94.33333
# {'results': [{'dataset': 'etopo1', 'elevation': 295.0, 'location': {'lat': 38.65, 'lng': -94.33333}}], 'status': 'OK'}
# 36.82444,-93.76111
# {'results': [{'dataset': 'etopo1', 'elevation': 391.0, 'location': {'lat': 36.82444, 'lng': -93.76111}}], 'status': 'OK'}
# 36.53333,-91.8
# {'results': [{'dataset': 'etopo1', 'elevation': 269.0, 'location': {'lat': 36.53333, 'lng': -91.8}}], 'status': 'OK'}
# 40.2875,-95.37667
# {'results': [{'dataset': 'etopo1', 'elevation': 305.0, 'location': {'lat': 40.2875, 'lng': -95.37667}}], 'status': 'OK'}
# 36.55,-93.1
# {'results': [{'dataset': 'etopo1', 'elevation': 270.0, 'location': {'lat': 36.55, 'lng': -93.1}}], 'status': 'OK'}
# 37.73333,-89.85
# {'results': [{'dataset': 'etopo1', 'elevation': 162.0, 'location': {'lat': 37.73333, 'lng': -89.85}}], 'status': 'OK'}
# 37.2375,-92.78694
# {'results': [{'dataset': 'etopo1', 'elevation': 481.0, 'location': {'lat': 37.2375, 'lng': -92.78694}}], 'status': 'OK'}
# 37.75,-90.5
# {'results': [{'dataset': 'etopo1', 'elevation': 296.0, 'location': {'lat': 37.75, 'lng': -90.5}}], 'status': 'OK'}
# 37.96667,-90.31667
# {'results': [{'dataset': 'etopo1', 'elevation': 234.0, 'location': {'lat': 37.96667, 'lng': -90.31667}}], 'status': 'OK'}
# 31.805,-97.01
# {'results': [{'dataset': 'etopo1', 'elevation': 170.0, 'location': {'lat': 31.805, 'lng': -97.01}}], 'status': 'OK'}
# 33.6,-96.46667
# {'results': [{'dataset': 'etopo1', 'elevation': 216.0, 'location': {'lat': 33.6, 'lng': -96.46667}}], 'status': 'OK'}
# 31.83333,-98.83333
# {'results': [{'dataset': 'etopo1', 'elevation': 534.0, 'location': {'lat': 31.83333, 'lng': -98.83333}}], 'status': 'OK'}
# 30.83333,-97.76667
# {'results': [{'dataset': 'etopo1', 'elevation': 310.0, 'location': {'lat': 30.83333, 'lng': -97.76667}}], 'status': 'OK'}
# 32.675,-94.51167
# {'results': [{'dataset': 'etopo1', 'elevation': 93.0, 'location': {'lat': 32.675, 'lng': -94.51167}}], 'status': 'OK'}
# 29.45,-96.0
# {'results': [{'dataset': 'etopo1', 'elevation': 31.0, 'location': {'lat': 29.45, 'lng': -96.0}}], 'status': 'OK'}
# 30.75,-95.95
# {'results': [{'dataset': 'etopo1', 'elevation': 96.0, 'location': {'lat': 30.75, 'lng': -95.95}}], 'status': 'OK'}
# 31.60833,-102.85833
# {'results': [{'dataset': 'etopo1', 'elevation': 812.0, 'location': {'lat': 31.60833, 'lng': -102.85833}}], 'status': 'OK'}
# 30.125,-103.11667
# {'results': [{'dataset': 'etopo1', 'elevation': 1220.0, 'location': {'lat': 30.125, 'lng': -103.11667}}], 'status': 'OK'}
# 30.7,-96.11667
# {'results': [{'dataset': 'etopo1', 'elevation': 85.0, 'location': {'lat': 30.7, 'lng': -96.11667}}], 'status': 'OK'}
# 31.25,-99.03333
# {'results': [{'dataset': 'etopo1', 'elevation': 497.0, 'location': {'lat': 31.25, 'lng': -99.03333}}], 'status': 'OK'}
# 32.16667,-95.1
# {'results': [{'dataset': 'etopo1', 'elevation': 143.0, 'location': {'lat': 32.16667, 'lng': -95.1}}], 'status': 'OK'}
# 33.85,-101.8
# {'results': [{'dataset': 'etopo1', 'elevation': 1016.0, 'location': {'lat': 33.85, 'lng': -101.8}}], 'status': 'OK'}
# 32.59033,-101.77217
# {'results': [{'dataset': 'etopo1', 'elevation': 868.0, 'location': {'lat': 32.59033, 'lng': -101.77217}}], 'status': 'OK'}
# 35.15,-102.71667
# {'results': [{'dataset': 'etopo1', 'elevation': 1268.0, 'location': {'lat': 35.15, 'lng': -102.71667}}], 'status': 'OK'}
# 34.2,-101.5
# {'results': [{'dataset': 'etopo1', 'elevation': 1005.0, 'location': {'lat': 34.2, 'lng': -101.5}}], 'status': 'OK'}
# 33.1,-96.7
# {'results': [{'dataset': 'etopo1', 'elevation': 200.0, 'location': {'lat': 33.1, 'lng': -96.7}}], 'status': 'OK'}
# 33.1,-102.95
# {'results': [{'dataset': 'etopo1', 'elevation': 1126.0, 'location': {'lat': 33.1, 'lng': -102.95}}], 'status': 'OK'}
# 33.7825,-102.18111
# {'results': [{'dataset': 'etopo1', 'elevation': 1037.0, 'location': {'lat': 33.7825, 'lng': -102.18111}}], 'status': 'OK'}
# 32.9,-102.28333
# {'results': [{'dataset': 'etopo1', 'elevation': 962.0, 'location': {'lat': 32.9, 'lng': -102.28333}}], 'status': 'OK'}
# 31.66,-96.97167
# {'results': [{'dataset': 'etopo1', 'elevation': 163.0, 'location': {'lat': 31.66, 'lng': -96.97167}}], 'status': 'OK'}
# 31.76667,-99.98333
# {'results': [{'dataset': 'etopo1', 'elevation': 526.0, 'location': {'lat': 31.76667, 'lng': -99.98333}}], 'status': 'OK'}
# 30.78333,-103.46667
# {'results': [{'dataset': 'etopo1', 'elevation': 1078.0, 'location': {'lat': 30.78333, 'lng': -103.46667}}], 'status': 'OK'}
# 30.83333,-97.5
# {'results': [{'dataset': 'etopo1', 'elevation': 212.0, 'location': {'lat': 30.83333, 'lng': -97.5}}], 'status': 'OK'}
# 34.0,-101.5
# {'results': [{'dataset': 'etopo1', 'elevation': 982.0, 'location': {'lat': 34.0, 'lng': -101.5}}], 'status': 'OK'}
# 33.58333,-99.8
# {'results': [{'dataset': 'etopo1', 'elevation': 449.0, 'location': {'lat': 33.58333, 'lng': -99.8}}], 'status': 'OK'}
# 33.59167,-103.02667
# {'results': [{'dataset': 'etopo1', 'elevation': 1208.0, 'location': {'lat': 33.59167, 'lng': -103.02667}}], 'status': 'OK'}
# 29.87861,-96.87222
# {'results': [{'dataset': 'etopo1', 'elevation': 122.0, 'location': {'lat': 29.87861, 'lng': -96.87222}}], 'status': 'OK'}
# 29.86306,-96.92667
# {'results': [{'dataset': 'etopo1', 'elevation': 96.0, 'location': {'lat': 29.86306, 'lng': -96.92667}}], 'status': 'OK'}
# 29.8,-98.8
# {'results': [{'dataset': 'etopo1', 'elevation': 533.0, 'location': {'lat': 29.8, 'lng': -98.8}}], 'status': 'OK'}
# 31.05,-99.46667
# {'results': [{'dataset': 'etopo1', 'elevation': 590.0, 'location': {'lat': 31.05, 'lng': -99.46667}}], 'status': 'OK'}
# 34.35,-101.4
# {'results': [{'dataset': 'etopo1', 'elevation': 1001.0, 'location': {'lat': 34.35, 'lng': -101.4}}], 'status': 'OK'}
# 33.28333,-102.96667
# {'results': [{'dataset': 'etopo1', 'elevation': 1162.0, 'location': {'lat': 33.28333, 'lng': -102.96667}}], 'status': 'OK'}
# 33.275,-102.96
# {'results': [{'dataset': 'etopo1', 'elevation': 1152.0, 'location': {'lat': 33.275, 'lng': -102.96}}], 'status': 'OK'}
# 33.275,-102.96
# {'results': [{'dataset': 'etopo1', 'elevation': 1152.0, 'location': {'lat': 33.275, 'lng': -102.96}}], 'status': 'OK'}
# 33.21667,-102.18333
# {'results': [{'dataset': 'etopo1', 'elevation': 989.0, 'location': {'lat': 33.21667, 'lng': -102.18333}}], 'status': 'OK'}
# 33.21667,-102.18333
# {'results': [{'dataset': 'etopo1', 'elevation': 989.0, 'location': {'lat': 33.21667, 'lng': -102.18333}}], 'status': 'OK'}
# 33.135,-102.27833
# {'results': [{'dataset': 'etopo1', 'elevation': 1006.0, 'location': {'lat': 33.135, 'lng': -102.27833}}], 'status': 'OK'}
# 33.21667,-102.18333
# {'results': [{'dataset': 'etopo1', 'elevation': 989.0, 'location': {'lat': 33.21667, 'lng': -102.18333}}], 'status': 'OK'}
# 32.246109999999994,-99.99306
# {'results': [{'dataset': 'etopo1', 'elevation': 681.0, 'location': {'lat': 32.246109999999994, 'lng': -99.99306}}], 'status': 'OK'}
# 32.03333,-99.25
# {'results': [{'dataset': 'etopo1', 'elevation': 486.0, 'location': {'lat': 32.03333, 'lng': -99.25}}], 'status': 'OK'}
# 28.41667,-98.25
# {'results': [{'dataset': 'etopo1', 'elevation': 47.0, 'location': {'lat': 28.41667, 'lng': -98.25}}], 'status': 'OK'}
# 34.96667,-101.93333
# {'results': [{'dataset': 'etopo1', 'elevation': 1075.0, 'location': {'lat': 34.96667, 'lng': -101.93333}}], 'status': 'OK'}
# 31.91667,-98.03333
# {'results': [{'dataset': 'etopo1', 'elevation': 339.0, 'location': {'lat': 31.91667, 'lng': -98.03333}}], 'status': 'OK'}
# 29.82806,-96.90861
# {'results': [{'dataset': 'etopo1', 'elevation': 118.0, 'location': {'lat': 29.82806, 'lng': -96.90861}}], 'status': 'OK'}
# 34.2,-100.48333
# {'results': [{'dataset': 'etopo1', 'elevation': 602.0, 'location': {'lat': 34.2, 'lng': -100.48333}}], 'status': 'OK'}
# 36.2,-102.45
# {'results': [{'dataset': 'etopo1', 'elevation': 1230.0, 'location': {'lat': 36.2, 'lng': -102.45}}], 'status': 'OK'}
# 35.71667,-102.28333
# {'results': [{'dataset': 'etopo1', 'elevation': 1147.0, 'location': {'lat': 35.71667, 'lng': -102.28333}}], 'status': 'OK'}
# 29.0,-103.25
# {'results': [{'dataset': 'etopo1', 'elevation': 624.0, 'location': {'lat': 29.0, 'lng': -103.25}}], 'status': 'OK'}
# 34.02806,-102.68
# {'results': [{'dataset': 'etopo1', 'elevation': 1185.0, 'location': {'lat': 34.02806, 'lng': -102.68}}], 'status': 'OK'}
# 34.905,-100.91333
# {'results': [{'dataset': 'etopo1', 'elevation': 873.0, 'location': {'lat': 34.905, 'lng': -100.91333}}], 'status': 'OK'}
# 34.93611,-100.94167
# {'results': [{'dataset': 'etopo1', 'elevation': 868.0, 'location': {'lat': 34.93611, 'lng': -100.94167}}], 'status': 'OK'}
# 34.34667,-101.49
# {'results': [{'dataset': 'etopo1', 'elevation': 1010.0, 'location': {'lat': 34.34667, 'lng': -101.49}}], 'status': 'OK'}
# 34.34833,-101.65833
# {'results': [{'dataset': 'etopo1', 'elevation': 1035.0, 'location': {'lat': 34.34833, 'lng': -101.65833}}], 'status': 'OK'}
# 32.31667,-97.41667
# {'results': [{'dataset': 'etopo1', 'elevation': 243.0, 'location': {'lat': 32.31667, 'lng': -97.41667}}], 'status': 'OK'}
# 32.01667,-98.7
# {'results': [{'dataset': 'etopo1', 'elevation': 423.0, 'location': {'lat': 32.01667, 'lng': -98.7}}], 'status': 'OK'}
# 31.991670000000006,-98.65167
# {'results': [{'dataset': 'etopo1', 'elevation': 407.0, 'location': {'lat': 31.991670000000006, 'lng': -98.65167}}], 'status': 'OK'}
# 32.0,-101.5
# {'results': [{'dataset': 'etopo1', 'elevation': 784.0, 'location': {'lat': 32.0, 'lng': -101.5}}], 'status': 'OK'}
# 31.75,-97.75
# {'results': [{'dataset': 'etopo1', 'elevation': 299.0, 'location': {'lat': 31.75, 'lng': -97.75}}], 'status': 'OK'}
# 29.01667,-97.28333
# {'results': [{'dataset': 'etopo1', 'elevation': 80.0, 'location': {'lat': 29.01667, 'lng': -97.28333}}], 'status': 'OK'}
# 36.04333,-102.40833
# {'results': [{'dataset': 'etopo1', 'elevation': 1203.0, 'location': {'lat': 36.04333, 'lng': -102.40833}}], 'status': 'OK'}
# 30.75,-104.25
# {'results': [{'dataset': 'etopo1', 'elevation': 1687.0, 'location': {'lat': 30.75, 'lng': -104.25}}], 'status': 'OK'}
# 29.1,-97.6
# {'results': [{'dataset': 'etopo1', 'elevation': 149.0, 'location': {'lat': 29.1, 'lng': -97.6}}], 'status': 'OK'}
# 29.00833,-97.70556
# {'results': [{'dataset': 'etopo1', 'elevation': 119.0, 'location': {'lat': 29.00833, 'lng': -97.70556}}], 'status': 'OK'}
# 34.86,-102.12
# {'results': [{'dataset': 'etopo1', 'elevation': 1127.0, 'location': {'lat': 34.86, 'lng': -102.12}}], 'status': 'OK'}
# 34.86,-102.12
# {'results': [{'dataset': 'etopo1', 'elevation': 1127.0, 'location': {'lat': 34.86, 'lng': -102.12}}], 'status': 'OK'}
# 29.366670000000006,-100.96667
# {'results': [{'dataset': 'etopo1', 'elevation': 288.0, 'location': {'lat': 29.366670000000006, 'lng': -100.96667}}], 'status': 'OK'}
# 33.0,-97.0
# {'results': [{'dataset': 'etopo1', 'elevation': 167.0, 'location': {'lat': 33.0, 'lng': -97.0}}], 'status': 'OK'}
# 33.07139,-102.80028
# {'results': [{'dataset': 'etopo1', 'elevation': 1094.0, 'location': {'lat': 33.07139, 'lng': -102.80028}}], 'status': 'OK'}
# 33.51667,-95.3
# ...
# {'results': [{'dataset': 'etopo1', 'elevation': 752.0, 'location': {'lat': 36.21017, 'lng': -116.16825}}], 'status': 'OK'}
# 35.25448,-117.10972
# {'results': [{'dataset': 'etopo1', 'elevation': 921.0, 'location': {'lat': 35.25448, 'lng': -117.10972}}], 'status': 'OK'}
# 35.22358,-117.1136
# {'results': [{'dataset': 'etopo1', 'elevation': 920.0, 'location': {'lat': 35.22358, 'lng': -117.1136}}], 'status': 'OK'}
# 35.24742,-117.0999
# {'results': [{'dataset': 'etopo1', 'elevation': 920.0, 'location': {'lat': 35.24742, 'lng': -117.0999}}], 'status': 'OK'}
# 35.23533,-117.1005
# {'results': [{'dataset': 'etopo1', 'elevation': 920.0, 'location': {'lat': 35.23533, 'lng': -117.1005}}], 'status': 'OK'}
# 35.238,-117.0365
# {'results': [{'dataset': 'etopo1', 'elevation': 918.0, 'location': {'lat': 35.238, 'lng': -117.0365}}], 'status': 'OK'}
# 35.23883,-117.02667
# {'results': [{'dataset': 'etopo1', 'elevation': 917.0, 'location': {'lat': 35.23883, 'lng': -117.02667}}], 'status': 'OK'}
# 35.23833,-117.03283
# {'results': [{'dataset': 'etopo1', 'elevation': 917.0, 'location': {'lat': 35.23833, 'lng': -117.03283}}], 'status': 'OK'}
# 35.236,-117.044
# {'results': [{'dataset': 'etopo1', 'elevation': 918.0, 'location': {'lat': 35.236, 'lng': -117.044}}], 'status': 'OK'}
# 35.23583,-117.044
# {'results': [{'dataset': 'etopo1', 'elevation': 918.0, 'location': {'lat': 35.23583, 'lng': -117.044}}], 'status': 'OK'}
# 35.23633,-117.04317
# {'results': [{'dataset': 'etopo1', 'elevation': 918.0, 'location': {'lat': 35.23633, 'lng': -117.04317}}], 'status': 'OK'}
# 35.23617,-117.043
# {'results': [{'dataset': 'etopo1', 'elevation': 918.0, 'location': {'lat': 35.23617, 'lng': -117.043}}], 'status': 'OK'}
# 35.23333,-117.03945
# {'results': [{'dataset': 'etopo1', 'elevation': 918.0, 'location': {'lat': 35.23333, 'lng': -117.03945}}], 'status': 'OK'}
# 35.236,-117.04212
# {'results': [{'dataset': 'etopo1', 'elevation': 918.0, 'location': {'lat': 35.236, 'lng': -117.04212}}], 'status': 'OK'}
# 35.23667000000001,-117.03945
# {'results': [{'dataset': 'etopo1', 'elevation': 918.0, 'location': {'lat': 35.23667000000001, 'lng': -117.03945}}], 'status': 'OK'}
# 35.23858,-117.02628
# {'results': [{'dataset': 'etopo1', 'elevation': 917.0, 'location': {'lat': 35.23858, 'lng': -117.02628}}], 'status': 'OK'}
# 35.23705,-117.01618
# {'results': [{'dataset': 'etopo1', 'elevation': 918.0, 'location': {'lat': 35.23705, 'lng': -117.01618}}], 'status': 'OK'}
# 35.23625,-117.04638
# {'results': [{'dataset': 'etopo1', 'elevation': 918.0, 'location': {'lat': 35.23625, 'lng': -117.04638}}], 'status': 'OK'}
# 32.87083,-115.7825
# {'results': [{'dataset': 'etopo1', 'elevation': 4.0, 'location': {'lat': 32.87083, 'lng': -115.7825}}], 'status': 'OK'}
# 34.16667,-115.91667
# {'results': [{'dataset': 'etopo1', 'elevation': 493.0, 'location': {'lat': 34.16667, 'lng': -115.91667}}], 'status': 'OK'}
# 34.075,-116.01667
# {'results': [{'dataset': 'etopo1', 'elevation': 855.0, 'location': {'lat': 34.075, 'lng': -116.01667}}], 'status': 'OK'}
# 35.46667,-115.66667
# {'results': [{'dataset': 'etopo1', 'elevation': 1161.0, 'location': {'lat': 35.46667, 'lng': -115.66667}}], 'status': 'OK'}
# 34.25,-119.3
# {'results': [{'dataset': 'etopo1', 'elevation': -18.0, 'location': {'lat': 34.25, 'lng': -119.3}}], 'status': 'OK'}
# 35.37358,-115.34388
# {'results': [{'dataset': 'etopo1', 'elevation': 906.0, 'location': {'lat': 35.37358, 'lng': -115.34388}}], 'status': 'OK'}
# 32.95,-114.666667
# {'results': [{'dataset': 'etopo1', 'elevation': 294.0, 'location': {'lat': 32.95, 'lng': -114.666667}}], 'status': 'OK'}
# 33.98333,-115.68333
# {'results': [{'dataset': 'etopo1', 'elevation': 471.0, 'location': {'lat': 33.98333, 'lng': -115.68333}}], 'status': 'OK'}
# 46.88333,-102.31667
# {'results': [{'dataset': 'etopo1', 'elevation': 747.0, 'location': {'lat': 46.88333, 'lng': -102.31667}}], 'status': 'OK'}
# 48.68333,-97.16667
# {'results': [{'dataset': 'etopo1', 'elevation': 238.0, 'location': {'lat': 48.68333, 'lng': -97.16667}}], 'status': 'OK'}
# 48.78333,-97.35
# {'results': [{'dataset': 'etopo1', 'elevation': 243.0, 'location': {'lat': 48.78333, 'lng': -97.35}}], 'status': 'OK'}
# 48.66667,-97.11667
# {'results': [{'dataset': 'etopo1', 'elevation': 237.0, 'location': {'lat': 48.66667, 'lng': -97.11667}}], 'status': 'OK'}
# 46.38333,-101.23333
# {'results': [{'dataset': 'etopo1', 'elevation': 610.0, 'location': {'lat': 46.38333, 'lng': -101.23333}}], 'status': 'OK'}
# 48.71667,-97.3
# {'results': [{'dataset': 'etopo1', 'elevation': 245.0, 'location': {'lat': 48.71667, 'lng': -97.3}}], 'status': 'OK'}
# 46.61667,-98.5
# {'results': [{'dataset': 'etopo1', 'elevation': 442.0, 'location': {'lat': 46.61667, 'lng': -98.5}}], 'status': 'OK'}
# 46.36667,-101.95
# {'results': [{'dataset': 'etopo1', 'elevation': 712.0, 'location': {'lat': 46.36667, 'lng': -101.95}}], 'status': 'OK'}
# 48.0,-97.93333
# {'results': [{'dataset': 'etopo1', 'elevation': 466.0, 'location': {'lat': 48.0, 'lng': -97.93333}}], 'status': 'OK'}
# 47.98333,-103.65
# {'results': [{'dataset': 'etopo1', 'elevation': 682.0, 'location': {'lat': 47.98333, 'lng': -103.65}}], 'status': 'OK'}
# 44.97917,-122.96944
# {'results': [{'dataset': 'etopo1', 'elevation': 57.0, 'location': {'lat': 44.97917, 'lng': -122.96944}}], 'status': 'OK'}
# 42.03839,-120.58942
# {'results': [{'dataset': 'etopo1', 'elevation': 1754.0, 'location': {'lat': 42.03839, 'lng': -120.58942}}], 'status': 'OK'}
# 42.16667,-121.85
# {'results': [{'dataset': 'etopo1', 'elevation': 1282.0, 'location': {'lat': 42.16667, 'lng': -121.85}}], 'status': 'OK'}
# 45.5,-119.5
# {'results': [{'dataset': 'etopo1', 'elevation': 593.0, 'location': {'lat': 45.5, 'lng': -119.5}}], 'status': 'OK'}
# 42.53333,-122.875
# {'results': [{'dataset': 'etopo1', 'elevation': 443.0, 'location': {'lat': 42.53333, 'lng': -122.875}}], 'status': 'OK'}
# 45.36667,-122.58333
# {'results': [{'dataset': 'etopo1', 'elevation': 34.0, 'location': {'lat': 45.36667, 'lng': -122.58333}}], 'status': 'OK'}
# 41.2,-73.13333
# {'results': [{'dataset': 'etopo1', 'elevation': 18.0, 'location': {'lat': 41.2, 'lng': -73.13333}}], 'status': 'OK'}
# 41.266667,-73.266667
# {'results': [{'dataset': 'etopo1', 'elevation': 117.0, 'location': {'lat': 41.266667, 'lng': -73.266667}}], 'status': 'OK'}
# 41.7,-72.65
# {'results': [{'dataset': 'etopo1', 'elevation': 12.0, 'location': {'lat': 41.7, 'lng': -72.65}}], 'status': 'OK'}
# 41.71056,-72.67361
# {'results': [{'dataset': 'etopo1', 'elevation': 28.0, 'location': {'lat': 41.71056, 'lng': -72.67361}}], 'status': 'OK'}
# 42.06667,-104.16667
# {'results': [{'dataset': 'etopo1', 'elevation': 1266.0, 'location': {'lat': 42.06667, 'lng': -104.16667}}], 'status': 'OK'}
# 41.5,-104.1
# {'results': [{'dataset': 'etopo1', 'elevation': 1568.0, 'location': {'lat': 41.5, 'lng': -104.1}}], 'status': 'OK'}
# 41.41667,-104.1
# {'results': [{'dataset': 'etopo1', 'elevation': 1626.0, 'location': {'lat': 41.41667, 'lng': -104.1}}], 'status': 'OK'}
# 44.5,-104.2
# {'results': [{'dataset': 'etopo1', 'elevation': 1244.0, 'location': {'lat': 44.5, 'lng': -104.2}}], 'status': 'OK'}
# 43.7,-104.7
# {'results': [{'dataset': 'etopo1', 'elevation': 1321.0, 'location': {'lat': 43.7, 'lng': -104.7}}], 'status': 'OK'}
# 42.91667,-104.41667
# {'results': [{'dataset': 'etopo1', 'elevation': 1450.0, 'location': {'lat': 42.91667, 'lng': -104.41667}}], 'status': 'OK'}
# 41.78333,-104.28333
# {'results': [{'dataset': 'etopo1', 'elevation': 1342.0, 'location': {'lat': 41.78333, 'lng': -104.28333}}], 'status': 'OK'}
# 44.33823,-107.67405
# {'results': [{'dataset': 'etopo1', 'elevation': 1483.0, 'location': {'lat': 44.33823, 'lng': -107.67405}}], 'status': 'OK'}
# 42.76667,-104.35
# {'results': [{'dataset': 'etopo1', 'elevation': 1507.0, 'location': {'lat': 42.76667, 'lng': -104.35}}], 'status': 'OK'}
# 41.18333,-104.06667
# {'results': [{'dataset': 'etopo1', 'elevation': 1540.0, 'location': {'lat': 41.18333, 'lng': -104.06667}}], 'status': 'OK'}
# 41.65,-109.025
# {'results': [{'dataset': 'etopo1', 'elevation': 1941.0, 'location': {'lat': 41.65, 'lng': -109.025}}], 'status': 'OK'}
# 41.23333,-104.98333
# {'results': [{'dataset': 'etopo1', 'elevation': 2006.0, 'location': {'lat': 41.23333, 'lng': -104.98333}}], 'status': 'OK'}
# 43.0,-107.16667
# {'results': [{'dataset': 'etopo1', 'elevation': 1813.0, 'location': {'lat': 43.0, 'lng': -107.16667}}], 'status': 'OK'}
# 43.46667,-106.76667
# {'results': [{'dataset': 'etopo1', 'elevation': 1636.0, 'location': {'lat': 43.46667, 'lng': -106.76667}}], 'status': 'OK'}
# 45.58333,-122.35
# {'results': [{'dataset': 'etopo1', 'elevation': 20.0, 'location': {'lat': 45.58333, 'lng': -122.35}}], 'status': 'OK'}
# 46.83333,-117.25
# {'results': [{'dataset': 'etopo1', 'elevation': 728.0, 'location': {'lat': 46.83333, 'lng': -117.25}}], 'status': 'OK'}
# 46.57056,-117.09861
# {'results': [{'dataset': 'etopo1', 'elevation': 803.0, 'location': {'lat': 46.57056, 'lng': -117.09861}}], 'status': 'OK'}
# 47.25,-122.41667
# {'results': [{'dataset': 'etopo1', 'elevation': 0.0, 'location': {'lat': 47.25, 'lng': -122.41667}}], 'status': 'OK'}
# 47.767778,-119.876389
# {'results': [{'dataset': 'etopo1', 'elevation': 876.0, 'location': {'lat': 47.767778, 'lng': -119.876389}}], 'status': 'OK'}
# 47.70667,-119.83
# {'results': [{'dataset': 'etopo1', 'elevation': 784.0, 'location': {'lat': 47.70667, 'lng': -119.83}}], 'status': 'OK'}
# 64.88333,-163.16666999999995
# {'results': [{'dataset': 'etopo1', 'elevation': 134.0, 'location': {'lat': 64.88333, 'lng': -163.16666999999995}}], 'status': 'OK'}
# 59.33333,-136.0
# {'results': [{'dataset': 'etopo1', 'elevation': 1146.0, 'location': {'lat': 59.33333, 'lng': -136.0}}], 'status': 'OK'}
# 55.18333000000001,-162.55
# {'results': [{'dataset': 'etopo1', 'elevation': -6.0, 'location': {'lat': 55.18333000000001, 'lng': -162.55}}], 'status': 'OK'}
# 65.38333,-146.26667
# {'results': [{'dataset': 'etopo1', 'elevation': 707.0, 'location': {'lat': 65.38333, 'lng': -146.26667}}], 'status': 'OK'}
# 37.83333,-80.31667
# {'results': [{'dataset': 'etopo1', 'elevation': 793.0, 'location': {'lat': 37.83333, 'lng': -80.31667}}], 'status': 'OK'}
# 37.9,-82.38333
# {'results': [{'dataset': 'etopo1', 'elevation': 303.0, 'location': {'lat': 37.9, 'lng': -82.38333}}], 'status': 'OK'}
# 38.9,-79.18333
# {'results': [{'dataset': 'etopo1', 'elevation': 419.0, 'location': {'lat': 38.9, 'lng': -79.18333}}], 'status': 'OK'}
# 46.43333,-109.83333
# {'results': [{'dataset': 'etopo1', 'elevation': 1277.0, 'location': {'lat': 46.43333, 'lng': -109.83333}}], 'status': 'OK'}
# 46.68333,-112.55
# {'results': [{'dataset': 'etopo1', 'elevation': 1736.0, 'location': {'lat': 46.68333, 'lng': -112.55}}], 'status': 'OK'}
# 45.6,-110.58333
# {'results': [{'dataset': 'etopo1', 'elevation': 1689.0, 'location': {'lat': 45.6, 'lng': -110.58333}}], 'status': 'OK'}
# 46.1,-111.4
# {'results': [{'dataset': 'etopo1', 'elevation': 1281.0, 'location': {'lat': 46.1, 'lng': -111.4}}], 'status': 'OK'}
# 46.78333,-108.56667
# {'results': [{'dataset': 'etopo1', 'elevation': 1069.0, 'location': {'lat': 46.78333, 'lng': -108.56667}}], 'status': 'OK'}
# 46.7,-110.13333
# {'results': [{'dataset': 'etopo1', 'elevation': 2066.0, 'location': {'lat': 46.7, 'lng': -110.13333}}], 'status': 'OK'}
# 45.0,-114.0
# {'results': [{'dataset': 'etopo1', 'elevation': 2044.0, 'location': {'lat': 45.0, 'lng': -114.0}}], 'status': 'OK'}
# 42.63333,-114.83333
# {'results': [{'dataset': 'etopo1', 'elevation': 1035.0, 'location': {'lat': 42.63333, 'lng': -114.83333}}], 'status': 'OK'}
# 42.33333,-113.7
# {'results': [{'dataset': 'etopo1', 'elevation': 1914.0, 'location': {'lat': 42.33333, 'lng': -113.7}}], 'status': 'OK'}
# 43.8,-117.0
# {'results': [{'dataset': 'etopo1', 'elevation': 670.0, 'location': {'lat': 43.8, 'lng': -117.0}}], 'status': 'OK'}
# 44.93389000000001,-116.43167
# {'results': [{'dataset': 'etopo1', 'elevation': 1556.0, 'location': {'lat': 44.93389000000001, 'lng': -116.43167}}], 'status': 'OK'}
# 43.72444,-116.91167
# {'results': [{'dataset': 'etopo1', 'elevation': 716.0, 'location': {'lat': 43.72444, 'lng': -116.91167}}], 'status': 'OK'}
# 42.31667,-72.63333
# {'results': [{'dataset': 'etopo1', 'elevation': 51.0, 'location': {'lat': 42.31667, 'lng': -72.63333}}], 'status': 'OK'}
# [{'results': [{'dataset': 'etopo1', 'elevation': 225.0, 'location': {'lat': 42.53333, 'lng': -85.88333}}], 'status': 'OK'}, {'results': [{'dataset': 'etopo1', 'elevation': 218.0, 'location': {'lat': 43.76111, 'lng': -84.50778000000003}}], 'status': 'OK'}, {'results': [{'dataset': 'etopo1', 'elevation': 387.0, 'location': {'lat': 44.51667, 'lng': -83.95}}], 'status': 'OK'}, {'results': [{'dataset': 'etopo1', 'elevation': 279.0, 'location': {'lat': 42.38467, 'lng': -83.6115}}], 'status': 'OK'}, {'results': [{'dataset': 'etopo1', 'elevation': 225.0, 'location': {'lat': 42.96667, 'lng': -85.76666999999998}}], 'status': 'OK'}, {'results': [{'dataset': 'etopo1', 'elevation': 510.0, 'location': {'lat': 46.07944000000001, 'lng': -88.55972}}], 'status': 'OK'}, {'results': [{'dataset': 'etopo1', 'elevation': 355.0, 'location': {'lat': 44.64694, 'lng': -85.13667}}], 'status': 'OK'}, {'results': [{'dataset': 'etopo1', 'elevation': 329.0, 'location': {'lat': 43.86667, 'lng': -85.51666999999998}}], 'status': 'OK'}, {'results': [{'dataset': 'etopo1', 'elevation': 243.0, 'location': {'lat': 41.78333, 'lng': -84.18333}}], 'status': 'OK'}, {'results': [{'dataset': 'etopo1', 'elevation': 220.0, 'location': {'lat': 44.61667, 'lng': -70.75}}], 'status': 'OK'}, {'results': [{'dataset': 'etopo1', 'elevation': 25.0, 'location': {'lat': 44.38333, 'lng': -68.75}}], 'status': 'OK'}, {'results': [{'dataset': 'etopo1', 'elevation': 44.0, 'location': {'lat': 44.08333, 'lng': -69.48333000000001}}], 'status': 'OK'}, {'results': [{'dataset': 'etopo1', 'elevation': 76.0, 'location': {'lat': 44.36667, 'lng': -69.2}}], 'status': 'OK'}, {'results': [{'dataset': 'etopo1', 'elevation': 68.0, 'location': {'lat': 43.827, 'lng': -70.24717}}], 'status': 'OK'}, {'results': [{'dataset': 'etopo1', 'elevation': 264.0, 'location': {'lat': 38.5, 'lng': -94.3}}], 'status': 'OK'}, {'results': [{'dataset': 'etopo1', 'elevation': 294.0, 'location': {'lat': 36.75, 'lng': -93.5}}], 'status': 'OK'}, {'results': [{'dataset': 'etopo1', 'elevation': 123.0, 'location': {'lat': 37.26667, 'lng': -89.58333}}], 'status': 'OK'}, {'results': [{'dataset': 'etopo1', 'elevation': 292.0, 'location': {'lat': 39.08333, 'lng': -94.4}}], 'status': 'OK'}, {'results': [{'dataset': 'etopo1', 'elevation': 281.0, 'location': {'lat': 37.91667, 'lng': -92.08333}}], 'status': 'OK'}, {'results': [{'dataset': 'etopo1', 'elevation': 179.0, 'location': {'lat': 39.8, 'lng': -91.5}}], 'status': 'OK'}, {'results': [{'dataset': 'etopo1', 'elevation': 147.0, 'location': {'lat': 38.7, 'lng': -90.23333}}], 'status': 'OK'}, {'results': [{'dataset': 'etopo1', 'elevation': 173.0, 'location': {'lat': 38.68333, 'lng': -91.15}}], 'status': 'OK'}, {'results': [{'dataset': 'etopo1', 'elevation': 416.0, 'location': {'lat': 37.06667, 'lng': -93.55}}], 'status': 'OK'}, {'results': [{'dataset': 'etopo1', 'elevation': 257.0, 'location': {'lat': 38.3, 'lng': -94.36667}}], 'status': 'OK'}, {'results': [{'dataset': 'etopo1', 'elevation': 318.0, 'location': {'lat': 40.266667, 'lng': -94.683333}}], 'status': 'OK'}, {'results': [{'dataset': 'etopo1', 'elevation': 339.0, 'location': {'lat': 39.59167, 'lng': -94.92194}}], 'status': 'OK'}, {'results': [{'dataset': 'etopo1', 'elevation': 329.0, 'location': {'lat': 39.61667, 'lng': -94.86667}}], 'status': 'OK'}, {'results': [{'dataset': 'etopo1', 'elevation': 295.0, 'location': {'lat': 38.65, 'lng': -94.33333}}], 'status': 'OK'}, {'results': [{'dataset': 'etopo1', 'elevation': 391.0, 'location': {'lat': 36.82444, 'lng': -93.76111}}], 'status': 'OK'}, {'results': [{'dataset': 'etopo1', 'elevation': 269.0, 'location': {'lat': 36.53333, 'lng': -91.8}}], 'status': 'OK'}, {'results': [{'dataset': 'etopo1', 'elevation': 305.0, 'location': {'lat': 40.2875, 'lng': -95.37667}}], 'status': 'OK'}, {'results': [{'dataset': 'etopo1', 'elevation': 270.0, 'location': {'lat': 36.55, 'lng': -93.1}}], 'status': 'OK'}, {'results': [{'dataset': 'etopo1', 'elevation': 162.0, 'location': {'lat': 37.73333, 'lng':  ...

# %%
# pull elevations from location dict
elevations = []

for ellie in range (0,len(responses)):
    elevations.append(responses[ellie]['results'][0]['elevation'])

elevations
# Out:
# [225.0,
#  218.0,
#  387.0,
#  279.0,
#  225.0,
#  510.0,
#  355.0,
#  329.0,
#  243.0,
#  220.0,
#  25.0,
#  44.0,
#  76.0,
#  68.0,
#  264.0,
#  294.0,
#  123.0,
#  292.0,
#  281.0,
#  179.0,
#  147.0,
#  173.0,
#  416.0,
#  257.0,
#  318.0,
#  339.0,
#  329.0,
#  295.0,
#  391.0,
#  269.0,
#  305.0,
#  270.0,
#  162.0,
#  481.0,
#  296.0,
#  234.0,
#  170.0,
#  216.0,
#  534.0,
#  310.0,
#  93.0,
#  31.0,
#  96.0,
#  812.0,
#  1220.0,
#  85.0,
#  497.0,
#  143.0,
#  1016.0,
#  868.0,
#  1268.0,
#  1005.0,
#  200.0,
#  1126.0,
#  1037.0,
#  962.0,
#  163.0,
#  526.0,
#  1078.0,
#  212.0,
#  982.0,
#  449.0,
#  1208.0,
#  122.0,
#  96.0,
#  533.0,
#  590.0,
#  1001.0,
#  1162.0,
#  1152.0,
#  1152.0,
#  989.0,
#  989.0,
#  1006.0,
#  989.0,
#  681.0,
#  486.0,
#  47.0,
#  1075.0,
#  339.0,
#  118.0,
#  602.0,
#  1230.0,
#  1147.0,
#  624.0,
#  1185.0,
#  873.0,
#  868.0,
#  1010.0,
#  1035.0,
#  243.0,
#  423.0,
#  407.0,
#  784.0,
#  299.0,
#  80.0,
#  1203.0,
#  1687.0,
#  149.0,
#  119.0,
#  1127.0,
#  1127.0,
#  288.0,
#  167.0,
#  1094.0,
#  131.0,
#  131.0,
#  234.0,
#  1154.0,
#  1162.0,
#  952.0,
#  1094.0,
#  1086.0,
#  623.0,
#  207.0,
#  1057.0,
#  1057.0,
#  1217.0,
#  797.0,
#  1011.0,
#  1086.0,
#  1059.0,
#  1177.0,
#  982.0,
#  450.0,
#  1015.0,
#  1034.0,
#  1187.0,
#  999.0,
#  961.0,
#  969.0,
#  771.0,
#  826.0,
#  285.0,
#  300.0,
#  947.0,
#  991.0,
#  1000.0,
#  1219.0,
#  780.0,
#  1047.0,
#  189.0,
#  1029.0,
#  914.0,
#  887.0,
#  1164.0,
#  972.0,
#  170.0,
#  1018.0,
#  1018.0,
#  416.0,
#  1135.0,
#  1120.0,
#  1129.0,
#  1038.0,
#  1115.0,
#  1073.0,
#  1161.0,
#  482.0,
#  1053.0,
#  339.0,
#  253.0,
#  1224.0,
#  1271.0,
#  1271.0,
#  305.0,
#  192.0,
#  606.0,
#  1102.0,
#  1083.0,
#  1083.0,
#  1083.0,
#  128.0,
#  192.0,
#  603.0,
#  1054.0,
#  1054.0,
#  1051.0,
#  1050.0,
#  212.0,
#  19.0,
#  936.0,
#  1042.0,
#  913.0,
#  1233.0,
#  330.0,
#  620.0,
#  1048.0,
#  1048.0,
#  550.0,
#  975.0,
#  993.0,
#  962.0,
#  1001.0,
#  1001.0,
#  1072.0,
#  965.0,
#  477.0,
#  161.0,
#  897.0,
#  1038.0,
#  1038.0,
#  229.0,
#  876.0,
#  1029.0,
#  1029.0,
#  542.0,
#  695.0,
#  906.0,
#  771.0,
#  1005.0,
#  1151.0,
#  791.0,
#  1179.0,
#  85.0,
#  448.0,
#  460.0,
#  1161.0,
#  1161.0,
#  1139.0,
#  1139.0,
#  1129.0,
#  1144.0,
#  1173.0,
#  1001.0,
#  905.0,
#  959.0,
#  960.0,
#  96.0,
#  125.0,
#  904.0,
#  933.0,
#  1094.0,
#  775.0,
#  999.0,
#  1054.0,
#  890.0,
#  836.0,
#  613.0,
#  1113.0,
#  888.0,
#  409.0,
#  1116.0,
#  1144.0,
#  1032.0,
#  1032.0,
#  1030.0,
#  1025.0,
#  1024.0,
#  521.0,
#  808.0,
#  181.0,
#  102.0,
#  431.0,
#  112.0,
#  1014.0,
#  1250.0,
#  139.0,
#  124.0,
#  126.0,
#  200.0,
#  561.0,
#  237.0,
#  700.0,
#  684.0,
#  1024.0,
#  1007.0,
#  1028.0,
#  990.0,
#  1003.0,
#  933.0,
#  1010.0,
#  1010.0,
#  1007.0,
#  1010.0,
#  1010.0,
#  1010.0,
#  1026.0,
#  976.0,
#  1007.0,
#  890.0,
#  958.0,
#  1091.0,
#  1031.0,
#  709.0,
#  277.0,
#  971.0,
#  1071.0,
#  942.0,
#  1117.0,
#  822.0,
#  990.0,
#  805.0,
#  998.0,
#  1182.0,
#  1069.0,
#  666.0,
#  602.0,
#  592.0,
#  194.0,
#  1420.0,
#  1135.0,
#  1073.0,
#  1082.0,
#  1088.0,
#  188.0,
#  290.0,
#  1131.0,
#  1114.0,
#  1042.0,
#  1063.0,
#  1031.0,
#  1154.0,
#  274.0,
#  196.0,
#  1010.0,
#  939.0,
#  852.0,
#  1092.0,
#  1069.0,
#  638.0,
#  991.0,
#  1007.0,
#  991.0,
#  998.0,
#  1063.0,
#  946.0,
#  959.0,
#  355.0,
#  302.0,
#  85.0,
#  1220.0,
#  204.0,
#  182.0,
#  52.0,
#  213.0,
#  188.0,
#  178.0,
#  203.0,
#  144.0,
#  293.0,
#  144.0,
#  466.0,
#  31.0,
#  35.0,
#  251.0,
#  47.0,
#  170.0,
#  200.0,
#  201.0,
#  325.0,
#  342.0,
#  627.0,
#  255.0,
#  304.0,
#  379.0,
#  761.0,
#  570.0,
#  412.0,
#  444.0,
#  308.0,
#  392.0,
#  470.0,
#  507.0,
#  281.0,
#  1092.0,
#  1349.0,
#  1328.0,
#  888.0,
#  336.0,
#  1265.0,
#  232.0,
#  331.0,
#  783.0,
#  383.0,
#  237.0,
#  729.0,
#  507.0,
#  373.0,
#  344.0,
#  466.0,
#  173.0,
#  290.0,
#  218.0,
#  464.0,
#  515.0,
#  1187.0,
#  651.0,
#  196.0,
#  1758.0,
#  892.0,
#  1525.0,
#  1221.0,
#  1857.0,
#  1186.0,
#  1867.0,
#  1361.0,
#  1264.0,
#  1239.0,
#  1210.0,
#  2686.0,
#  1678.0,
#  1242.0,
#  1246.0,
#  1237.0,
#  2018.0,
#  1365.0,
#  2137.0,
#  1882.0,
#  1256.0,
#  1256.0,
#  1222.0,
#  1674.0,
#  3513.0,
#  1281.0,
#  1291.0,
#  1298.0,
#  1304.0,
#  1370.0,
#  1295.0,
#  1320.0,
#  1899.0,
#  1351.0,
#  1372.0,
#  1347.0,
#  1301.0,
#  1843.0,
#  1266.0,
#  1456.0,
#  1314.0,
#  1807.0,
#  2392.0,
#  1398.0,
#  1398.0,
#  1398.0,
#  2016.0,
#  1315.0,
#  1246.0,
#  1897.0,
#  1101.0,
#  1101.0,
#  1376.0,
#  1334.0,
#  2200.0,
#  1298.0,
#  1257.0,
#  1865.0,
#  996.0,
#  909.0,
#  908.0,
#  909.0,
#  1331.0,
#  1583.0,
#  1615.0,
#  1340.0,
#  1303.0,
#  1319.0,
#  1888.0,
#  1278.0,
#  1888.0,
#  1661.0,
#  1587.0,
#  2554.0,
#  1243.0,
#  1235.0,
#  1960.0,
#  1931.0,
#  1828.0,
#  2659.0,
#  1553.0,
#  1661.0,
#  1828.0,
#  1828.0,
#  1301.0,
#  1301.0,
#  1263.0,
#  1442.0,
#  1411.0,
#  1462.0,
#  1621.0,
#  1294.0,
#  1294.0,
#  1294.0,
#  1279.0,
#  1349.0,
#  1365.0,
#  1365.0,
#  1294.0,
#  1245.0,
#  1294.0,
#  1254.0,
#  1228.0,
#  1288.0,
#  1288.0,
#  1288.0,
#  1288.0,
#  1288.0,
#  1233.0,
#  1269.0,
#  1282.0,
#  1282.0,
#  1249.0,
#  1245.0,
#  1227.0,
#  1294.0,
#  1294.0,
#  1276.0,
#  1261.0,
#  1294.0,
#  1294.0,
#  1249.0,
#  1345.0,
#  1294.0,
#  1294.0,
#  1287.0,
#  1287.0,
#  1287.0,
#  1282.0,
#  1256.0,
#  1294.0,
#  1294.0,
#  1294.0,
#  1282.0,
#  1287.0,
#  1246.0,
#  1238.0,
#  1288.0,
#  1243.0,
#  1306.0,
#  1294.0,
#  1294.0,
#  1239.0,
#  1288.0,
#  1360.0,
#  1257.0,
#  1257.0,
#  1338.0,
#  1245.0,
#  1294.0,
#  1294.0,
#  1287.0,
#  1282.0,
#  1238.0,
#  1294.0,
#  1294.0,
#  1306.0,
#  1288.0,
#  1288.0,
#  1288.0,
#  1288.0,
#  1288.0,
#  1288.0,
#  1288.0,
#  1299.0,
#  1282.0,
#  1237.0,
#  1294.0,
#  1294.0,
#  1294.0,
#  1285.0,
#  1309.0,
#  1234.0,
#  1281.0,
#  1302.0,
#  1237.0,
#  1270.0,
#  1255.0,
#  1292.0,
#  1365.0,
#  1265.0,
#  1255.0,
#  1294.0,
#  1294.0,
#  1294.0,
#  1294.0,
#  1286.0,
#  1309.0,
#  1308.0,
#  1253.0,
#  1266.0,
#  1256.0,
#  1302.0,
#  1288.0,
#  1363.0,
#  1366.0,
#  1324.0,
#  1339.0,
#  1229.0,
#  1234.0,
#  1234.0,
#  1359.0,
#  1795.0,
#  1795.0,
#  1151.0,
#  2104.0,
#  1575.0,
#  1266.0,
#  1674.0,
#  1937.0,
#  1937.0,
#  1271.0,
#  1271.0,
#  1253.0,
#  2226.0,
#  2508.0,
#  1619.0,
#  1738.0,
#  1800.0,
#  1902.0,
#  1946.0,
#  1166.0,
#  88.0,
#  162.0,
#  59.0,
#  20.0,
#  461.0,
#  164.0,
#  98.0,
#  974.0,
#  321.0,
#  672.0,
#  1064.0,
#  356.0,
#  291.0,
#  180.0,
#  699.0,
#  699.0,
#  261.0,
#  215.0,
#  242.0,
#  198.0,
#  927.0,
#  199.0,
#  513.0,
#  59.0,
#  770.0,
#  215.0,
#  191.0,
#  805.0,
#  119.0,
#  103.0,
#  95.0,
#  394.0,
#  374.0,
#  1041.0,
#  797.0,
#  394.0,
#  1459.0,
#  420.0,
#  859.0,
#  734.0,
#  474.0,
#  452.0,
#  906.0,
#  779.0,
#  806.0,
#  660.0,
#  411.0,
#  279.0,
#  363.0,
#  322.0,
#  249.0,
#  144.0,
#  144.0,
#  255.0,
#  286.0,
#  301.0,
#  263.0,
#  234.0,
#  237.0,
#  216.0,
#  244.0,
#  274.0,
#  244.0,
#  110.0,
#  251.0,
#  217.0,
#  179.0,
#  237.0,
#  140.0,
#  216.0,
#  112.0,
#  809.0,
#  369.0,
#  1852.0,
#  1467.0,
#  1376.0,
#  806.0,
#  1194.0,
#  1485.0,
#  1191.0,
#  1191.0,
#  1191.0,
#  1191.0,
#  1191.0,
#  1190.0,
#  1190.0,
#  1191.0,
#  1191.0,
#  1192.0,
#  1192.0,
#  1192.0,
#  1192.0,
#  1192.0,
#  1192.0,
#  1192.0,
#  1191.0,
#  1204.0,
#  1204.0,
#  794.0,
#  801.0,
#  1760.0,
#  1399.0,
#  1303.0,
#  1381.0,
#  1271.0,
#  1271.0,
#  1271.0,
#  1347.0,
#  1755.0,
#  1421.0,
#  1449.0,
#  1419.0,
#  1336.0,
#  1390.0,
#  421.0,
#  1584.0,
#  797.0,
#  1592.0,
#  1689.0,
#  803.0,
#  800.0,
#  798.0,
#  800.0,
#  798.0,
#  802.0,
#  799.0,
#  803.0,
#  798.0,
#  797.0,
#  800.0,
#  1527.0,
#  1466.0,
#  1706.0,
#  1706.0,
#  768.0,
#  757.0,
#  753.0,
#  753.0,
#  753.0,
#  753.0,
#  755.0,
#  839.0,
#  1562.0,
#  1563.0,
#  1563.0,
#  1563.0,
#  1563.0,
#  1563.0,
#  1564.0,
#  1563.0,
#  1563.0,
#  1563.0,
#  1562.0,
#  1562.0,
#  1563.0,
#  1568.0,
#  1567.0,
#  1567.0,
#  1567.0,
#  1567.0,
#  1562.0,
#  1563.0,
#  1566.0,
#  1734.0,
#  1694.0,
#  931.0,
#  433.0,
#  823.0,
#  959.0,
#  715.0,
#  278.0,
#  636.0,
#  906.0,
#  385.0,
#  743.0,
#  442.0,
#  411.0,
#  386.0,
#  436.0,
#  780.0,
#  373.0,
#  682.0,
#  978.0,
#  668.0,
#  1038.0,
#  736.0,
#  560.0,
#  651.0,
#  350.0,
#  523.0,
#  245.0,
#  962.0,
#  639.0,
#  639.0,
#  1018.0,
#  554.0,
#  631.0,
#  621.0,
#  675.0,
#  452.0,
#  830.0,
#  462.0,
#  740.0,
#  1090.0,
#  622.0,
#  356.0,
#  473.0,
#  713.0,
#  606.0,
#  320.0,
#  522.0,
#  1110.0,
#  516.0,
#  954.0,
#  589.0,
#  663.0,
#  465.0,
#  1090.0,
#  450.0,
#  661.0,
#  667.0,
#  448.0,
#  673.0,
#  1108.0,
#  950.0,
#  840.0,
#  452.0,
#  795.0,
#  998.0,
#  453.0,
#  793.0,
#  259.0,
#  309.0,
#  1079.0,
#  333.0,
#  636.0,
#  250.0,
#  425.0,
#  812.0,
#  837.0,
#  500.0,
#  507.0,
#  654.0,
#  486.0,
#  484.0,
#  406.0,
#  392.0,
#  400.0,
#  701.0,
#  332.0,
#  364.0,
#  959.0,
#  734.0,
#  538.0,
#  651.0,
#  710.0,
#  746.0,
#  792.0,
#  554.0,
#  923.0,
#  812.0,
#  624.0,
#  306.0,
#  1024.0,
#  839.0,
#  672.0,
#  843.0,
#  843.0,
#  262.0,
#  483.0,
#  819.0,
#  768.0,
#  709.0,
#  1023.0,
#  1009.0,
#  1009.0,
#  1021.0,
#  1021.0,
#  485.0,
#  834.0,
#  754.0,
#  797.0,
#  576.0,
#  907.0,
#  893.0,
#  865.0,
#  348.0,
#  1123.0,
#  768.0,
#  587.0,
#  737.0,
#  893.0,
#  307.0,
#  939.0,
#  374.0,
#  461.0,
#  541.0,
#  252.0,
#  408.0,
#  1043.0,
#  534.0,
#  402.0,
#  657.0,
#  179.0,
#  243.0,
#  218.0,
#  146.0,
#  263.0,
#  196.0,
#  223.0,
#  237.0,
#  1510.0,
#  1689.0,
#  1600.0,
#  2089.0,
#  1458.0,
#  1412.0,
#  1395.0,
#  1395.0,
#  2300.0,
#  1851.0,
#  1234.0,
#  1150.0,
#  1581.0,
#  1219.0,
#  1219.0,
#  2414.0,
#  1296.0,
#  2118.0,
#  1503.0,
#  2081.0,
#  1608.0,
#  1340.0,
#  1345.0,
#  1969.0,
#  2488.0,
#  1364.0,
#  2509.0,
#  1297.0,
#  2761.0,
#  1460.0,
#  1927.0,
#  1556.0,
#  1488.0,
#  1287.0,
#  1852.0,
#  2456.0,
#  2802.0,
#  1127.0,
#  2777.0,
#  2832.0,
#  1211.0,
#  1054.0,
#  1141.0,
#  1404.0,
#  1543.0,
#  1212.0,
#  1173.0,
#  1543.0,
#  1364.0,
#  1536.0,
#  1528.0,
#  2297.0,
#  2295.0,
#  2021.0,
#  2301.0,
#  3841.0,
#  1456.0,
#  2301.0,
#  1078.0,
#  1171.0,
#  1340.0,
#  1159.0,
#  1820.0,
#  1265.0,
#  2586.0,
#  1146.0,
#  1417.0,
#  1446.0,
#  1558.0,
#  1347.0,
#  1362.0,
#  1217.0,
#  1412.0,
#  1166.0,
#  1354.0,
#  1494.0,
#  1782.0,
#  1640.0,
#  ...]

# %%
# add elevation to meteorite8
meteorite8['elevation'] = elevations
print(len(meteorite8))
print(type(meteorite8))
meteorite8.head(2)
# Out:
# 1650
# <class 'pandas.core.frame.DataFrame'>
#       name    id nametype recclass  mass_grams  fall  year    reclat  \
# 0  Allegan  2276    Valid       H5     32000.0  Fell  1899  42.53333
# 1  Coleman  5401    Valid       L6       469.0  Fell  1994  43.76111
#
#     reclong            geolocation                    geometry state_abbrev_x  \
# 0 -85.88333  (42.53333, -85.88333)  POINT (-85.88333 42.53333)     None_Found
# 1 -84.50778  (43.76111, -84.50778)  POINT (-84.50778 43.76111)     None_Found
#
#       state          county        country  elevation state_abbrev_y  FIPS
# 0  Michigan  Allegan County  United States      225.0             MI    26
# 1  Michigan  Midland County  United States      218.0             MI    26

# %%
meteorite8.rename({'state_abbrev_y':'state_abbrev'},axis=1, inplace = True)

# %%
# save US data with county info to csv - interim csvs available for troubleshooting, uncomment if needed.
meteorite8.to_csv('Resources/Raw_Data/meteorite8_interim.csv')

# %%
# create meteorite_main
meteorite = meteorite8[['id','name','recclass','mass_grams','fall','year','reclat','reclong','geolocation','geometry','elevation','country','state_abbrev']]
print(len(meteorite))
print(type(meteorite))
meteorite.head(2)
# Out:
# 1650
# <class 'pandas.core.frame.DataFrame'>
#      id     name recclass  mass_grams  fall  year    reclat   reclong  \
# 0  2276  Allegan       H5     32000.0  Fell  1899  42.53333 -85.88333
# 1  5401  Coleman       L6       469.0  Fell  1994  43.76111 -84.50778
#
#              geolocation                    geometry  elevation  \
# 0  (42.53333, -85.88333)  POINT (-85.88333 42.53333)      225.0
# 1  (43.76111, -84.50778)  POINT (-84.50778 43.76111)      218.0
#
#          country state_abbrev
# 0  United States           MI
# 1  United States           MI

# %%
# save US data with county info to csv - csv already created, commented out so it doesn't get overwritten. Uncomment if needed.
meteorite.to_csv('Resources/DB_CSV/meteorite_main.csv', index = False)

# %%
# check landcover.csv - csv already created, commented out so it doesn't get overwritten. Uncomment if needed.
meteorite_main_check = pd.read_csv('Resources/DB_CSV/meteorite_main.csv')
print(len(meteorite_main_check))
print(meteorite_main_check.dtypes)
meteorite_main_check.head()
# Out:
# 1650
# id                int64
# name             object
# recclass         object
# mass_grams      float64
# fall             object
# year              int64
# reclat          float64
# reclong         float64
# geolocation      object
# geometry         object
# elevation       float64
# country          object
# state_abbrev     object
# dtype: object
#       id          name         recclass  mass_grams   fall  year    reclat  \
# 0   2276       Allegan               H5     32000.0   Fell  1899  42.53333
# 1   5401       Coleman               L6       469.0   Fell  1994  43.76111
# 2  22766     Rose City               H5     10600.0   Fell  1921  44.51667
# 3  24337        Worden               L5      1551.0   Fell  1997  42.38467
# 4  10955  Grand Rapids  Iron, ungrouped     51700.0  Found  1883  42.96667
#
#     reclong            geolocation                    geometry  elevation  \
# 0 -85.88333  (42.53333, -85.88333)  POINT (-85.88333 42.53333)      225.0
# 1 -84.50778  (43.76111, -84.50778)  POINT (-84.50778 43.76111)      218.0
# 2 -83.95000     (44.51667, -83.95)     POINT (-83.95 44.51667)      387.0
# 3 -83.61150   (42.38467, -83.6115)   POINT (-83.6115 42.38467)      279.0
# 4 -85.76667  (42.96667, -85.76667)  POINT (-85.76667 42.96667)      225.0
#
#          country state_abbrev
# 0  United States           MI
# 1  United States           MI
# 2  United States           MI
# 3  United States           MI
# 4  United States           MI

# %% [markdown]
# * meteorite_main table schema and csv are compatible
# * Use meteorite_main.csv to populate meteorite_main db table
