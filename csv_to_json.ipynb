# %%
import pandas as pd

df = pd.read_csv ('Resources/Meteorite_Landings_clean.csv')
df
# Out:
#        Unnamed: 0        name     id nametype              recclass  mass (g)  \
# 0               0      Aachen      1    Valid                    L5      21.0
# 1               1      Aarhus      2    Valid                    H6     720.0
# 2               2        Abee      6    Valid                   EH4  107000.0
# 3               3    Acapulco     10    Valid           Acapulcoite    1914.0
# 4               4     Achiras    370    Valid                    L6     780.0
# ...           ...         ...    ...      ...                   ...       ...
# 38109       45711  Zillah 002  31356    Valid               Eucrite     172.0
# 38110       45712      Zinder  30409    Valid  Pallasite, ungrouped      46.0
# 38111       45713        Zlin  30410    Valid                    H4       3.3
# 38112       45714   Zubkovsky  31357    Valid                    L6    2167.0
# 38113       45715  Zulu Queen  30414    Valid                  L3.7     200.0
#
# ...

# %%
df.to_json ('Resources/Meteorite.json')
