# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# import plotly.express as px

# %%
land_data = pd.read_csv('Resources/LAND_COVER_14032023014858227.csv')

# %%
land_data.head()
# Out:
#    COU    Country  SMALL_SUBNATIONAL_REGION Small subnational region  \
# 0  AUS  Australia                       NaN           Not applicable
# 1  AUS  Australia                       NaN           Not applicable
# 2  AUS  Australia                       NaN           Not applicable
# 3  AUS  Australia                       NaN           Not applicable
# 4  AUS  Australia                       NaN           Not applicable
#
#   LARGE_SUBNATIONAL_REGION           Large subnational region           MEAS  \
# 0           GAUL1_467_2015  Administrative unit not available  THOUSAND_SQKM
# 1           GAUL1_467_2015  Administrative unit not available  THOUSAND_SQKM
# 2           GAUL1_467_2015  Administrative unit not available  THOUSAND_SQKM
# 3           GAUL1_467_2015  Administrative unit not available  THOUSAND_SQKM
# 4           GAUL1_467_2015  Administrative unit not available  THOUSAND_SQKM
#
#                      Measure VARIABLE Land cover class  ...  Year  Unit Code  \
# ...

# %%
land_data.columns
# Out:
# Index(['COU', 'Country', 'SMALL_SUBNATIONAL_REGION',
#        'Small subnational region', 'LARGE_SUBNATIONAL_REGION',
#        'Large subnational region', 'MEAS', 'Measure', 'VARIABLE',
#        'Land cover class', 'YEA', 'Year', 'Unit Code', 'Unit',
#        'PowerCode Code', 'PowerCode', 'Reference Period Code',
#        'Reference Period', 'Value', 'Flag Codes', 'Flags'],
#       dtype='object')

# %%
# Filtering to most recent year
land_data = land_data.loc[land_data['Year'] == 2019] 
land_data
# Out:
#         COU      Country  SMALL_SUBNATIONAL_REGION Small subnational region  \
# 4       AUS    Australia                       NaN           Not applicable
# 9       AFG  Afghanistan                       NaN           Not applicable
# 14      AFG  Afghanistan                       NaN           Not applicable
# 19      AFG  Afghanistan                       NaN           Not applicable
# 24      AFG  Afghanistan                       NaN           Not applicable
# ...     ...          ...                       ...                      ...
# 253842  MNE   Montenegro                       NaN           Not applicable
# 253847  MNE   Montenegro                       NaN           Not applicable
# 253852  MNE   Montenegro                       NaN           Not applicable
# 253857  MNE   Montenegro                       NaN           Not applicable
# 253862  MNE   Montenegro                       NaN           Not applicable
#
# ...

# %%
land_data = land_data.loc[land_data['MEAS'] == 'THOUSAND_SQKM'] 
land_data
# Out:
#         COU      Country  SMALL_SUBNATIONAL_REGION Small subnational region  \
# 4       AUS    Australia                       NaN           Not applicable
# 9       AFG  Afghanistan                       NaN           Not applicable
# 14      AFG  Afghanistan                       NaN           Not applicable
# 29      AFG  Afghanistan                       NaN           Not applicable
# 34      AFG  Afghanistan                       NaN           Not applicable
# ...     ...          ...                       ...                      ...
# 253797  MNE   Montenegro                       NaN           Not applicable
# 253802  MNE   Montenegro                       NaN           Not applicable
# 253807  MNE   Montenegro                       NaN           Not applicable
# 253812  MNE   Montenegro                       NaN           Not applicable
# 253817  MNE   Montenegro                       NaN           Not applicable
#
# ...

# %%
land_data.loc[:, 'Value'] *=1000
# Out:
# /Users/greg/opt/anaconda3/envs/PythonDataOne/lib/python3.7/site-packages/pandas/core/indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
#creating new DF with needed rows
land_df = land_data[[
       'COU','Large subnational region',
       'Land cover class', 'Value', 'Unit Code'
       ]]

land_df.reset_index()
land_df
# Out:
#         COU           Large subnational region                    Measure  \
# 4       AUS  Administrative unit not available  Square kilometers (000's)
# 9       AFG                              Logar  Square kilometers (000's)
# 14      AFG                              Logar  Square kilometers (000's)
# 29      AFG                              Farah  Square kilometers (000's)
# 34      AFG                            Hilmand  Square kilometers (000's)
# ...     ...                                ...                        ...
# 253797  MNE                         Montenegro  Square kilometers (000's)
# 253802  MNE                         Montenegro  Square kilometers (000's)
# 253807  MNE                         Montenegro  Square kilometers (000's)
# 253812  MNE                         Montenegro  Square kilometers (000's)
# 253817  MNE                         Montenegro  Square kilometers (000's)
#
#            Land cover class        Value Unit Code
# ...

# %%
# Checking missing values. 
land_df.isnull().sum()
# Out:
# COU                         0
# Large subnational region    0
# Measure                     0
# Land cover class            0
# Value                       0
# Unit Code                   0
# dtype: int64

# %%
# checking number of unique values per column
land_df.nunique()
# Out:
# COU                           237
# Large subnational region     2659
# Measure                         1
# Land cover class                9
# Value                       10827
# Unit Code                       1
# dtype: int64

# %%
# Write clean data to csv
# land_df.to_csv('Resources/land_coverage.csv', index = True)
